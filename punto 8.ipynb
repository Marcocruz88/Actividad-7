# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 13-14: redes neuronales para clasificación
#
# - Redes densas
# - Redes para clasificación
# - Procesamiento de datos continuos y categóricos
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy, pandas, keras, tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# Descripción de las variables:
#
# https://archive.ics.uci.edu/dataset/45/heart+disease

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Definimos listas para las variables categóricas enteras, categóricas string y numéricas.

# %%
subset_feats = ['age', 'trestbps', 'chol', 'sex', 'cp']
df = df[subset_feats+['target']]

# %%
df.head()
# Out:
#    age  trestbps  chol  sex  cp  target
# 0   63       145   233    1   1       0
# 1   67       160   286    1   4       1
# 2   67       120   229    1   4       0
# 3   37       130   250    1   3       0
# 4   41       130   204    0   2       0

# %% [markdown]
# Separamos los datos en entrenamiento, validación y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#      age  trestbps  chol  sex  cp  target
# 69    35       138   183    0   4       0
# 300   65       135   254    1   4       1
# 220   59       134   204    1   1       0
# 134   42       120   240    1   3       0
# 7     57       120   354    0   4       0

# %%
train.shape
# Out:
# (242, 6)

# %%
test = df.drop(train.index)
test.head()
# Out:
#     age  trestbps  chol  sex  cp  target
# 0    63       145   233    1   1       0
# 2    67       120   229    1   4       0
# 4    41       130   204    0   2       0
# 8    63       130   254    1   4       1
# 13   44       120   263    1   2       0

# %%
val = train.sample(frac=0.2, random_state=100)

# %%
val.shape
# Out:
# (48, 6)

# %%
train = train.drop(val.index)

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (194, 6)
# (48, 6)
# (61, 6)

# %% [markdown]
# Calculamos estadísticas de cada variable numérica

# %%
train.describe()
# Out:
#               age    trestbps        chol         sex          cp      target
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    54.953608  132.876289  249.974227    0.664948    3.097938    0.257732
# std      8.754150   17.952879   52.803226    0.473230    1.030969    0.438517
# min     34.000000   94.000000  126.000000    0.000000    0.000000    0.000000
# 25%     49.000000  120.000000  215.750000    0.000000    2.000000    0.000000
# 50%     56.000000  130.000000  243.000000    1.000000    3.000000    0.000000
# 75%     61.000000  143.500000  281.000000    1.000000    4.000000    1.000000
# max     77.000000  192.000000  564.000000    1.000000    4.000000    1.000000

# %% [markdown]
# Función para convertir de dataframe (pandas) a dataset (tensorflow), separando características y etiquetas

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

# %%
train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %% [markdown]
# Ejemplo de cómo queda el tf.dataset

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=52>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=125>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=212>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=4>}
# Target: tf.Tensor(1, shape=(), dtype=int64)

# %% [markdown]
# Separamos los datos de entrenamiento, validación y prueba en lotes

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Función para codificar variables numéricas (Keras docs)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

# %% [markdown]
# Función para codificar variables categóricas (Keras docs)

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# Creamos una lista de inputs para el modelo, de acuerdo con cada tipo de variable

# %%
inputs = {
    'age': keras.Input(shape=(1,), name='age'),
    'trestbps': keras.Input(shape=(1,), name='trestbps'),
    'chol': keras.Input(shape=(1,), name='chol'),
    'sex': keras.Input(shape=(1,), name='sex', dtype='int64'),
    'cp': keras.Input(shape=(1,), name='cp', dtype='int64')
}
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
for i in inputs:
   print(i)
# Out:
# age
# trestbps
# chol
# sex
# cp

# %% [markdown]
# Creamos una lista de variables codificadas/normalizadas de acuerdo con su tipo, empleando las funciones de codificación/normalización

# %%
feats_encoded = [
    encode_numerical_feature(inputs['age'], 'age', train_ds),
    encode_numerical_feature(inputs['trestbps'], 'trestbps', train_ds),
    encode_numerical_feature(inputs['chol'], 'chol', train_ds),
    encode_categorical_feature(inputs['sex'], 'sex', train_ds, False),  # 'sex' es categórica (entero)
    encode_categorical_feature(inputs['cp'], 'cp', train_ds, False)  # 'cp' es categórica (entero)
]
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.

# %%
len_feats = len(feats_encoded)
len_feats
# Out:
# 5

# %%
for i in feats_encoded:
  print(i)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization/truediv:0', description="created by layer 'normalization'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_1/truediv:0', description="created by layer 'normalization_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_2/truediv:0', description="created by layer 'normalization_2'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='integer_lookup/bincount/DenseBincount:0', description="created by layer 'integer_lookup'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 6), dtype=tf.float32, name=None), name='integer_lookup_1/bincount/DenseBincount:0', description="created by layer 'integer_lookup_1'")

# %% [markdown]
# Creamos una capa concatenando todas las variables codificadas

# %%
all_feats = keras.layers.concatenate(feats_encoded)

# %%
type(all_feats)
# Out:
# keras.src.engine.keras_tensor.KerasTensor

# %% [markdown]
# Agregamos una capa densa con 32 neuronas y función de activación relu

# %%
#variacion 1
model_layers_var1 = keras.layers.Dense(64, activation='softplus')(all_feats)
model_layers_var1 = keras.layers.Dense(64, activation='softplus')(model_layers_var1)
model_layers_var1 = keras.layers.Dense(64, activation='softplus')(model_layers_var1)
model_layers_var1 = keras.layers.Dense(64, activation='softplus')(model_layers_var1)


#variacion 2
model_layers_var2 = keras.layers.Dense(32, activation='relu')(all_feats)
model_layers_var2 = keras.layers.Dense(32, activation='relu')(model_layers_var2)
model_layers_var2 = keras.layers.Dense(32, activation='relu')(model_layers_var2)

# %% [markdown]
# Agregamos la capa de salida con 1 neurona (probabilidad de sufrir la enfermedad cardiada) y función de activación sigmoide

# %%
#variacion 1
model_layers_var1 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var1)

#variacion 2
model_layers_var2 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var2)

# %% [markdown]
# Creamos el modelo con las capas ya creadas y las variables de entrada

# %%
#variacion 1
model_var1= keras.Model(inputs, model_layers_var1)

#Variacion 2
model_var2= keras.Model(inputs, model_layers_var2)

# %% [markdown]
# Compilamos el modelo, definiendo optimizador, función de pérdida y métricas adicionales a capturar

# %%
#variacion 1
model_var1.compile(optimizer=keras.optimizers.SGD(learning_rate=0.003), loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 2
model_var2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Aseguramos que Keras use TensorFlow como backend, para asegurar que el modelo pueda usar strings como entradas

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# Entrenamos el modelo con los datos en el formato tf.Dataset

# %%
#variacion 1
history_var1=model_var1.fit(train_ds, epochs=50, validation_data=val_ds)
#Variacion 2
history_var2=model_var2.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 7/7 [==============================] - 1s 28ms/step - loss: 0.6448 - accuracy: 0.7423 - val_loss: 0.6028 - val_accuracy: 0.7500
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6000 - accuracy: 0.7423 - val_loss: 0.5776 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5811 - accuracy: 0.7423 - val_loss: 0.5672 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5749 - accuracy: 0.7423 - val_loss: 0.5632 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5722 - accuracy: 0.7423 - val_loss: 0.5621 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5715 - accuracy: 0.7423 - val_loss: 0.5620 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5720 - accuracy: 0.7423 - val_loss: 0.5646 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5730 - accuracy: 0.7423 - val_loss: 0.5708 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5770 - accuracy: 0.7423 - val_loss: 0.5644 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5724 - accuracy: 0.7423 - val_loss: 0.5622 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5719 - accuracy: 0.7423 - val_loss: 0.5618 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5717 - accuracy: 0.7423 - val_loss: 0.5620 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5721 - accuracy: 0.7423 - val_loss: 0.5623 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5723 - accuracy: 0.7423 - val_loss: 0.5627 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5733 - accuracy: 0.7423 - val_loss: 0.5631 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5744 - accuracy: 0.7423 - val_loss: 0.5636 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5742 - accuracy: 0.7423 - val_loss: 0.5639 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5741 - accuracy: 0.7423 - val_loss: 0.5640 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5743 - accuracy: 0.7423 - val_loss: 0.5620 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5711 - accuracy: 0.7423 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5717 - accuracy: 0.7423 - val_loss: 0.5647 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5730 - accuracy: 0.7423 - val_loss: 0.5621 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5713 - accuracy: 0.7423 - val_loss: 0.5629 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5725 - accuracy: 0.7423 - val_loss: 0.5684 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5752 - accuracy: 0.7423 - val_loss: 0.5679 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5748 - accuracy: 0.7423 - val_loss: 0.5631 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5719 - accuracy: 0.7423 - val_loss: 0.5640 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5722 - accuracy: 0.7423 - val_loss: 0.5617 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5712 - accuracy: 0.7423 - val_loss: 0.5625 - val_accuracy: 0.7500
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5717 - accuracy: 0.7423 - val_loss: 0.5635 - val_accuracy: 0.7500
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5716 - accuracy: 0.7423 - val_loss: 0.5643 - val_accuracy: 0.7500
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5725 - accuracy: 0.7423 - val_loss: 0.5648 - val_accuracy: 0.7500
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5722 - accuracy: 0.7423 - val_loss: 0.5619 - val_accuracy: 0.7500
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5707 - accuracy: 0.7423 - val_loss: 0.5612 - val_accuracy: 0.7500
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5712 - accuracy: 0.7423 - val_loss: 0.5612 - val_accuracy: 0.7500
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5713 - accuracy: 0.7423 - val_loss: 0.5613 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5706 - accuracy: 0.7423 - val_loss: 0.5610 - val_accuracy: 0.7500
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5710 - accuracy: 0.7423 - val_loss: 0.5613 - val_accuracy: 0.7500
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5714 - accuracy: 0.7423 - val_loss: 0.5610 - val_accuracy: 0.7500
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5712 - accuracy: 0.7423 - val_loss: 0.5610 - val_accuracy: 0.7500
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5706 - accuracy: 0.7423 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5705 - accuracy: 0.7423 - val_loss: 0.5652 - val_accuracy: 0.7500
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5732 - accuracy: 0.7423 - val_loss: 0.5656 - val_accuracy: 0.7500
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5730 - accuracy: 0.7423 - val_loss: 0.5620 - val_accuracy: 0.7500
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5709 - accuracy: 0.7423 - val_loss: 0.5609 - val_accuracy: 0.7500
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5707 - accuracy: 0.7423 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5708 - accuracy: 0.7423 - val_loss: 0.5625 - val_accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5708 - accuracy: 0.7423 - val_loss: 0.5633 - val_accuracy: 0.7500
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5712 - accuracy: 0.7423 - val_loss: 0.5611 - val_accuracy: 0.7500
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5703 - accuracy: 0.7423 - val_loss: 0.5620 - val_accuracy: 0.7500
# Epoch 1/50
# 7/7 [==============================] - 1s 23ms/step - loss: 0.8004 - accuracy: 0.2577 - val_loss: 0.7539 - val_accuracy: 0.2500
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7281 - accuracy: 0.3505 - val_loss: 0.6984 - val_accuracy: 0.3750
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6878 - accuracy: 0.5412 - val_loss: 0.6639 - val_accuracy: 0.6250
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6592 - accuracy: 0.6959 - val_loss: 0.6446 - val_accuracy: 0.7292
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6443 - accuracy: 0.7371 - val_loss: 0.6317 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6302 - accuracy: 0.7423 - val_loss: 0.6170 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6161 - accuracy: 0.7423 - val_loss: 0.6013 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6010 - accuracy: 0.7423 - val_loss: 0.5876 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5876 - accuracy: 0.7423 - val_loss: 0.5789 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5731 - accuracy: 0.7423 - val_loss: 0.5687 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5558 - accuracy: 0.7423 - val_loss: 0.5524 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5364 - accuracy: 0.7423 - val_loss: 0.5345 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5177 - accuracy: 0.7423 - val_loss: 0.5186 - val_accuracy: 0.7292
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5013 - accuracy: 0.7680 - val_loss: 0.5050 - val_accuracy: 0.7292
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4868 - accuracy: 0.7680 - val_loss: 0.4972 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4750 - accuracy: 0.7629 - val_loss: 0.4860 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4637 - accuracy: 0.7732 - val_loss: 0.4766 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4542 - accuracy: 0.7629 - val_loss: 0.4696 - val_accuracy: 0.7708
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4453 - accuracy: 0.7526 - val_loss: 0.4627 - val_accuracy: 0.7917
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4384 - accuracy: 0.7577 - val_loss: 0.4596 - val_accuracy: 0.7917
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4328 - accuracy: 0.7577 - val_loss: 0.4590 - val_accuracy: 0.7708
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4301 - accuracy: 0.7732 - val_loss: 0.4629 - val_accuracy: 0.7292
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4247 - accuracy: 0.7835 - val_loss: 0.4608 - val_accuracy: 0.7917
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4221 - accuracy: 0.7887 - val_loss: 0.4592 - val_accuracy: 0.8125
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4273 - accuracy: 0.7680 - val_loss: 0.4556 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.7732 - val_loss: 0.4541 - val_accuracy: 0.8125
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4128 - accuracy: 0.7887 - val_loss: 0.4520 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4078 - accuracy: 0.7938 - val_loss: 0.4491 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4072 - accuracy: 0.7938 - val_loss: 0.4439 - val_accuracy: 0.8125
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4041 - accuracy: 0.7938 - val_loss: 0.4422 - val_accuracy: 0.8125
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4026 - accuracy: 0.7938 - val_loss: 0.4426 - val_accuracy: 0.7917
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4010 - accuracy: 0.7990 - val_loss: 0.4453 - val_accuracy: 0.7292
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4011 - accuracy: 0.8093 - val_loss: 0.4374 - val_accuracy: 0.7917
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3952 - accuracy: 0.7990 - val_loss: 0.4440 - val_accuracy: 0.7708
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3957 - accuracy: 0.7990 - val_loss: 0.4401 - val_accuracy: 0.7708
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3910 - accuracy: 0.8041 - val_loss: 0.4403 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3875 - accuracy: 0.7990 - val_loss: 0.4374 - val_accuracy: 0.7917
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3864 - accuracy: 0.8041 - val_loss: 0.4342 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3888 - accuracy: 0.7990 - val_loss: 0.4292 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3854 - accuracy: 0.8144 - val_loss: 0.4234 - val_accuracy: 0.7708
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3841 - accuracy: 0.8196 - val_loss: 0.4205 - val_accuracy: 0.7708
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3821 - accuracy: 0.8299 - val_loss: 0.4193 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3816 - accuracy: 0.8247 - val_loss: 0.4185 - val_accuracy: 0.7917
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3805 - accuracy: 0.8247 - val_loss: 0.4182 - val_accuracy: 0.7917
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3745 - accuracy: 0.8299 - val_loss: 0.4181 - val_accuracy: 0.7708
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3744 - accuracy: 0.8247 - val_loss: 0.4209 - val_accuracy: 0.7708
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3758 - accuracy: 0.8247 - val_loss: 0.4267 - val_accuracy: 0.7708
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3727 - accuracy: 0.8402 - val_loss: 0.4303 - val_accuracy: 0.7708
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3742 - accuracy: 0.8351 - val_loss: 0.4323 - val_accuracy: 0.7708
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3724 - accuracy: 0.8196 - val_loss: 0.4331 - val_accuracy: 0.8125

# %% [markdown]
# Graficar la pérdida de entrenamiento y validación

# %%
#variacion 1
plt.plot(history_var1.history['loss'], label='Perdida')
plt.plot(history_var1.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 1")
plt.show()

#variacion 2
plt.plot(history_var2.history['loss'], label='Perdida')
plt.plot(history_var2.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 2")
plt.show()

# %% [markdown]
# Hacer predicciones en el set de prueba

# %%
y_true = []
y_pred = []
for x, y in test_ds:
    y_true.extend(list(y.numpy()))


# varicacion 1
y_pred_var1 = []
for x, y in test_ds:
    y_pred_var1.extend(list(model_var1.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var1 = [1 if pred >= 0.5 else 0 for pred in y_pred_var1]


# varicacion 2
y_pred_var2 = []
for x, y in test_ds:
    y_pred_var2.extend(list(model_var2.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var2 = [1 if pred >= 0.5 else 0 for pred in y_pred_var2]
# Out:
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 88ms/step

# %% [markdown]
# Calcular las métricas

# %%
#base

from sklearn.metrics import classification_report, confusion_matrix
#variacion 1
print("Variacion 1")
print(classification_report(y_true, y_pred_bin_var1, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var1))
# Out:
# Variacion 1
#                precision    recall  f1-score   support
#
# No enfermedad       0.66      1.00      0.79        40
#    Enfermedad       0.00      0.00      0.00        21
#
#      accuracy                           0.66        61
#     macro avg       0.33      0.50      0.40        61
#  weighted avg       0.43      0.66      0.52        61
#
# Matriz de confusión:
#  [[40  0]
#  [21  0]]
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#variacion 2
print("Variacion 2")
print(classification_report(y_true, y_pred_bin_var2, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var2))
# Out:
# Variacion 2
#                precision    recall  f1-score   support
#
# No enfermedad       0.70      0.80      0.74        40
#    Enfermedad       0.47      0.33      0.39        21
#
#      accuracy                           0.64        61
#     macro avg       0.58      0.57      0.57        61
#  weighted avg       0.62      0.64      0.62        61
#
# Matriz de confusión:
#  [[32  8]
#  [14  7]]
