# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 13-14: redes neuronales para clasificación
#
# - Redes densas
# - Redes para clasificación
# - Procesamiento de datos continuos y categóricos
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy, pandas, keras, tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# Descripción de las variables:
#
# https://archive.ics.uci.edu/dataset/45/heart+disease

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Definimos listas para las variables categóricas enteras, categóricas string y numéricas.

# %%
subset_feats = ['age', 'trestbps', 'chol', 'sex', 'cp']
df = df[subset_feats+['target']]

# %%
df.head()
# Out:
#    age  trestbps  chol  sex  cp  target
# 0   63       145   233    1   1       0
# 1   67       160   286    1   4       1
# 2   67       120   229    1   4       0
# 3   37       130   250    1   3       0
# 4   41       130   204    0   2       0

# %% [markdown]
# Separamos los datos en entrenamiento, validación y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#      age  trestbps  chol  sex  cp  target
# 69    35       138   183    0   4       0
# 300   65       135   254    1   4       1
# 220   59       134   204    1   1       0
# 134   42       120   240    1   3       0
# 7     57       120   354    0   4       0

# %%
train.shape
# Out:
# (242, 6)

# %%
test = df.drop(train.index)
test.head()
# Out:
#     age  trestbps  chol  sex  cp  target
# 0    63       145   233    1   1       0
# 2    67       120   229    1   4       0
# 4    41       130   204    0   2       0
# 8    63       130   254    1   4       1
# 13   44       120   263    1   2       0

# %%
val = train.sample(frac=0.2, random_state=100)

# %%
val.shape
# Out:
# (48, 6)

# %%
train = train.drop(val.index)

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (194, 6)
# (48, 6)
# (61, 6)

# %% [markdown]
# Calculamos estadísticas de cada variable numérica

# %%
train.describe()
# Out:
#               age    trestbps        chol         sex          cp      target
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    54.953608  132.876289  249.974227    0.664948    3.097938    0.257732
# std      8.754150   17.952879   52.803226    0.473230    1.030969    0.438517
# min     34.000000   94.000000  126.000000    0.000000    0.000000    0.000000
# 25%     49.000000  120.000000  215.750000    0.000000    2.000000    0.000000
# 50%     56.000000  130.000000  243.000000    1.000000    3.000000    0.000000
# 75%     61.000000  143.500000  281.000000    1.000000    4.000000    1.000000
# max     77.000000  192.000000  564.000000    1.000000    4.000000    1.000000

# %% [markdown]
# Función para convertir de dataframe (pandas) a dataset (tensorflow), separando características y etiquetas

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

# %%
train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %% [markdown]
# Ejemplo de cómo queda el tf.dataset

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=67>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=100>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=299>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=4>}
# Target: tf.Tensor(1, shape=(), dtype=int64)

# %% [markdown]
# Separamos los datos de entrenamiento, validación y prueba en lotes

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Función para codificar variables numéricas (Keras docs)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

# %% [markdown]
# Función para codificar variables categóricas (Keras docs)

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# Creamos una lista de inputs para el modelo, de acuerdo con cada tipo de variable

# %%
inputs = {
    'age': keras.Input(shape=(1,), name='age'),
    'trestbps': keras.Input(shape=(1,), name='trestbps'),
    'chol': keras.Input(shape=(1,), name='chol'),
    'sex': keras.Input(shape=(1,), name='sex', dtype='int64'),
    'cp': keras.Input(shape=(1,), name='cp', dtype='int64')
}

# %%
for i in inputs:
   print(i)
# Out:
# age
# trestbps
# chol
# sex
# cp

# %% [markdown]
# Creamos una lista de variables codificadas/normalizadas de acuerdo con su tipo, empleando las funciones de codificación/normalización

# %%
feats_encoded = [
    encode_numerical_feature(inputs['age'], 'age', train_ds),
    encode_numerical_feature(inputs['trestbps'], 'trestbps', train_ds),
    encode_numerical_feature(inputs['chol'], 'chol', train_ds),
    encode_categorical_feature(inputs['sex'], 'sex', train_ds, False),  # 'sex' es categórica (entero)
    encode_categorical_feature(inputs['cp'], 'cp', train_ds, False)  # 'cp' es categórica (entero)
]

# %%
len_feats = len(feats_encoded)
len_feats
# Out:
# 5

# %%
for i in feats_encoded:
  print(i)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_24/truediv:0', description="created by layer 'normalization_24'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_25/truediv:0', description="created by layer 'normalization_25'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_26/truediv:0', description="created by layer 'normalization_26'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='integer_lookup_16/bincount/DenseBincount:0', description="created by layer 'integer_lookup_16'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 6), dtype=tf.float32, name=None), name='integer_lookup_17/bincount/DenseBincount:0', description="created by layer 'integer_lookup_17'")

# %% [markdown]
# Creamos una capa concatenando todas las variables codificadas

# %%
all_feats = keras.layers.concatenate(feats_encoded)

# %%
type(all_feats)
# Out:
# keras.src.engine.keras_tensor.KerasTensor

# %% [markdown]
# Agregamos una capa densa con 32 neuronas y función de activación relu

# %%
#variacion 1
model_layers_var1 = keras.layers.Dense(32, activation='tanh')(all_feats)
model_layers_var1 = keras.layers.Dense(32, activation='tanh')(model_layers_var1)

#variacion 2
model_layers_var2 = keras.layers.Dense(32, activation='relu')(all_feats)
model_layers_var2 = keras.layers.Dense(32, activation='relu')(model_layers_var2)
model_layers_var2 = keras.layers.Dense(32, activation='relu')(model_layers_var2)

# %% [markdown]
# Agregamos la capa de salida con 1 neurona (probabilidad de sufrir la enfermedad cardiada) y función de activación sigmoide

# %%
#variacion 1
model_layers_var1 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var1)

#variacion 2
model_layers_var2 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var2)

# %% [markdown]
# Creamos el modelo con las capas ya creadas y las variables de entrada

# %%
#variacion 1
model_var1= keras.Model(inputs, model_layers_var1)

#Variacion 2
model_var2= keras.Model(inputs, model_layers_var2)

# %% [markdown]
# Compilamos el modelo, definiendo optimizador, función de pérdida y métricas adicionales a capturar

# %%
#variacion 1
model_var1.compile(optimizer=keras.optimizers.RMSprop(learning_rate=0.003), loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 2
model_var2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Aseguramos que Keras use TensorFlow como backend, para asegurar que el modelo pueda usar strings como entradas

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# Entrenamos el modelo con los datos en el formato tf.Dataset

# %%
#variacion 1
history_var1=model_var1.fit(train_ds, epochs=50, validation_data=val_ds)
#Variacion 2
history_var2=model_var2.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 1s 20ms/step - loss: 0.5933 - accuracy: 0.6649 - val_loss: 0.5552 - val_accuracy: 0.7083
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5147 - accuracy: 0.7371 - val_loss: 0.4982 - val_accuracy: 0.7708
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4776 - accuracy: 0.7577 - val_loss: 0.4753 - val_accuracy: 0.7917
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4667 - accuracy: 0.7784 - val_loss: 0.4575 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4645 - accuracy: 0.7732 - val_loss: 0.4527 - val_accuracy: 0.7292
# Epoch 6/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4625 - accuracy: 0.7732 - val_loss: 0.4349 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4481 - accuracy: 0.7732 - val_loss: 0.4304 - val_accuracy: 0.7708
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4484 - accuracy: 0.7680 - val_loss: 0.4525 - val_accuracy: 0.7708
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4450 - accuracy: 0.7835 - val_loss: 0.4257 - val_accuracy: 0.7708
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4454 - accuracy: 0.7887 - val_loss: 0.4362 - val_accuracy: 0.7708
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4401 - accuracy: 0.7938 - val_loss: 0.4321 - val_accuracy: 0.7708
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4450 - accuracy: 0.7938 - val_loss: 0.4438 - val_accuracy: 0.7708
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4444 - accuracy: 0.7938 - val_loss: 0.4249 - val_accuracy: 0.7917
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4372 - accuracy: 0.7835 - val_loss: 0.4265 - val_accuracy: 0.8125
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4376 - accuracy: 0.7680 - val_loss: 0.4066 - val_accuracy: 0.7708
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4428 - accuracy: 0.7784 - val_loss: 0.4192 - val_accuracy: 0.7917
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4378 - accuracy: 0.7732 - val_loss: 0.4110 - val_accuracy: 0.7708
# Epoch 18/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4385 - accuracy: 0.7784 - val_loss: 0.4446 - val_accuracy: 0.7292
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4323 - accuracy: 0.7784 - val_loss: 0.4153 - val_accuracy: 0.7292
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4352 - accuracy: 0.7680 - val_loss: 0.4216 - val_accuracy: 0.7292
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4377 - accuracy: 0.7784 - val_loss: 0.4386 - val_accuracy: 0.7917
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4279 - accuracy: 0.8093 - val_loss: 0.4399 - val_accuracy: 0.7917
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4301 - accuracy: 0.7887 - val_loss: 0.4131 - val_accuracy: 0.7917
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4308 - accuracy: 0.7732 - val_loss: 0.4215 - val_accuracy: 0.7708
# Epoch 25/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4304 - accuracy: 0.7938 - val_loss: 0.4232 - val_accuracy: 0.8125
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4304 - accuracy: 0.7784 - val_loss: 0.4040 - val_accuracy: 0.7708
# Epoch 27/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4237 - accuracy: 0.7990 - val_loss: 0.4064 - val_accuracy: 0.7917
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4231 - accuracy: 0.7938 - val_loss: 0.4128 - val_accuracy: 0.7708
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4215 - accuracy: 0.7887 - val_loss: 0.4413 - val_accuracy: 0.7500
# Epoch 30/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4190 - accuracy: 0.7990 - val_loss: 0.4521 - val_accuracy: 0.7708
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4239 - accuracy: 0.7938 - val_loss: 0.4517 - val_accuracy: 0.7292
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4207 - accuracy: 0.8041 - val_loss: 0.4153 - val_accuracy: 0.7708
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4145 - accuracy: 0.7990 - val_loss: 0.4437 - val_accuracy: 0.7917
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4197 - accuracy: 0.7938 - val_loss: 0.4515 - val_accuracy: 0.7708
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4185 - accuracy: 0.8144 - val_loss: 0.4314 - val_accuracy: 0.7500
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8144 - val_loss: 0.4501 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4136 - accuracy: 0.7938 - val_loss: 0.4278 - val_accuracy: 0.8125
# Epoch 38/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4168 - accuracy: 0.8196 - val_loss: 0.4203 - val_accuracy: 0.7708
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4115 - accuracy: 0.7835 - val_loss: 0.4238 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4113 - accuracy: 0.8041 - val_loss: 0.4147 - val_accuracy: 0.8125
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4132 - accuracy: 0.7835 - val_loss: 0.4069 - val_accuracy: 0.7708
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.8144 - val_loss: 0.4322 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4131 - accuracy: 0.7990 - val_loss: 0.4206 - val_accuracy: 0.7500
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4103 - accuracy: 0.8144 - val_loss: 0.4196 - val_accuracy: 0.7708
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4024 - accuracy: 0.8144 - val_loss: 0.4329 - val_accuracy: 0.8125
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.7990 - val_loss: 0.4295 - val_accuracy: 0.8333
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4078 - accuracy: 0.7938 - val_loss: 0.4085 - val_accuracy: 0.7917
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3991 - accuracy: 0.7990 - val_loss: 0.4176 - val_accuracy: 0.8333
# Epoch 49/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4030 - accuracy: 0.8093 - val_loss: 0.4134 - val_accuracy: 0.8125
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4001 - accuracy: 0.8247 - val_loss: 0.4532 - val_accuracy: 0.7917
# Epoch 1/50
# 7/7 [==============================] - 1s 21ms/step - loss: 0.6970 - accuracy: 0.5052 - val_loss: 0.6692 - val_accuracy: 0.6875
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6495 - accuracy: 0.7165 - val_loss: 0.6281 - val_accuracy: 0.7917
# Epoch 3/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6123 - accuracy: 0.7371 - val_loss: 0.5908 - val_accuracy: 0.7708
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5825 - accuracy: 0.7680 - val_loss: 0.5562 - val_accuracy: 0.7292
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5556 - accuracy: 0.7423 - val_loss: 0.5289 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5349 - accuracy: 0.7423 - val_loss: 0.5104 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5205 - accuracy: 0.7423 - val_loss: 0.4960 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5084 - accuracy: 0.7526 - val_loss: 0.4808 - val_accuracy: 0.7292
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4925 - accuracy: 0.7680 - val_loss: 0.4705 - val_accuracy: 0.7292
# Epoch 10/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4793 - accuracy: 0.7474 - val_loss: 0.4662 - val_accuracy: 0.7708
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4716 - accuracy: 0.7629 - val_loss: 0.4591 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4633 - accuracy: 0.7887 - val_loss: 0.4556 - val_accuracy: 0.7292
# Epoch 13/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4586 - accuracy: 0.7835 - val_loss: 0.4523 - val_accuracy: 0.7708
# Epoch 14/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4525 - accuracy: 0.7835 - val_loss: 0.4450 - val_accuracy: 0.7708
# Epoch 15/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4466 - accuracy: 0.7835 - val_loss: 0.4383 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4427 - accuracy: 0.7887 - val_loss: 0.4339 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4409 - accuracy: 0.7835 - val_loss: 0.4304 - val_accuracy: 0.7083
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4402 - accuracy: 0.7732 - val_loss: 0.4287 - val_accuracy: 0.7708
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4380 - accuracy: 0.7732 - val_loss: 0.4288 - val_accuracy: 0.7917
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4350 - accuracy: 0.7784 - val_loss: 0.4289 - val_accuracy: 0.7917
# Epoch 21/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4308 - accuracy: 0.7887 - val_loss: 0.4282 - val_accuracy: 0.7708
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4281 - accuracy: 0.7938 - val_loss: 0.4288 - val_accuracy: 0.7917
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4265 - accuracy: 0.8041 - val_loss: 0.4306 - val_accuracy: 0.7708
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4234 - accuracy: 0.8041 - val_loss: 0.4251 - val_accuracy: 0.7708
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4216 - accuracy: 0.7938 - val_loss: 0.4224 - val_accuracy: 0.7708
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4206 - accuracy: 0.7938 - val_loss: 0.4238 - val_accuracy: 0.7292
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4200 - accuracy: 0.7835 - val_loss: 0.4255 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4154 - accuracy: 0.8196 - val_loss: 0.4266 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4135 - accuracy: 0.7990 - val_loss: 0.4261 - val_accuracy: 0.7500
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4108 - accuracy: 0.8093 - val_loss: 0.4261 - val_accuracy: 0.7708
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.8041 - val_loss: 0.4259 - val_accuracy: 0.7708
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4088 - accuracy: 0.8041 - val_loss: 0.4277 - val_accuracy: 0.7708
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4045 - accuracy: 0.7990 - val_loss: 0.4273 - val_accuracy: 0.7708
# Epoch 34/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4034 - accuracy: 0.8041 - val_loss: 0.4290 - val_accuracy: 0.7917
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4029 - accuracy: 0.7887 - val_loss: 0.4254 - val_accuracy: 0.7708
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3990 - accuracy: 0.7990 - val_loss: 0.4206 - val_accuracy: 0.7708
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3984 - accuracy: 0.7887 - val_loss: 0.4173 - val_accuracy: 0.7708
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3980 - accuracy: 0.7938 - val_loss: 0.4165 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3962 - accuracy: 0.7990 - val_loss: 0.4172 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3913 - accuracy: 0.7938 - val_loss: 0.4254 - val_accuracy: 0.8333
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3951 - accuracy: 0.8144 - val_loss: 0.4315 - val_accuracy: 0.8333
# Epoch 42/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3918 - accuracy: 0.8144 - val_loss: 0.4257 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3882 - accuracy: 0.7990 - val_loss: 0.4233 - val_accuracy: 0.7917
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3878 - accuracy: 0.7938 - val_loss: 0.4231 - val_accuracy: 0.7917
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3872 - accuracy: 0.8144 - val_loss: 0.4267 - val_accuracy: 0.7917
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3868 - accuracy: 0.8144 - val_loss: 0.4268 - val_accuracy: 0.8333
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3862 - accuracy: 0.8144 - val_loss: 0.4235 - val_accuracy: 0.8333
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3846 - accuracy: 0.8144 - val_loss: 0.4177 - val_accuracy: 0.8333
# Epoch 49/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3811 - accuracy: 0.8144 - val_loss: 0.4122 - val_accuracy: 0.8125
# Epoch 50/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3803 - accuracy: 0.8041 - val_loss: 0.4126 - val_accuracy: 0.7917

# %% [markdown]
# Graficar la pérdida de entrenamiento y validación

# %%
#variacion 1
plt.plot(history_var1.history['loss'], label='Perdida')
plt.plot(history_var1.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Base")
plt.show()

#variacion 2
plt.plot(history_var2.history['loss'], label='Perdida')
plt.plot(history_var2.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Base")
plt.show()

# %% [markdown]
# Hacer predicciones en el set de prueba

# %%
y_true = []
y_pred = []
for x, y in test_ds:
    y_true.extend(list(y.numpy()))


# varicacion 1
y_pred_var1 = []
for x, y in test_ds:
    y_pred_var1.extend(list(model_var1.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var1 = [1 if pred >= 0.5 else 0 for pred in y_pred_var1]


# varicacion 2
y_pred_var2 = []
for x, y in test_ds:
    y_pred_var2.extend(list(model_var2.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var2 = [1 if pred >= 0.5 else 0 for pred in y_pred_var2]
# Out:
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step

# %% [markdown]
# Calcular las métricas

# %%
#base

from sklearn.metrics import classification_report, confusion_matrix
#variacion 1
print("Variacion 1")
print(classification_report(y_true, y_pred_bin_var1, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var1))
# Out:
# Variacion 1
#                precision    recall  f1-score   support
#
# No enfermedad       0.66      0.68      0.67        40
#    Enfermedad       0.35      0.33      0.34        21
#
#      accuracy                           0.56        61
#     macro avg       0.50      0.50      0.50        61
#  weighted avg       0.55      0.56      0.55        61
#
# Matriz de confusión:
#  [[27 13]
#  [14  7]]

# %%
#variacion 2
print("Variacion 2")
print(classification_report(y_true, y_pred_bin_var2, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var2))
# Out:
# Variacion 2
#                precision    recall  f1-score   support
#
# No enfermedad       0.70      0.82      0.76        40
#    Enfermedad       0.50      0.33      0.40        21
#
#      accuracy                           0.66        61
#     macro avg       0.60      0.58      0.58        61
#  weighted avg       0.63      0.66      0.64        61
#
# Matriz de confusión:
#  [[33  7]
#  [14  7]]
