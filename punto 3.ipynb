# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 13-14: redes neuronales para clasificación
#
# - Redes densas
# - Redes para clasificación
# - Procesamiento de datos continuos y categóricos
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy, pandas, keras, tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# Descripción de las variables:
#
# https://archive.ics.uci.edu/dataset/45/heart+disease

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Definimos listas para las variables categóricas enteras, categóricas string y numéricas.

# %%
subset_feats = ['age', 'trestbps', 'chol', 'sex', 'cp']
df = df[subset_feats+['target']]

# %%
df.head()
# Out:
#    age  trestbps  chol  sex  cp  target
# 0   63       145   233    1   1       0
# 1   67       160   286    1   4       1
# 2   67       120   229    1   4       0
# 3   37       130   250    1   3       0
# 4   41       130   204    0   2       0

# %% [markdown]
# Separamos los datos en entrenamiento, validación y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#      age  trestbps  chol  sex  cp  target
# 69    35       138   183    0   4       0
# 300   65       135   254    1   4       1
# 220   59       134   204    1   1       0
# 134   42       120   240    1   3       0
# 7     57       120   354    0   4       0

# %%
train.shape
# Out:
# (242, 6)

# %%
test = df.drop(train.index)
test.head()
# Out:
#     age  trestbps  chol  sex  cp  target
# 0    63       145   233    1   1       0
# 2    67       120   229    1   4       0
# 4    41       130   204    0   2       0
# 8    63       130   254    1   4       1
# 13   44       120   263    1   2       0

# %%
val = train.sample(frac=0.2, random_state=100)

# %%
val.shape
# Out:
# (48, 6)

# %%
train = train.drop(val.index)

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (194, 6)
# (48, 6)
# (61, 6)

# %% [markdown]
# Calculamos estadísticas de cada variable numérica

# %%
train.describe()
# Out:
#               age    trestbps        chol         sex          cp      target
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    54.953608  132.876289  249.974227    0.664948    3.097938    0.257732
# std      8.754150   17.952879   52.803226    0.473230    1.030969    0.438517
# min     34.000000   94.000000  126.000000    0.000000    0.000000    0.000000
# 25%     49.000000  120.000000  215.750000    0.000000    2.000000    0.000000
# 50%     56.000000  130.000000  243.000000    1.000000    3.000000    0.000000
# 75%     61.000000  143.500000  281.000000    1.000000    4.000000    1.000000
# max     77.000000  192.000000  564.000000    1.000000    4.000000    1.000000

# %% [markdown]
# Función para convertir de dataframe (pandas) a dataset (tensorflow), separando características y etiquetas

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

# %%
train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %% [markdown]
# Ejemplo de cómo queda el tf.dataset

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=55>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=135>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=250>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=2>}
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# Separamos los datos de entrenamiento, validación y prueba en lotes

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Función para codificar variables numéricas (Keras docs)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

# %% [markdown]
# Función para codificar variables categóricas (Keras docs)

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# Creamos una lista de inputs para el modelo, de acuerdo con cada tipo de variable

# %%
inputs = {
    'age': keras.Input(shape=(1,), name='age'),
    'trestbps': keras.Input(shape=(1,), name='trestbps'),
    'chol': keras.Input(shape=(1,), name='chol'),
    'sex': keras.Input(shape=(1,), name='sex', dtype='int64'),
    'cp': keras.Input(shape=(1,), name='cp', dtype='int64')
}

# %%
for i in inputs:
   print(i)
# Out:
# age
# trestbps
# chol
# sex
# cp

# %% [markdown]
# Creamos una lista de variables codificadas/normalizadas de acuerdo con su tipo, empleando las funciones de codificación/normalización

# %%
feats_encoded = [
    encode_numerical_feature(inputs['age'], 'age', train_ds),
    encode_numerical_feature(inputs['trestbps'], 'trestbps', train_ds),
    encode_numerical_feature(inputs['chol'], 'chol', train_ds),
    encode_categorical_feature(inputs['sex'], 'sex', train_ds, False),  # 'sex' es categórica (entero)
    encode_categorical_feature(inputs['cp'], 'cp', train_ds, False)  # 'cp' es categórica (entero)
]

# %%
len_feats = len(feats_encoded)
len_feats
# Out:
# 5

# %%
for i in feats_encoded:
  print(i)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_12/truediv:0', description="created by layer 'normalization_12'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_13/truediv:0', description="created by layer 'normalization_13'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_14/truediv:0', description="created by layer 'normalization_14'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='integer_lookup_8/bincount/DenseBincount:0', description="created by layer 'integer_lookup_8'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 6), dtype=tf.float32, name=None), name='integer_lookup_9/bincount/DenseBincount:0', description="created by layer 'integer_lookup_9'")

# %% [markdown]
# Creamos una capa concatenando todas las variables codificadas

# %%
all_feats = keras.layers.concatenate(feats_encoded)

# %%
type(all_feats)
# Out:
# keras.src.engine.keras_tensor.KerasTensor

# %% [markdown]
# Agregamos una capa densa con 32 neuronas y función de activación relu

# %%
model_layers = keras.layers.Dense(32, activation='relu')(all_feats)

# %% [markdown]
# Agregamos la capa de salida con 1 neurona (probabilidad de sufrir la enfermedad cardiada) y función de activación sigmoide

# %%
model_layers = keras.layers.Dense(1, activation='sigmoid')(model_layers)

# %% [markdown]
# Creamos el modelo con las capas ya creadas y las variables de entrada

# %%
#Base
model = keras.Model(inputs, model_layers)

#variacion 1
model_var1= keras.Model(inputs, model_layers)

#Variacion 2
model_var2= keras.Model(inputs, model_layers)

# %% [markdown]
# Compilamos el modelo, definiendo optimizador, función de pérdida y métricas adicionales a capturar

# %%
#Base
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#variacion 1
model_var1.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 2
model_var2.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Aseguramos que Keras use TensorFlow como backend, para asegurar que el modelo pueda usar strings como entradas

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# Entrenamos el modelo con los datos en el formato tf.Dataset

# %%
#Base 
history=model.fit(train_ds, epochs=50, validation_data=val_ds)

#variacion 1
history_var1=model_var1.fit(train_ds, epochs=50, validation_data=val_ds)
#Variacion 2
history_var2=model_var2.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 1s 23ms/step - loss: 0.6599 - accuracy: 0.6340 - val_loss: 0.6355 - val_accuracy: 0.7500
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6415 - accuracy: 0.7165 - val_loss: 0.6202 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6265 - accuracy: 0.7474 - val_loss: 0.6072 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6151 - accuracy: 0.7423 - val_loss: 0.5968 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6048 - accuracy: 0.7423 - val_loss: 0.5871 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5951 - accuracy: 0.7423 - val_loss: 0.5780 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5861 - accuracy: 0.7423 - val_loss: 0.5695 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5770 - accuracy: 0.7423 - val_loss: 0.5616 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5694 - accuracy: 0.7423 - val_loss: 0.5549 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5626 - accuracy: 0.7423 - val_loss: 0.5483 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5556 - accuracy: 0.7423 - val_loss: 0.5428 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5497 - accuracy: 0.7423 - val_loss: 0.5372 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5439 - accuracy: 0.7423 - val_loss: 0.5319 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5389 - accuracy: 0.7423 - val_loss: 0.5272 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5342 - accuracy: 0.7423 - val_loss: 0.5240 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5304 - accuracy: 0.7423 - val_loss: 0.5198 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5263 - accuracy: 0.7423 - val_loss: 0.5156 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5225 - accuracy: 0.7423 - val_loss: 0.5117 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5186 - accuracy: 0.7423 - val_loss: 0.5080 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5145 - accuracy: 0.7423 - val_loss: 0.5044 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5104 - accuracy: 0.7423 - val_loss: 0.5018 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5086 - accuracy: 0.7423 - val_loss: 0.4998 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5049 - accuracy: 0.7423 - val_loss: 0.4975 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7423 - val_loss: 0.4950 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4993 - accuracy: 0.7423 - val_loss: 0.4925 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4967 - accuracy: 0.7423 - val_loss: 0.4894 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4940 - accuracy: 0.7474 - val_loss: 0.4868 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4914 - accuracy: 0.7526 - val_loss: 0.4840 - val_accuracy: 0.7292
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4887 - accuracy: 0.7474 - val_loss: 0.4814 - val_accuracy: 0.7292
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4864 - accuracy: 0.7474 - val_loss: 0.4788 - val_accuracy: 0.7292
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4835 - accuracy: 0.7474 - val_loss: 0.4759 - val_accuracy: 0.7292
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4814 - accuracy: 0.7474 - val_loss: 0.4740 - val_accuracy: 0.7708
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4792 - accuracy: 0.7423 - val_loss: 0.4723 - val_accuracy: 0.7708
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4768 - accuracy: 0.7474 - val_loss: 0.4706 - val_accuracy: 0.7708
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4744 - accuracy: 0.7577 - val_loss: 0.4685 - val_accuracy: 0.7708
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4721 - accuracy: 0.7526 - val_loss: 0.4661 - val_accuracy: 0.7708
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4698 - accuracy: 0.7474 - val_loss: 0.4641 - val_accuracy: 0.7708
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4673 - accuracy: 0.7474 - val_loss: 0.4625 - val_accuracy: 0.7500
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4658 - accuracy: 0.7474 - val_loss: 0.4622 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4649 - accuracy: 0.7526 - val_loss: 0.4616 - val_accuracy: 0.7917
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4635 - accuracy: 0.7526 - val_loss: 0.4605 - val_accuracy: 0.7917
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4618 - accuracy: 0.7526 - val_loss: 0.4596 - val_accuracy: 0.8125
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4602 - accuracy: 0.7474 - val_loss: 0.4585 - val_accuracy: 0.7917
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4576 - accuracy: 0.7526 - val_loss: 0.4571 - val_accuracy: 0.7917
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4559 - accuracy: 0.7526 - val_loss: 0.4554 - val_accuracy: 0.7917
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4540 - accuracy: 0.7474 - val_loss: 0.4538 - val_accuracy: 0.7917
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4523 - accuracy: 0.7474 - val_loss: 0.4529 - val_accuracy: 0.7917
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4507 - accuracy: 0.7474 - val_loss: 0.4511 - val_accuracy: 0.7917
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4496 - accuracy: 0.7474 - val_loss: 0.4498 - val_accuracy: 0.7917
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4483 - accuracy: 0.7474 - val_loss: 0.4486 - val_accuracy: 0.7917
# Epoch 1/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4476 - accuracy: 0.7474 - val_loss: 0.4482 - val_accuracy: 0.7917
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4471 - accuracy: 0.7474 - val_loss: 0.4484 - val_accuracy: 0.7917
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4466 - accuracy: 0.7526 - val_loss: 0.4480 - val_accuracy: 0.7917
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4464 - accuracy: 0.7526 - val_loss: 0.4478 - val_accuracy: 0.7917
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4460 - accuracy: 0.7526 - val_loss: 0.4474 - val_accuracy: 0.7917
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4455 - accuracy: 0.7526 - val_loss: 0.4471 - val_accuracy: 0.7917
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4451 - accuracy: 0.7526 - val_loss: 0.4466 - val_accuracy: 0.7917
# Epoch 8/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4451 - accuracy: 0.7474 - val_loss: 0.4464 - val_accuracy: 0.7917
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4447 - accuracy: 0.7526 - val_loss: 0.4467 - val_accuracy: 0.7917
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4444 - accuracy: 0.7526 - val_loss: 0.4467 - val_accuracy: 0.7917
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4442 - accuracy: 0.7526 - val_loss: 0.4463 - val_accuracy: 0.7917
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4439 - accuracy: 0.7526 - val_loss: 0.4456 - val_accuracy: 0.7917
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4434 - accuracy: 0.7577 - val_loss: 0.4452 - val_accuracy: 0.7917
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4431 - accuracy: 0.7577 - val_loss: 0.4451 - val_accuracy: 0.7917
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4427 - accuracy: 0.7577 - val_loss: 0.4449 - val_accuracy: 0.7917
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4425 - accuracy: 0.7577 - val_loss: 0.4450 - val_accuracy: 0.7917
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4422 - accuracy: 0.7577 - val_loss: 0.4446 - val_accuracy: 0.7917
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4419 - accuracy: 0.7629 - val_loss: 0.4442 - val_accuracy: 0.7917
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4416 - accuracy: 0.7577 - val_loss: 0.4436 - val_accuracy: 0.7917
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4413 - accuracy: 0.7629 - val_loss: 0.4431 - val_accuracy: 0.7917
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4411 - accuracy: 0.7629 - val_loss: 0.4432 - val_accuracy: 0.7917
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4406 - accuracy: 0.7680 - val_loss: 0.4425 - val_accuracy: 0.7917
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4404 - accuracy: 0.7629 - val_loss: 0.4423 - val_accuracy: 0.7917
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4401 - accuracy: 0.7577 - val_loss: 0.4419 - val_accuracy: 0.7917
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4399 - accuracy: 0.7577 - val_loss: 0.4414 - val_accuracy: 0.7917
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4396 - accuracy: 0.7577 - val_loss: 0.4409 - val_accuracy: 0.7917
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4395 - accuracy: 0.7577 - val_loss: 0.4408 - val_accuracy: 0.7917
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4388 - accuracy: 0.7577 - val_loss: 0.4406 - val_accuracy: 0.7917
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4388 - accuracy: 0.7577 - val_loss: 0.4398 - val_accuracy: 0.7917
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4382 - accuracy: 0.7680 - val_loss: 0.4402 - val_accuracy: 0.7917
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4381 - accuracy: 0.7629 - val_loss: 0.4406 - val_accuracy: 0.7917
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4379 - accuracy: 0.7629 - val_loss: 0.4406 - val_accuracy: 0.7917
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4377 - accuracy: 0.7629 - val_loss: 0.4404 - val_accuracy: 0.7917
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4375 - accuracy: 0.7629 - val_loss: 0.4398 - val_accuracy: 0.7917
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4371 - accuracy: 0.7629 - val_loss: 0.4395 - val_accuracy: 0.7917
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4371 - accuracy: 0.7629 - val_loss: 0.4399 - val_accuracy: 0.7917
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4369 - accuracy: 0.7629 - val_loss: 0.4397 - val_accuracy: 0.7917
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4366 - accuracy: 0.7577 - val_loss: 0.4397 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4363 - accuracy: 0.7577 - val_loss: 0.4399 - val_accuracy: 0.7500
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4361 - accuracy: 0.7577 - val_loss: 0.4394 - val_accuracy: 0.7917
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4361 - accuracy: 0.7577 - val_loss: 0.4390 - val_accuracy: 0.7708
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4363 - accuracy: 0.7577 - val_loss: 0.4390 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4359 - accuracy: 0.7577 - val_loss: 0.4392 - val_accuracy: 0.7708
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4355 - accuracy: 0.7629 - val_loss: 0.4388 - val_accuracy: 0.7500
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4354 - accuracy: 0.7577 - val_loss: 0.4382 - val_accuracy: 0.7500
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4350 - accuracy: 0.7577 - val_loss: 0.4379 - val_accuracy: 0.7708
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4351 - accuracy: 0.7577 - val_loss: 0.4377 - val_accuracy: 0.7708
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4346 - accuracy: 0.7577 - val_loss: 0.4376 - val_accuracy: 0.7708
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4343 - accuracy: 0.7577 - val_loss: 0.4373 - val_accuracy: 0.7708
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4342 - accuracy: 0.7577 - val_loss: 0.4371 - val_accuracy: 0.7708
# Epoch 1/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4355 - accuracy: 0.7577 - val_loss: 0.4362 - val_accuracy: 0.7708
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4330 - accuracy: 0.7577 - val_loss: 0.4353 - val_accuracy: 0.7708
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4314 - accuracy: 0.7629 - val_loss: 0.4348 - val_accuracy: 0.7708
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4304 - accuracy: 0.7680 - val_loss: 0.4340 - val_accuracy: 0.7708
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4286 - accuracy: 0.7732 - val_loss: 0.4352 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4278 - accuracy: 0.7835 - val_loss: 0.4350 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4272 - accuracy: 0.7835 - val_loss: 0.4338 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4264 - accuracy: 0.7887 - val_loss: 0.4330 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4261 - accuracy: 0.7732 - val_loss: 0.4328 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4248 - accuracy: 0.7938 - val_loss: 0.4324 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4242 - accuracy: 0.7938 - val_loss: 0.4318 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4239 - accuracy: 0.7887 - val_loss: 0.4296 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4232 - accuracy: 0.7990 - val_loss: 0.4291 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4222 - accuracy: 0.7938 - val_loss: 0.4284 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.7887 - val_loss: 0.4281 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.7784 - val_loss: 0.4281 - val_accuracy: 0.7708
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4213 - accuracy: 0.7784 - val_loss: 0.4285 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4198 - accuracy: 0.7990 - val_loss: 0.4288 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4193 - accuracy: 0.7938 - val_loss: 0.4281 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4190 - accuracy: 0.7887 - val_loss: 0.4282 - val_accuracy: 0.7708
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4178 - accuracy: 0.7938 - val_loss: 0.4276 - val_accuracy: 0.7708
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4176 - accuracy: 0.7938 - val_loss: 0.4271 - val_accuracy: 0.7708
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4168 - accuracy: 0.8093 - val_loss: 0.4266 - val_accuracy: 0.7708
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4167 - accuracy: 0.8093 - val_loss: 0.4256 - val_accuracy: 0.7708
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4162 - accuracy: 0.7990 - val_loss: 0.4277 - val_accuracy: 0.7708
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4160 - accuracy: 0.8144 - val_loss: 0.4272 - val_accuracy: 0.7708
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4157 - accuracy: 0.8144 - val_loss: 0.4282 - val_accuracy: 0.7917
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4150 - accuracy: 0.8196 - val_loss: 0.4275 - val_accuracy: 0.7708
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4149 - accuracy: 0.8093 - val_loss: 0.4276 - val_accuracy: 0.7917
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4140 - accuracy: 0.8093 - val_loss: 0.4266 - val_accuracy: 0.7708
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4138 - accuracy: 0.8093 - val_loss: 0.4266 - val_accuracy: 0.7708
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4135 - accuracy: 0.8093 - val_loss: 0.4284 - val_accuracy: 0.7708
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4131 - accuracy: 0.8093 - val_loss: 0.4272 - val_accuracy: 0.7917
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4124 - accuracy: 0.8093 - val_loss: 0.4267 - val_accuracy: 0.7917
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4122 - accuracy: 0.8093 - val_loss: 0.4265 - val_accuracy: 0.7917
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4114 - accuracy: 0.8041 - val_loss: 0.4257 - val_accuracy: 0.7917
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4116 - accuracy: 0.7990 - val_loss: 0.4248 - val_accuracy: 0.7917
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4106 - accuracy: 0.8041 - val_loss: 0.4242 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4103 - accuracy: 0.8041 - val_loss: 0.4231 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.8093 - val_loss: 0.4217 - val_accuracy: 0.7917
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4092 - accuracy: 0.8041 - val_loss: 0.4214 - val_accuracy: 0.7917
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4092 - accuracy: 0.8041 - val_loss: 0.4220 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4085 - accuracy: 0.8093 - val_loss: 0.4215 - val_accuracy: 0.7917
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.8093 - val_loss: 0.4213 - val_accuracy: 0.7917
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4079 - accuracy: 0.8093 - val_loss: 0.4219 - val_accuracy: 0.7917
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4077 - accuracy: 0.8093 - val_loss: 0.4218 - val_accuracy: 0.7917
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4068 - accuracy: 0.8093 - val_loss: 0.4210 - val_accuracy: 0.7917
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4063 - accuracy: 0.8041 - val_loss: 0.4227 - val_accuracy: 0.7917
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4059 - accuracy: 0.8093 - val_loss: 0.4245 - val_accuracy: 0.7917
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4047 - accuracy: 0.8041 - val_loss: 0.4233 - val_accuracy: 0.7917

# %% [markdown]
# Graficar la pérdida de entrenamiento y validación

# %%
#Base
plt.plot(history.history['loss'], label='Perdida')
plt.plot(history.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Base")
plt.show()

#variacion 1
plt.plot(history_var1.history['loss'], label='Perdida')
plt.plot(history_var1.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 1")
plt.show()

#variacion 2
plt.plot(history_var2.history['loss'], label='Perdida')
plt.plot(history_var2.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 2")
plt.show()

# %% [markdown]
# Hacer predicciones en el set de prueba

# %%
#base 
y_true = []
y_pred = []
for x, y in test_ds:
    y_true.extend(list(y.numpy()))
    y_pred.extend(list(model.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin = [1 if pred >= 0.5 else 0 for pred in y_pred]

# varicacion 1
y_pred_var1 = []
for x, y in test_ds:
    y_pred_var1.extend(list(model_var1.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var1 = [1 if pred >= 0.5 else 0 for pred in y_pred_var1]


# varicacion 2
y_pred_var2 = []
for x, y in test_ds:
    y_pred_var2.extend(list(model_var2.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var2 = [1 if pred >= 0.5 else 0 for pred in y_pred_var2]
# Out:
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 89ms/step

# %% [markdown]
# Calcular las métricas

# %%
#base

from sklearn.metrics import classification_report, confusion_matrix

#base
# Calcular métricas
print("Base")
print(classification_report(y_true, y_pred_bin, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin))
# Out:
# Base
#                precision    recall  f1-score   support
#
# No enfermedad       0.74      0.85      0.79        40
#    Enfermedad       0.60      0.43      0.50        21
#
#      accuracy                           0.70        61
#     macro avg       0.67      0.64      0.65        61
#  weighted avg       0.69      0.70      0.69        61
#
# Matriz de confusión:
#  [[34  6]
#  [12  9]]

# %%
#variacion 1
print("Variacion 1")
print(classification_report(y_true, y_pred_bin_var1, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var1))
# Out:
# Variacion 1
#                precision    recall  f1-score   support
#
# No enfermedad       0.63      0.72      0.67        40
#    Enfermedad       0.27      0.19      0.22        21
#
#      accuracy                           0.54        61
#     macro avg       0.45      0.46      0.45        61
#  weighted avg       0.51      0.54      0.52        61
#
# Matriz de confusión:
#  [[29 11]
#  [17  4]]

# %%
#variacion 2
print("Variacion 2")
print(classification_report(y_true, y_pred_bin_var2, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var2))
# Out:
# Variacion 2
#                precision    recall  f1-score   support
#
# No enfermedad       0.67      0.78      0.72        40
#    Enfermedad       0.40      0.29      0.33        21
#
#      accuracy                           0.61        61
#     macro avg       0.54      0.53      0.53        61
#  weighted avg       0.58      0.61      0.59        61
#
# Matriz de confusión:
#  [[31  9]
#  [15  6]]
