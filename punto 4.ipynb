# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 13-14: redes neuronales para clasificación
#
# - Redes densas
# - Redes para clasificación
# - Procesamiento de datos continuos y categóricos
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy, pandas, keras, tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# Descripción de las variables:
#
# https://archive.ics.uci.edu/dataset/45/heart+disease

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Definimos listas para las variables categóricas enteras, categóricas string y numéricas.

# %%
subset_feats = ['age', 'trestbps', 'chol', 'sex', 'cp']
df = df[subset_feats+['target']]

# %%
df.head()
# Out:
#    age  trestbps  chol  sex  cp  target
# 0   63       145   233    1   1       0
# 1   67       160   286    1   4       1
# 2   67       120   229    1   4       0
# 3   37       130   250    1   3       0
# 4   41       130   204    0   2       0

# %% [markdown]
# Separamos los datos en entrenamiento, validación y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#      age  trestbps  chol  sex  cp  target
# 69    35       138   183    0   4       0
# 300   65       135   254    1   4       1
# 220   59       134   204    1   1       0
# 134   42       120   240    1   3       0
# 7     57       120   354    0   4       0

# %%
train.shape
# Out:
# (242, 6)

# %%
test = df.drop(train.index)
test.head()
# Out:
#     age  trestbps  chol  sex  cp  target
# 0    63       145   233    1   1       0
# 2    67       120   229    1   4       0
# 4    41       130   204    0   2       0
# 8    63       130   254    1   4       1
# 13   44       120   263    1   2       0

# %%
val = train.sample(frac=0.2, random_state=100)

# %%
val.shape
# Out:
# (48, 6)

# %%
train = train.drop(val.index)

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (194, 6)
# (48, 6)
# (61, 6)

# %% [markdown]
# Calculamos estadísticas de cada variable numérica

# %%
train.describe()
# Out:
#               age    trestbps        chol         sex          cp      target
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    54.953608  132.876289  249.974227    0.664948    3.097938    0.257732
# std      8.754150   17.952879   52.803226    0.473230    1.030969    0.438517
# min     34.000000   94.000000  126.000000    0.000000    0.000000    0.000000
# 25%     49.000000  120.000000  215.750000    0.000000    2.000000    0.000000
# 50%     56.000000  130.000000  243.000000    1.000000    3.000000    0.000000
# 75%     61.000000  143.500000  281.000000    1.000000    4.000000    1.000000
# max     77.000000  192.000000  564.000000    1.000000    4.000000    1.000000

# %% [markdown]
# Función para convertir de dataframe (pandas) a dataset (tensorflow), separando características y etiquetas

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

# %%
train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %% [markdown]
# Ejemplo de cómo queda el tf.dataset

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=52>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=152>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=298>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=1>}
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# Separamos los datos de entrenamiento, validación y prueba en lotes

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Función para codificar variables numéricas (Keras docs)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

# %% [markdown]
# Función para codificar variables categóricas (Keras docs)

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# Creamos una lista de inputs para el modelo, de acuerdo con cada tipo de variable

# %%
inputs = {
    'age': keras.Input(shape=(1,), name='age'),
    'trestbps': keras.Input(shape=(1,), name='trestbps'),
    'chol': keras.Input(shape=(1,), name='chol'),
    'sex': keras.Input(shape=(1,), name='sex', dtype='int64'),
    'cp': keras.Input(shape=(1,), name='cp', dtype='int64')
}

# %%
for i in inputs:
   print(i)
# Out:
# age
# trestbps
# chol
# sex
# cp

# %% [markdown]
# Creamos una lista de variables codificadas/normalizadas de acuerdo con su tipo, empleando las funciones de codificación/normalización

# %%
feats_encoded = [
    encode_numerical_feature(inputs['age'], 'age', train_ds),
    encode_numerical_feature(inputs['trestbps'], 'trestbps', train_ds),
    encode_numerical_feature(inputs['chol'], 'chol', train_ds),
    encode_categorical_feature(inputs['sex'], 'sex', train_ds, False),  # 'sex' es categórica (entero)
    encode_categorical_feature(inputs['cp'], 'cp', train_ds, False)  # 'cp' es categórica (entero)
]

# %%
len_feats = len(feats_encoded)
len_feats
# Out:
# 5

# %%
for i in feats_encoded:
  print(i)
# Out:
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, name=keras_tensor>
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, name=keras_tensor_1>
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, name=keras_tensor_2>
# <KerasTensor shape=(None, 3), dtype=float32, sparse=False, name=keras_tensor_3>
# <KerasTensor shape=(None, 6), dtype=float32, sparse=False, name=keras_tensor_4>

# %% [markdown]
# Creamos una capa concatenando todas las variables codificadas

# %%
all_feats = keras.layers.concatenate(feats_encoded)

# %%
type(all_feats)
# Out:
# keras.src.backend.common.keras_tensor.KerasTensor

# %% [markdown]
# Agregamos una capa densa con 32 neuronas y función de activación relu

# %%
model_layers = keras.layers.Dense(32, activation='relu')(all_feats)

# %% [markdown]
# Agregamos la capa de salida con 1 neurona (probabilidad de sufrir la enfermedad cardiada) y función de activación sigmoide

# %%
model_layers = keras.layers.Dense(1, activation='sigmoid')(model_layers)

# %% [markdown]
# Creamos el modelo con las capas ya creadas y las variables de entrada

# %%
#Base
model = keras.Model(inputs, model_layers)

#variacion 1
model_var1= keras.Model(inputs, model_layers)

#Variacion 2
model_var2= keras.Model(inputs, model_layers)

#Variacion 3
model_var3= keras.Model(inputs, model_layers)

# %% [markdown]
# Compilamos el modelo, definiendo optimizador, función de pérdida y métricas adicionales a capturar

# %%
#Base
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#variacion 1
model_var1.compile(optimizer=keras.optimizers.Adam(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 2
model_var2.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 3
model_var3.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Aseguramos que Keras use TensorFlow como backend, para asegurar que el modelo pueda usar strings como entradas

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# Entrenamos el modelo con los datos en el formato tf.Dataset

# %%
#Base 
history=model.fit(train_ds, epochs=50, validation_data=val_ds)

#variacion 1
history_var1=model_var1.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 2
history_var2=model_var2.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 3
history_var3=model_var3.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9335 - loss: 0.1896 - val_accuracy: 0.7083 - val_loss: 0.6509
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8921 - loss: 0.2399 - val_accuracy: 0.7083 - val_loss: 0.6540
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8792 - loss: 0.2417 - val_accuracy: 0.7083 - val_loss: 0.6538
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8922 - loss: 0.2290 - val_accuracy: 0.7083 - val_loss: 0.6557
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9231 - loss: 0.2115 - val_accuracy: 0.7083 - val_loss: 0.6547
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8953 - loss: 0.2136 - val_accuracy: 0.7083 - val_loss: 0.6550
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8944 - loss: 0.2307 - val_accuracy: 0.7083 - val_loss: 0.6565
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8974 - loss: 0.2143 - val_accuracy: 0.7083 - val_loss: 0.6570
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8867 - loss: 0.2293 - val_accuracy: 0.7083 - val_loss: 0.6581
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8979 - loss: 0.2182 - val_accuracy: 0.7083 - val_loss: 0.6601
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8911 - loss: 0.2389 - val_accuracy: 0.7083 - val_loss: 0.6611
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8942 - loss: 0.2326 - val_accuracy: 0.7083 - val_loss: 0.6616
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9103 - loss: 0.2149 - val_accuracy: 0.7083 - val_loss: 0.6644
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9185 - loss: 0.2084 - val_accuracy: 0.7083 - val_loss: 0.6658
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9124 - loss: 0.2029 - val_accuracy: 0.7083 - val_loss: 0.6647
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8968 - loss: 0.2386 - val_accuracy: 0.7083 - val_loss: 0.6588
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9025 - loss: 0.2230 - val_accuracy: 0.7083 - val_loss: 0.6583
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8711 - loss: 0.2377 - val_accuracy: 0.7083 - val_loss: 0.6599
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8894 - loss: 0.2373 - val_accuracy: 0.7083 - val_loss: 0.6657
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2073 - val_accuracy: 0.7083 - val_loss: 0.6672
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9279 - loss: 0.1991 - val_accuracy: 0.7083 - val_loss: 0.6676
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9248 - loss: 0.1885 - val_accuracy: 0.7083 - val_loss: 0.6676
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9070 - loss: 0.2216 - val_accuracy: 0.7083 - val_loss: 0.6779
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9215 - loss: 0.2054 - val_accuracy: 0.7083 - val_loss: 0.6803
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9006 - loss: 0.2276 - val_accuracy: 0.7083 - val_loss: 0.6807
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2171 - val_accuracy: 0.7083 - val_loss: 0.6789
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9183 - loss: 0.2107 - val_accuracy: 0.7083 - val_loss: 0.6788
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9106 - loss: 0.2188 - val_accuracy: 0.7083 - val_loss: 0.6849
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9061 - loss: 0.2227 - val_accuracy: 0.7083 - val_loss: 0.6851
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9013 - loss: 0.2294 - val_accuracy: 0.7083 - val_loss: 0.6833
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8749 - loss: 0.2503 - val_accuracy: 0.7083 - val_loss: 0.6819
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.2132 - val_accuracy: 0.7083 - val_loss: 0.6790
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9196 - loss: 0.1975 - val_accuracy: 0.7083 - val_loss: 0.6731
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9111 - loss: 0.2193 - val_accuracy: 0.7083 - val_loss: 0.6723
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9146 - loss: 0.2051 - val_accuracy: 0.7083 - val_loss: 0.6710
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8984 - loss: 0.2285 - val_accuracy: 0.7083 - val_loss: 0.6694
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8918 - loss: 0.2177 - val_accuracy: 0.7083 - val_loss: 0.6677
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8902 - loss: 0.2210 - val_accuracy: 0.7083 - val_loss: 0.6702
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8842 - loss: 0.2324 - val_accuracy: 0.7083 - val_loss: 0.6691
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9124 - loss: 0.1993 - val_accuracy: 0.7083 - val_loss: 0.6658
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9204 - loss: 0.2120 - val_accuracy: 0.7083 - val_loss: 0.6653
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9009 - loss: 0.2263 - val_accuracy: 0.7083 - val_loss: 0.6653
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8971 - loss: 0.2229 - val_accuracy: 0.7083 - val_loss: 0.6653
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9066 - loss: 0.2187 - val_accuracy: 0.7083 - val_loss: 0.6636
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8881 - loss: 0.2320 - val_accuracy: 0.7083 - val_loss: 0.6624
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9129 - loss: 0.2055 - val_accuracy: 0.7083 - val_loss: 0.6612
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9073 - loss: 0.2074 - val_accuracy: 0.7083 - val_loss: 0.6603
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8973 - loss: 0.2311 - val_accuracy: 0.7083 - val_loss: 0.6614
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8971 - loss: 0.2221 - val_accuracy: 0.7083 - val_loss: 0.6616
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8764 - loss: 0.2497 - val_accuracy: 0.7083 - val_loss: 0.6599
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8885 - loss: 0.2266 - val_accuracy: 0.7083 - val_loss: 0.6600
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8950 - loss: 0.2354 - val_accuracy: 0.6875 - val_loss: 0.6336
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8842 - loss: 0.2341 - val_accuracy: 0.6875 - val_loss: 0.6444
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8879 - loss: 0.2214 - val_accuracy: 0.7083 - val_loss: 0.7258
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9111 - loss: 0.2188 - val_accuracy: 0.6875 - val_loss: 0.7222
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8816 - loss: 0.2378 - val_accuracy: 0.7083 - val_loss: 0.6947
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8852 - loss: 0.2386 - val_accuracy: 0.6875 - val_loss: 0.6760
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8651 - loss: 0.2609 - val_accuracy: 0.6875 - val_loss: 0.6840
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8832 - loss: 0.2448 - val_accuracy: 0.7292 - val_loss: 0.6576
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9174 - loss: 0.1982 - val_accuracy: 0.7083 - val_loss: 0.6458
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9007 - loss: 0.2096 - val_accuracy: 0.7083 - val_loss: 0.6517
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9192 - loss: 0.1997 - val_accuracy: 0.7083 - val_loss: 0.7109
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9058 - loss: 0.2051 - val_accuracy: 0.6875 - val_loss: 0.7411
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8798 - loss: 0.2143 - val_accuracy: 0.7083 - val_loss: 0.7119
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8962 - loss: 0.2300 - val_accuracy: 0.6875 - val_loss: 0.6956
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8977 - loss: 0.2345 - val_accuracy: 0.7083 - val_loss: 0.7009
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8812 - loss: 0.2343 - val_accuracy: 0.6667 - val_loss: 0.6952
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8996 - loss: 0.2231 - val_accuracy: 0.6875 - val_loss: 0.6687
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9109 - loss: 0.2024 - val_accuracy: 0.6875 - val_loss: 0.6550
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8896 - loss: 0.2122 - val_accuracy: 0.6875 - val_loss: 0.6758
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8918 - loss: 0.2061 - val_accuracy: 0.7083 - val_loss: 0.7111
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8902 - loss: 0.2327 - val_accuracy: 0.7083 - val_loss: 0.7165
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9103 - loss: 0.2148 - val_accuracy: 0.7083 - val_loss: 0.7000
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9225 - loss: 0.1852 - val_accuracy: 0.6875 - val_loss: 0.6356
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8752 - loss: 0.2212 - val_accuracy: 0.7292 - val_loss: 0.6379
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8860 - loss: 0.2405 - val_accuracy: 0.7500 - val_loss: 0.6350
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8746 - loss: 0.2603 - val_accuracy: 0.7292 - val_loss: 0.6074
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8950 - loss: 0.2093 - val_accuracy: 0.6875 - val_loss: 0.6117
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8953 - loss: 0.2119 - val_accuracy: 0.6875 - val_loss: 0.6370
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9056 - loss: 0.2033 - val_accuracy: 0.6875 - val_loss: 0.6761
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8752 - loss: 0.2204 - val_accuracy: 0.6667 - val_loss: 0.7132
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8790 - loss: 0.2342 - val_accuracy: 0.6875 - val_loss: 0.7059
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9249 - loss: 0.1933 - val_accuracy: 0.6875 - val_loss: 0.6933
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8803 - loss: 0.2347 - val_accuracy: 0.6875 - val_loss: 0.6838
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.1945 - val_accuracy: 0.6875 - val_loss: 0.6866
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8670 - loss: 0.2192 - val_accuracy: 0.6875 - val_loss: 0.6911
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8681 - loss: 0.2739 - val_accuracy: 0.6667 - val_loss: 0.6718
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9210 - loss: 0.2142 - val_accuracy: 0.6667 - val_loss: 0.6712
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9013 - loss: 0.1980 - val_accuracy: 0.6875 - val_loss: 0.6861
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8721 - loss: 0.2216 - val_accuracy: 0.6667 - val_loss: 0.6973
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9108 - loss: 0.1890 - val_accuracy: 0.6875 - val_loss: 0.7084
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8969 - loss: 0.1868 - val_accuracy: 0.7292 - val_loss: 0.7231
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8760 - loss: 0.2266 - val_accuracy: 0.7500 - val_loss: 0.6786
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8966 - loss: 0.1970 - val_accuracy: 0.6875 - val_loss: 0.6548
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8627 - loss: 0.2119 - val_accuracy: 0.6667 - val_loss: 0.6643
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8967 - loss: 0.1883 - val_accuracy: 0.6875 - val_loss: 0.6699
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2021 - val_accuracy: 0.6875 - val_loss: 0.6809
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9070 - loss: 0.1912 - val_accuracy: 0.6875 - val_loss: 0.7028
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8746 - loss: 0.2227 - val_accuracy: 0.6875 - val_loss: 0.7358
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8835 - loss: 0.2350 - val_accuracy: 0.7083 - val_loss: 0.7074
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9064 - loss: 0.1809 - val_accuracy: 0.7083 - val_loss: 0.6973
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9262 - loss: 0.1689 - val_accuracy: 0.6875 - val_loss: 0.6975
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9095 - loss: 0.1948 - val_accuracy: 0.6875 - val_loss: 0.6965
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9074 - loss: 0.1832 - val_accuracy: 0.6875 - val_loss: 0.6967
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8902 - loss: 0.2020 - val_accuracy: 0.6875 - val_loss: 0.6957
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8809 - loss: 0.2120 - val_accuracy: 0.6875 - val_loss: 0.6938
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9049 - loss: 0.2007 - val_accuracy: 0.6875 - val_loss: 0.6918
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9066 - loss: 0.1992 - val_accuracy: 0.6667 - val_loss: 0.6911
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9251 - loss: 0.1696 - val_accuracy: 0.6667 - val_loss: 0.6922
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9058 - loss: 0.1888 - val_accuracy: 0.6875 - val_loss: 0.6949
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9104 - loss: 0.1982 - val_accuracy: 0.6875 - val_loss: 0.6949
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9110 - loss: 0.1915 - val_accuracy: 0.6875 - val_loss: 0.6936
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9183 - loss: 0.1801 - val_accuracy: 0.6667 - val_loss: 0.6835
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9190 - loss: 0.1840 - val_accuracy: 0.6667 - val_loss: 0.6799
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9003 - loss: 0.1965 - val_accuracy: 0.6667 - val_loss: 0.6786
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9092 - loss: 0.1929 - val_accuracy: 0.6667 - val_loss: 0.6782
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9165 - loss: 0.1755 - val_accuracy: 0.6667 - val_loss: 0.6797
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8952 - loss: 0.1955 - val_accuracy: 0.6667 - val_loss: 0.6820
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9083 - loss: 0.1816 - val_accuracy: 0.6667 - val_loss: 0.6829
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8772 - loss: 0.2236 - val_accuracy: 0.6667 - val_loss: 0.6829
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9016 - loss: 0.2062 - val_accuracy: 0.6667 - val_loss: 0.6816
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9045 - loss: 0.2026 - val_accuracy: 0.6667 - val_loss: 0.6823
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9228 - loss: 0.1778 - val_accuracy: 0.6667 - val_loss: 0.6832
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8989 - loss: 0.1964 - val_accuracy: 0.6667 - val_loss: 0.6827
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9193 - loss: 0.1763 - val_accuracy: 0.6667 - val_loss: 0.6856
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9013 - loss: 0.1955 - val_accuracy: 0.6667 - val_loss: 0.6877
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9057 - loss: 0.1975 - val_accuracy: 0.6667 - val_loss: 0.6889
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9461 - loss: 0.1757 - val_accuracy: 0.6875 - val_loss: 0.6921
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8970 - loss: 0.2173 - val_accuracy: 0.6875 - val_loss: 0.6935
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9222 - loss: 0.1875 - val_accuracy: 0.6875 - val_loss: 0.6950
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9194 - loss: 0.1857 - val_accuracy: 0.6875 - val_loss: 0.6945
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9212 - loss: 0.1768 - val_accuracy: 0.6875 - val_loss: 0.6945
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9133 - loss: 0.1928 - val_accuracy: 0.6875 - val_loss: 0.6966
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.1854 - val_accuracy: 0.6875 - val_loss: 0.6970
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9204 - loss: 0.2004 - val_accuracy: 0.6875 - val_loss: 0.6975
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9354 - loss: 0.1794 - val_accuracy: 0.6875 - val_loss: 0.6986
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9426 - loss: 0.1637 - val_accuracy: 0.7083 - val_loss: 0.6990
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9470 - loss: 0.1728 - val_accuracy: 0.7083 - val_loss: 0.7032
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9158 - loss: 0.1810 - val_accuracy: 0.7083 - val_loss: 0.7057
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9194 - loss: 0.1919 - val_accuracy: 0.7083 - val_loss: 0.7071
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9207 - loss: 0.1882 - val_accuracy: 0.7083 - val_loss: 0.7075
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9134 - loss: 0.1915 - val_accuracy: 0.7083 - val_loss: 0.7079
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9046 - loss: 0.2195 - val_accuracy: 0.7083 - val_loss: 0.7085
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9305 - loss: 0.1748 - val_accuracy: 0.6875 - val_loss: 0.7093
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9125 - loss: 0.1816 - val_accuracy: 0.6875 - val_loss: 0.7093
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9281 - loss: 0.1671 - val_accuracy: 0.7083 - val_loss: 0.7097
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9253 - loss: 0.1887 - val_accuracy: 0.7083 - val_loss: 0.7127
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9113 - loss: 0.1920 - val_accuracy: 0.7083 - val_loss: 0.7142
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9310 - loss: 0.1726 - val_accuracy: 0.7083 - val_loss: 0.7152
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9190 - loss: 0.1824 - val_accuracy: 0.7083 - val_loss: 0.7173
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9372 - loss: 0.1813 - val_accuracy: 0.7083 - val_loss: 0.7173
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8929 - loss: 0.2068 - val_accuracy: 0.7083 - val_loss: 0.7173
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9108 - loss: 0.2044 - val_accuracy: 0.7083 - val_loss: 0.7172
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9313 - loss: 0.1682 - val_accuracy: 0.7083 - val_loss: 0.7170
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9151 - loss: 0.1850 - val_accuracy: 0.7083 - val_loss: 0.7167
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9162 - loss: 0.1982 - val_accuracy: 0.7083 - val_loss: 0.7171
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8999 - loss: 0.2156 - val_accuracy: 0.7083 - val_loss: 0.7171
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9309 - loss: 0.1793 - val_accuracy: 0.7083 - val_loss: 0.7170
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9198 - loss: 0.2042 - val_accuracy: 0.7083 - val_loss: 0.7168
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9155 - loss: 0.1865 - val_accuracy: 0.7083 - val_loss: 0.7165
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9298 - loss: 0.1874 - val_accuracy: 0.7083 - val_loss: 0.7161
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9206 - loss: 0.1869 - val_accuracy: 0.7083 - val_loss: 0.7160
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9221 - loss: 0.1965 - val_accuracy: 0.7083 - val_loss: 0.7157
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9456 - loss: 0.1578 - val_accuracy: 0.7083 - val_loss: 0.7152
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9186 - loss: 0.1807 - val_accuracy: 0.7083 - val_loss: 0.7149
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9377 - loss: 0.1665 - val_accuracy: 0.7083 - val_loss: 0.7145
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9334 - loss: 0.1693 - val_accuracy: 0.7083 - val_loss: 0.7142
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9150 - loss: 0.2055 - val_accuracy: 0.7083 - val_loss: 0.7138
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9208 - loss: 0.1825 - val_accuracy: 0.7083 - val_loss: 0.7134
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9189 - loss: 0.1880 - val_accuracy: 0.7083 - val_loss: 0.7132
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9091 - loss: 0.2058 - val_accuracy: 0.7083 - val_loss: 0.7131
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9337 - loss: 0.1804 - val_accuracy: 0.7083 - val_loss: 0.7132
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9074 - loss: 0.2042 - val_accuracy: 0.7083 - val_loss: 0.7132
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9121 - loss: 0.2015 - val_accuracy: 0.7083 - val_loss: 0.7130
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9201 - loss: 0.1842 - val_accuracy: 0.7083 - val_loss: 0.7130
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9179 - loss: 0.1897 - val_accuracy: 0.7083 - val_loss: 0.7130
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9175 - loss: 0.1913 - val_accuracy: 0.7083 - val_loss: 0.7129
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9358 - loss: 0.1624 - val_accuracy: 0.7083 - val_loss: 0.7127
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9218 - loss: 0.1732 - val_accuracy: 0.7083 - val_loss: 0.7124
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9180 - loss: 0.1921 - val_accuracy: 0.7083 - val_loss: 0.7120
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9238 - loss: 0.1769 - val_accuracy: 0.7083 - val_loss: 0.7118
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9434 - loss: 0.1684 - val_accuracy: 0.7083 - val_loss: 0.7114
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9216 - loss: 0.1864 - val_accuracy: 0.7083 - val_loss: 0.7098
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9066 - loss: 0.2066 - val_accuracy: 0.7083 - val_loss: 0.7092
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9130 - loss: 0.1920 - val_accuracy: 0.7083 - val_loss: 0.7089
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9097 - loss: 0.1963 - val_accuracy: 0.7083 - val_loss: 0.7085
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9087 - loss: 0.1956 - val_accuracy: 0.7083 - val_loss: 0.7079
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9136 - loss: 0.1851 - val_accuracy: 0.7083 - val_loss: 0.7074
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9130 - loss: 0.2024 - val_accuracy: 0.7083 - val_loss: 0.7072
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.1954 - val_accuracy: 0.7083 - val_loss: 0.7070
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9175 - loss: 0.1766 - val_accuracy: 0.7083 - val_loss: 0.7069
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9279 - loss: 0.1748 - val_accuracy: 0.7083 - val_loss: 0.7067
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9182 - loss: 0.1819 - val_accuracy: 0.7083 - val_loss: 0.7067
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9121 - loss: 0.2094 - val_accuracy: 0.7083 - val_loss: 0.7071
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9225 - loss: 0.1921 - val_accuracy: 0.7083 - val_loss: 0.7072
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9357 - loss: 0.1734 - val_accuracy: 0.7083 - val_loss: 0.7072
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9241 - loss: 0.1820 - val_accuracy: 0.7083 - val_loss: 0.7070
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9270 - loss: 0.1870 - val_accuracy: 0.7083 - val_loss: 0.7070
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9259 - loss: 0.1910 - val_accuracy: 0.7083 - val_loss: 0.7071
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.1936 - val_accuracy: 0.7083 - val_loss: 0.7071

# %% [markdown]
# Graficar la pérdida de entrenamiento y validación

# %%
#Base
plt.plot(history.history['loss'], label='Perdida')
plt.plot(history.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Base")
plt.show()

#variacion 1
plt.plot(history_var1.history['loss'], label='Perdida')
plt.plot(history_var1.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 1")
plt.show()

#variacion 2
plt.plot(history_var2.history['loss'], label='Perdida')
plt.plot(history_var2.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 2")
plt.show()

#variacion 3
plt.plot(history_var3.history['loss'], label='Perdida')
plt.plot(history_var3.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 3")
plt.show()

# %% [markdown]
# Hacer predicciones en el set de prueba

# %%
#base 
y_true = []
y_pred = []
for x, y in test_ds:
    y_true.extend(list(y.numpy()))
    y_pred.extend(list(model.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin = [1 if pred >= 0.5 else 0 for pred in y_pred]

# varicacion 1
y_pred_var1 = []
for x, y in test_ds:
    y_pred_var1.extend(list(model_var1.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var1 = [1 if pred >= 0.5 else 0 for pred in y_pred_var1]


# varicacion 2
y_pred_var2 = []
for x, y in test_ds:
    y_pred_var2.extend(list(model_var2.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var2 = [1 if pred >= 0.5 else 0 for pred in y_pred_var2]


# varicacion 3
y_pred_var3 = []
for x, y in test_ds:
    y_pred_var3.extend(list(model_var3.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var3 = [1 if pred >= 0.5 else 0 for pred in y_pred_var3]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000233FF00BE20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000233FF00BE20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step

# %% [markdown]
# Calcular las métricas

# %%
#base
accuracy = accuracy_score(y_true, y_pred_bin)
precision = precision_score(y_true, y_pred_bin)
recall = recall_score(y_true, y_pred_bin)
f1 = f1_score(y_true, y_pred_bin)

#variacion 1
accuracy_var1 = accuracy_score(y_true, y_pred_bin_var1)
precision_var1 = precision_score(y_true, y_pred_bin_var1)
recall_var1 = recall_score(y_true, y_pred_bin_var1)
f1_var1 = f1_score(y_true, y_pred_bin_var1)

#variacion 2
accuracy_var2 = accuracy_score(y_true, y_pred_bin_var2)
precision_var2 = precision_score(y_true, y_pred_bin_var2)
recall_var2 = recall_score(y_true, y_pred_bin_var2)
f1_var2 = f1_score(y_true, y_pred_bin_var2)

#variacion 3
accuracy_var3 = accuracy_score(y_true, y_pred_bin_var3)
precision_var3 = precision_score(y_true, y_pred_bin_var3)
recall_var3 = recall_score(y_true, y_pred_bin_var3)
f1_var3 = f1_score(y_true, y_pred_bin_var3)


# Imprimir las métricas base
print("Base")
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1-score: {f1}')


# Imprimir las métricas variacion 1
print("variacion 1")
print(f'Accuracy: {accuracy_var1}')
print(f'Precision: {precision_var1}')
print(f'Recall: {recall_var1}')
print(f'F1-score: {f1_var1}')

# Imprimir las métricas variacion 2
print("variacion 2")
print(f'Accuracy: {accuracy_var2}')
print(f'Precision: {precision_var2}')
print(f'Recall: {recall_var2}')
print(f'F1-score: {f1_var2}')

# Imprimir las métricas variacion 3
print("variacion 2")
print(f'Accuracy: {accuracy_var3}')
print(f'Precision: {precision_var3}')
print(f'Recall: {recall_var3}')
print(f'F1-score: {f1_var3}')
# Out:
# Base
# Accuracy: 0.7540983606557377
# Precision: 0.6666666666666666
# Recall: 0.5714285714285714
# F1-score: 0.6153846153846154
# variacion 1
# Accuracy: 0.5573770491803278
# Precision: 0.3333333333333333
# Recall: 0.2857142857142857
# F1-score: 0.3076923076923077
# variacion 2
# Accuracy: 0.5901639344262295
# Precision: 0.3888888888888889
# Recall: 0.3333333333333333
# F1-score: 0.358974358974359
# variacion 2
# Accuracy: 0.5573770491803278
# Precision: 0.3333333333333333
# Recall: 0.2857142857142857
# F1-score: 0.3076923076923077
