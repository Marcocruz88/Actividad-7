# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 13-14: redes neuronales para clasificación
#
# - Redes densas
# - Redes para clasificación
# - Procesamiento de datos continuos y categóricos
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy, pandas, keras, tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# Descripción de las variables:
#
# https://archive.ics.uci.edu/dataset/45/heart+disease

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Definimos listas para las variables categóricas enteras, categóricas string y numéricas.

# %%
subset_feats = ['age', 'trestbps', 'chol', 'sex', 'cp']
df = df[subset_feats+['target']]

# %%
df.head()
# Out:
#    age  trestbps  chol  sex  cp  target
# 0   63       145   233    1   1       0
# 1   67       160   286    1   4       1
# 2   67       120   229    1   4       0
# 3   37       130   250    1   3       0
# 4   41       130   204    0   2       0

# %% [markdown]
# Separamos los datos en entrenamiento, validación y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#      age  trestbps  chol  sex  cp  target
# 69    35       138   183    0   4       0
# 300   65       135   254    1   4       1
# 220   59       134   204    1   1       0
# 134   42       120   240    1   3       0
# 7     57       120   354    0   4       0

# %%
train.shape
# Out:
# (242, 6)

# %%
test = df.drop(train.index)
test.head()
# Out:
#     age  trestbps  chol  sex  cp  target
# 0    63       145   233    1   1       0
# 2    67       120   229    1   4       0
# 4    41       130   204    0   2       0
# 8    63       130   254    1   4       1
# 13   44       120   263    1   2       0

# %%
val = train.sample(frac=0.2, random_state=100)

# %%
val.shape
# Out:
# (48, 6)

# %%
train = train.drop(val.index)

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (194, 6)
# (48, 6)
# (61, 6)

# %% [markdown]
# Calculamos estadísticas de cada variable numérica

# %%
train.describe()
# Out:
#               age    trestbps        chol         sex          cp      target
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    54.953608  132.876289  249.974227    0.664948    3.097938    0.257732
# std      8.754150   17.952879   52.803226    0.473230    1.030969    0.438517
# min     34.000000   94.000000  126.000000    0.000000    0.000000    0.000000
# 25%     49.000000  120.000000  215.750000    0.000000    2.000000    0.000000
# 50%     56.000000  130.000000  243.000000    1.000000    3.000000    0.000000
# 75%     61.000000  143.500000  281.000000    1.000000    4.000000    1.000000
# max     77.000000  192.000000  564.000000    1.000000    4.000000    1.000000

# %% [markdown]
# Función para convertir de dataframe (pandas) a dataset (tensorflow), separando características y etiquetas

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

# %%
train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %% [markdown]
# Ejemplo de cómo queda el tf.dataset

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=66>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=146>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=278>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=3>}
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# Separamos los datos de entrenamiento, validación y prueba en lotes

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Función para codificar variables numéricas (Keras docs)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

# %% [markdown]
# Función para codificar variables categóricas (Keras docs)

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# Creamos una lista de inputs para el modelo, de acuerdo con cada tipo de variable

# %%
inputs = {
    'age': keras.Input(shape=(1,), name='age'),
    'trestbps': keras.Input(shape=(1,), name='trestbps'),
    'chol': keras.Input(shape=(1,), name='chol'),
    'sex': keras.Input(shape=(1,), name='sex', dtype='int64'),
    'cp': keras.Input(shape=(1,), name='cp', dtype='int64')
}
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
for i in inputs:
   print(i)
# Out:
# age
# trestbps
# chol
# sex
# cp

# %% [markdown]
# Creamos una lista de variables codificadas/normalizadas de acuerdo con su tipo, empleando las funciones de codificación/normalización

# %%
feats_encoded = [
    encode_numerical_feature(inputs['age'], 'age', train_ds),
    encode_numerical_feature(inputs['trestbps'], 'trestbps', train_ds),
    encode_numerical_feature(inputs['chol'], 'chol', train_ds),
    encode_categorical_feature(inputs['sex'], 'sex', train_ds, False),  # 'sex' es categórica (entero)
    encode_categorical_feature(inputs['cp'], 'cp', train_ds, False)  # 'cp' es categórica (entero)
]
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.

# %%
len_feats = len(feats_encoded)
len_feats
# Out:
# 5

# %%
for i in feats_encoded:
  print(i)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization/truediv:0', description="created by layer 'normalization'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_1/truediv:0', description="created by layer 'normalization_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_2/truediv:0', description="created by layer 'normalization_2'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='integer_lookup/bincount/DenseBincount:0', description="created by layer 'integer_lookup'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 6), dtype=tf.float32, name=None), name='integer_lookup_1/bincount/DenseBincount:0', description="created by layer 'integer_lookup_1'")

# %% [markdown]
# Creamos una capa concatenando todas las variables codificadas

# %%
all_feats = keras.layers.concatenate(feats_encoded)

# %%
type(all_feats)
# Out:
# keras.src.engine.keras_tensor.KerasTensor

# %% [markdown]
# Agregamos una capa densa con 32 neuronas y función de activación relu

# %%
model_layers = keras.layers.Dense(32, activation='relu')(all_feats)

# %% [markdown]
# Agregamos la capa de salida con 1 neurona (probabilidad de sufrir la enfermedad cardiada) y función de activación sigmoide

# %%
model_layers = keras.layers.Dense(1, activation='sigmoid')(model_layers)

# %% [markdown]
# Creamos el modelo con las capas ya creadas y las variables de entrada

# %%
#Base
model = keras.Model(inputs, model_layers)

#variacion 1
model_var1= keras.Model(inputs, model_layers)

#Variacion 2
model_var2= keras.Model(inputs, model_layers)

#Variacion 3
model_var3= keras.Model(inputs, model_layers)

# %% [markdown]
# Compilamos el modelo, definiendo optimizador, función de pérdida y métricas adicionales a capturar

# %%
#Base
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#variacion 1
model_var1.compile(optimizer=keras.optimizers.Adam(learning_rate=0.3), loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 2
model_var2.compile(optimizer=keras.optimizers.Adam(learning_rate=0.003), loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 3
model_var3.compile(optimizer=keras.optimizers.Adam(learning_rate=0.2), loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Aseguramos que Keras use TensorFlow como backend, para asegurar que el modelo pueda usar strings como entradas

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# Entrenamos el modelo con los datos en el formato tf.Dataset

# %%
#Base 
history=model.fit(train_ds, epochs=50, validation_data=val_ds)

#variacion 1
history_var1=model_var1.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 2
history_var2=model_var2.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 3
history_var3=model_var3.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 7/7 [==============================] - 1s 30ms/step - loss: 0.7220 - accuracy: 0.4691 - val_loss: 0.6820 - val_accuracy: 0.5000
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6925 - accuracy: 0.5412 - val_loss: 0.6571 - val_accuracy: 0.5417
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6702 - accuracy: 0.5825 - val_loss: 0.6338 - val_accuracy: 0.6458
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6466 - accuracy: 0.6237 - val_loss: 0.6117 - val_accuracy: 0.6875
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6269 - accuracy: 0.6753 - val_loss: 0.5907 - val_accuracy: 0.6875
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6089 - accuracy: 0.6804 - val_loss: 0.5733 - val_accuracy: 0.7292
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5938 - accuracy: 0.7062 - val_loss: 0.5620 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5821 - accuracy: 0.7216 - val_loss: 0.5512 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5714 - accuracy: 0.7113 - val_loss: 0.5404 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5608 - accuracy: 0.7216 - val_loss: 0.5293 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5503 - accuracy: 0.7320 - val_loss: 0.5199 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5411 - accuracy: 0.7371 - val_loss: 0.5123 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5335 - accuracy: 0.7371 - val_loss: 0.5060 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5271 - accuracy: 0.7423 - val_loss: 0.5005 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5223 - accuracy: 0.7423 - val_loss: 0.4958 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5183 - accuracy: 0.7423 - val_loss: 0.4925 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5142 - accuracy: 0.7423 - val_loss: 0.4889 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5101 - accuracy: 0.7423 - val_loss: 0.4860 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5061 - accuracy: 0.7474 - val_loss: 0.4829 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5025 - accuracy: 0.7474 - val_loss: 0.4807 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5001 - accuracy: 0.7423 - val_loss: 0.4793 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4970 - accuracy: 0.7423 - val_loss: 0.4773 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4938 - accuracy: 0.7474 - val_loss: 0.4744 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4906 - accuracy: 0.7474 - val_loss: 0.4710 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4874 - accuracy: 0.7474 - val_loss: 0.4685 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4844 - accuracy: 0.7474 - val_loss: 0.4664 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4817 - accuracy: 0.7474 - val_loss: 0.4639 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4780 - accuracy: 0.7474 - val_loss: 0.4618 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4750 - accuracy: 0.7474 - val_loss: 0.4594 - val_accuracy: 0.7708
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4720 - accuracy: 0.7577 - val_loss: 0.4571 - val_accuracy: 0.7708
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4696 - accuracy: 0.7526 - val_loss: 0.4548 - val_accuracy: 0.7708
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4673 - accuracy: 0.7577 - val_loss: 0.4527 - val_accuracy: 0.7708
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4652 - accuracy: 0.7577 - val_loss: 0.4509 - val_accuracy: 0.7708
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4630 - accuracy: 0.7526 - val_loss: 0.4489 - val_accuracy: 0.7708
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4612 - accuracy: 0.7526 - val_loss: 0.4488 - val_accuracy: 0.7917
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4597 - accuracy: 0.7577 - val_loss: 0.4487 - val_accuracy: 0.8125
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4590 - accuracy: 0.7577 - val_loss: 0.4485 - val_accuracy: 0.7917
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4577 - accuracy: 0.7577 - val_loss: 0.4481 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4565 - accuracy: 0.7577 - val_loss: 0.4469 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4555 - accuracy: 0.7680 - val_loss: 0.4465 - val_accuracy: 0.7917
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4540 - accuracy: 0.7732 - val_loss: 0.4450 - val_accuracy: 0.7917
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4519 - accuracy: 0.7732 - val_loss: 0.4430 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4502 - accuracy: 0.7732 - val_loss: 0.4418 - val_accuracy: 0.7708
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4493 - accuracy: 0.7732 - val_loss: 0.4418 - val_accuracy: 0.7708
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4476 - accuracy: 0.7835 - val_loss: 0.4401 - val_accuracy: 0.7708
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4459 - accuracy: 0.7784 - val_loss: 0.4383 - val_accuracy: 0.7708
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4443 - accuracy: 0.7784 - val_loss: 0.4362 - val_accuracy: 0.7917
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4428 - accuracy: 0.7784 - val_loss: 0.4357 - val_accuracy: 0.7917
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4422 - accuracy: 0.7784 - val_loss: 0.4353 - val_accuracy: 0.7917
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4414 - accuracy: 0.7835 - val_loss: 0.4345 - val_accuracy: 0.7708
# Epoch 1/50
# 7/7 [==============================] - 1s 22ms/step - loss: 1.1480 - accuracy: 0.6340 - val_loss: 0.6003 - val_accuracy: 0.7500
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5744 - accuracy: 0.7216 - val_loss: 0.4756 - val_accuracy: 0.7083
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5054 - accuracy: 0.7474 - val_loss: 0.4404 - val_accuracy: 0.6875
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4461 - accuracy: 0.7887 - val_loss: 0.4953 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4123 - accuracy: 0.7887 - val_loss: 0.6980 - val_accuracy: 0.6875
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4025 - accuracy: 0.7835 - val_loss: 0.6336 - val_accuracy: 0.6667
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4049 - accuracy: 0.7784 - val_loss: 0.4878 - val_accuracy: 0.7292
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3845 - accuracy: 0.7784 - val_loss: 0.5195 - val_accuracy: 0.6875
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4220 - accuracy: 0.7887 - val_loss: 0.4755 - val_accuracy: 0.7292
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4061 - accuracy: 0.7938 - val_loss: 0.5782 - val_accuracy: 0.7083
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4664 - accuracy: 0.7216 - val_loss: 0.8036 - val_accuracy: 0.6875
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4371 - accuracy: 0.7577 - val_loss: 0.6609 - val_accuracy: 0.6875
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5113 - accuracy: 0.7474 - val_loss: 0.6202 - val_accuracy: 0.7083
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.7423 - val_loss: 0.6649 - val_accuracy: 0.6875
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4429 - accuracy: 0.7680 - val_loss: 0.7042 - val_accuracy: 0.6875
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5268 - accuracy: 0.7629 - val_loss: 0.9939 - val_accuracy: 0.6458
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5108 - accuracy: 0.7680 - val_loss: 0.4856 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5400 - accuracy: 0.7423 - val_loss: 0.4689 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4452 - accuracy: 0.7423 - val_loss: 0.5244 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4517 - accuracy: 0.7423 - val_loss: 0.5622 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4415 - accuracy: 0.7423 - val_loss: 0.5041 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4411 - accuracy: 0.7320 - val_loss: 0.5826 - val_accuracy: 0.7292
# Epoch 23/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4571 - accuracy: 0.6237 - val_loss: 0.6127 - val_accuracy: 0.5417
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4230 - accuracy: 0.6804 - val_loss: 0.5429 - val_accuracy: 0.7292
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.7423 - val_loss: 0.5558 - val_accuracy: 0.7292
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4044 - accuracy: 0.7474 - val_loss: 0.6186 - val_accuracy: 0.7292
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4060 - accuracy: 0.7474 - val_loss: 0.6798 - val_accuracy: 0.7292
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4036 - accuracy: 0.7474 - val_loss: 0.7084 - val_accuracy: 0.7292
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4026 - accuracy: 0.7474 - val_loss: 0.5991 - val_accuracy: 0.7292
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4091 - accuracy: 0.7474 - val_loss: 0.6014 - val_accuracy: 0.7292
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3998 - accuracy: 0.7474 - val_loss: 0.6090 - val_accuracy: 0.7292
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4015 - accuracy: 0.7474 - val_loss: 0.6759 - val_accuracy: 0.7292
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3907 - accuracy: 0.7320 - val_loss: 0.6130 - val_accuracy: 0.5833
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3882 - accuracy: 0.7577 - val_loss: 0.5060 - val_accuracy: 0.7292
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3938 - accuracy: 0.7474 - val_loss: 0.4713 - val_accuracy: 0.7292
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3890 - accuracy: 0.7474 - val_loss: 0.4718 - val_accuracy: 0.7292
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3851 - accuracy: 0.7474 - val_loss: 0.5220 - val_accuracy: 0.7292
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3861 - accuracy: 0.7474 - val_loss: 0.6197 - val_accuracy: 0.7292
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3888 - accuracy: 0.7474 - val_loss: 0.6317 - val_accuracy: 0.7292
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3847 - accuracy: 0.7474 - val_loss: 0.6058 - val_accuracy: 0.6250
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3893 - accuracy: 0.7062 - val_loss: 0.5591 - val_accuracy: 0.6458
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3865 - accuracy: 0.6959 - val_loss: 0.5676 - val_accuracy: 0.7292
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3850 - accuracy: 0.7474 - val_loss: 0.5865 - val_accuracy: 0.7292
# Epoch 44/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3852 - accuracy: 0.7474 - val_loss: 0.6560 - val_accuracy: 0.6250
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4230 - accuracy: 0.6753 - val_loss: 0.6487 - val_accuracy: 0.5833
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4506 - accuracy: 0.6753 - val_loss: 0.5725 - val_accuracy: 0.7292
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4207 - accuracy: 0.7474 - val_loss: 0.6540 - val_accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4345 - accuracy: 0.7423 - val_loss: 0.7445 - val_accuracy: 0.7292
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4333 - accuracy: 0.7423 - val_loss: 0.5632 - val_accuracy: 0.7292
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5072 - accuracy: 0.7320 - val_loss: 1.4730 - val_accuracy: 0.6667
# Epoch 1/50
# 7/7 [==============================] - 1s 26ms/step - loss: 0.5362 - accuracy: 0.7371 - val_loss: 1.4630 - val_accuracy: 0.6667
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5309 - accuracy: 0.7371 - val_loss: 1.4505 - val_accuracy: 0.6667
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5275 - accuracy: 0.7371 - val_loss: 1.4462 - val_accuracy: 0.6667
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5238 - accuracy: 0.7371 - val_loss: 1.4416 - val_accuracy: 0.6667
# Epoch 5/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5214 - accuracy: 0.7371 - val_loss: 1.4372 - val_accuracy: 0.6667
# Epoch 6/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5188 - accuracy: 0.7371 - val_loss: 1.4336 - val_accuracy: 0.6667
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5174 - accuracy: 0.7371 - val_loss: 1.4291 - val_accuracy: 0.6667
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5155 - accuracy: 0.7423 - val_loss: 1.4251 - val_accuracy: 0.6667
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5140 - accuracy: 0.7423 - val_loss: 1.4204 - val_accuracy: 0.6667
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5119 - accuracy: 0.7423 - val_loss: 1.4141 - val_accuracy: 0.6667
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5098 - accuracy: 0.7423 - val_loss: 1.4094 - val_accuracy: 0.6667
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5084 - accuracy: 0.7423 - val_loss: 1.4060 - val_accuracy: 0.6667
# Epoch 13/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5070 - accuracy: 0.7423 - val_loss: 1.4023 - val_accuracy: 0.6667
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5061 - accuracy: 0.7423 - val_loss: 1.3980 - val_accuracy: 0.6667
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5051 - accuracy: 0.7423 - val_loss: 1.3936 - val_accuracy: 0.6667
# Epoch 16/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5037 - accuracy: 0.7423 - val_loss: 1.3904 - val_accuracy: 0.6667
# Epoch 17/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5027 - accuracy: 0.7423 - val_loss: 1.3869 - val_accuracy: 0.6667
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7423 - val_loss: 1.3828 - val_accuracy: 0.6667
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5008 - accuracy: 0.7423 - val_loss: 1.3798 - val_accuracy: 0.6667
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5000 - accuracy: 0.7423 - val_loss: 1.3764 - val_accuracy: 0.6667
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4991 - accuracy: 0.7423 - val_loss: 1.3744 - val_accuracy: 0.6667
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4985 - accuracy: 0.7423 - val_loss: 1.3722 - val_accuracy: 0.6667
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4978 - accuracy: 0.7423 - val_loss: 1.3690 - val_accuracy: 0.6667
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4969 - accuracy: 0.7423 - val_loss: 1.3655 - val_accuracy: 0.6667
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.7423 - val_loss: 1.3620 - val_accuracy: 0.6667
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4949 - accuracy: 0.7423 - val_loss: 1.3582 - val_accuracy: 0.6667
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4936 - accuracy: 0.7423 - val_loss: 1.3552 - val_accuracy: 0.6667
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4926 - accuracy: 0.7423 - val_loss: 1.3522 - val_accuracy: 0.6667
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4917 - accuracy: 0.7423 - val_loss: 1.3490 - val_accuracy: 0.6667
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4907 - accuracy: 0.7423 - val_loss: 1.3479 - val_accuracy: 0.6667
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4902 - accuracy: 0.7423 - val_loss: 1.3453 - val_accuracy: 0.6667
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4894 - accuracy: 0.7423 - val_loss: 1.3409 - val_accuracy: 0.6667
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4880 - accuracy: 0.7423 - val_loss: 1.3374 - val_accuracy: 0.6667
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4871 - accuracy: 0.7423 - val_loss: 1.3341 - val_accuracy: 0.6667
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4863 - accuracy: 0.7423 - val_loss: 1.3298 - val_accuracy: 0.6667
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4852 - accuracy: 0.7423 - val_loss: 1.3260 - val_accuracy: 0.6667
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4840 - accuracy: 0.7423 - val_loss: 1.3233 - val_accuracy: 0.6667
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4832 - accuracy: 0.7423 - val_loss: 1.3194 - val_accuracy: 0.6667
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4821 - accuracy: 0.7423 - val_loss: 1.3155 - val_accuracy: 0.6667
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4810 - accuracy: 0.7423 - val_loss: 1.3122 - val_accuracy: 0.6667
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4795 - accuracy: 0.7423 - val_loss: 1.3093 - val_accuracy: 0.6667
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4790 - accuracy: 0.7423 - val_loss: 1.3061 - val_accuracy: 0.6667
# Epoch 43/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4782 - accuracy: 0.7423 - val_loss: 1.3025 - val_accuracy: 0.6667
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4772 - accuracy: 0.7423 - val_loss: 1.2989 - val_accuracy: 0.6667
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4765 - accuracy: 0.7423 - val_loss: 1.2952 - val_accuracy: 0.6667
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4752 - accuracy: 0.7423 - val_loss: 1.2914 - val_accuracy: 0.6667
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4742 - accuracy: 0.7423 - val_loss: 1.2868 - val_accuracy: 0.6667
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4731 - accuracy: 0.7423 - val_loss: 1.2829 - val_accuracy: 0.6667
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4722 - accuracy: 0.7423 - val_loss: 1.2787 - val_accuracy: 0.6667
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4708 - accuracy: 0.7423 - val_loss: 1.2749 - val_accuracy: 0.6667
# Epoch 1/50
# 7/7 [==============================] - 1s 23ms/step - loss: 0.4845 - accuracy: 0.7474 - val_loss: 0.7673 - val_accuracy: 0.6667
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.6753 - val_loss: 0.8958 - val_accuracy: 0.6250
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4267 - accuracy: 0.6907 - val_loss: 1.0425 - val_accuracy: 0.6875
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4209 - accuracy: 0.7474 - val_loss: 0.7715 - val_accuracy: 0.7292
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3964 - accuracy: 0.7474 - val_loss: 0.7588 - val_accuracy: 0.7292
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4016 - accuracy: 0.7423 - val_loss: 0.8322 - val_accuracy: 0.7292
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4047 - accuracy: 0.7423 - val_loss: 1.1225 - val_accuracy: 0.6875
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4016 - accuracy: 0.6907 - val_loss: 1.2563 - val_accuracy: 0.6042
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4004 - accuracy: 0.7113 - val_loss: 1.2391 - val_accuracy: 0.6250
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3912 - accuracy: 0.7113 - val_loss: 1.1590 - val_accuracy: 0.6875
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3860 - accuracy: 0.7474 - val_loss: 0.9150 - val_accuracy: 0.6875
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3951 - accuracy: 0.7526 - val_loss: 0.9457 - val_accuracy: 0.6875
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4001 - accuracy: 0.7526 - val_loss: 1.1249 - val_accuracy: 0.6875
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4049 - accuracy: 0.7526 - val_loss: 1.2171 - val_accuracy: 0.6875
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3986 - accuracy: 0.7526 - val_loss: 1.2528 - val_accuracy: 0.6875
# Epoch 16/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3957 - accuracy: 0.7474 - val_loss: 0.9151 - val_accuracy: 0.6875
# Epoch 17/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4001 - accuracy: 0.7526 - val_loss: 1.0544 - val_accuracy: 0.6875
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3880 - accuracy: 0.7526 - val_loss: 1.2455 - val_accuracy: 0.6875
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3850 - accuracy: 0.7526 - val_loss: 1.3481 - val_accuracy: 0.6875
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3856 - accuracy: 0.7474 - val_loss: 0.9848 - val_accuracy: 0.6875
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3975 - accuracy: 0.7423 - val_loss: 0.9147 - val_accuracy: 0.7083
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3896 - accuracy: 0.7474 - val_loss: 1.0367 - val_accuracy: 0.7292
# Epoch 23/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4186 - accuracy: 0.7423 - val_loss: 0.8711 - val_accuracy: 0.7292
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4079 - accuracy: 0.7423 - val_loss: 0.8232 - val_accuracy: 0.7292
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3904 - accuracy: 0.7474 - val_loss: 0.8742 - val_accuracy: 0.7292
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4077 - accuracy: 0.7474 - val_loss: 0.9009 - val_accuracy: 0.7292
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3891 - accuracy: 0.7474 - val_loss: 0.9318 - val_accuracy: 0.7292
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3968 - accuracy: 0.7474 - val_loss: 0.9480 - val_accuracy: 0.7292
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3941 - accuracy: 0.7474 - val_loss: 0.9525 - val_accuracy: 0.7292
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3879 - accuracy: 0.7474 - val_loss: 0.9537 - val_accuracy: 0.7292
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3842 - accuracy: 0.7474 - val_loss: 0.9483 - val_accuracy: 0.7292
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3792 - accuracy: 0.7474 - val_loss: 0.9358 - val_accuracy: 0.7292
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3786 - accuracy: 0.7474 - val_loss: 0.9250 - val_accuracy: 0.7292
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3757 - accuracy: 0.7474 - val_loss: 0.9273 - val_accuracy: 0.7292
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3780 - accuracy: 0.7474 - val_loss: 0.9390 - val_accuracy: 0.7292
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3746 - accuracy: 0.7474 - val_loss: 0.9556 - val_accuracy: 0.7292
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3694 - accuracy: 0.7216 - val_loss: 0.9734 - val_accuracy: 0.7083
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3700 - accuracy: 0.7268 - val_loss: 0.9848 - val_accuracy: 0.6875
# Epoch 39/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3683 - accuracy: 0.7268 - val_loss: 0.9936 - val_accuracy: 0.6875
# Epoch 40/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3649 - accuracy: 0.7474 - val_loss: 1.0038 - val_accuracy: 0.7292
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3671 - accuracy: 0.7474 - val_loss: 1.0128 - val_accuracy: 0.7292
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3666 - accuracy: 0.7474 - val_loss: 1.0228 - val_accuracy: 0.7292
# Epoch 43/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3673 - accuracy: 0.7474 - val_loss: 1.0295 - val_accuracy: 0.7083
# Epoch 44/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3665 - accuracy: 0.7474 - val_loss: 1.0360 - val_accuracy: 0.7083
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3652 - accuracy: 0.7474 - val_loss: 1.0762 - val_accuracy: 0.7083
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3610 - accuracy: 0.7526 - val_loss: 1.0938 - val_accuracy: 0.6875
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3618 - accuracy: 0.7371 - val_loss: 1.0945 - val_accuracy: 0.6875
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3611 - accuracy: 0.7423 - val_loss: 1.1079 - val_accuracy: 0.7083
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3652 - accuracy: 0.7474 - val_loss: 1.1179 - val_accuracy: 0.7083
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3612 - accuracy: 0.7474 - val_loss: 1.1224 - val_accuracy: 0.7083

# %% [markdown]
# Graficar la pérdida de entrenamiento y validación

# %%
#Base
plt.plot(history.history['loss'], label='Perdida')
plt.plot(history.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Base")
plt.show()

#variacion 1
plt.plot(history_var1.history['loss'], label='Perdida')
plt.plot(history_var1.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 1")
plt.show()

#variacion 2
plt.plot(history_var2.history['loss'], label='Perdida')
plt.plot(history_var2.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 2")
plt.show()

#variacion 3
plt.plot(history_var3.history['loss'], label='Perdida')
plt.plot(history_var3.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 3")
plt.show()

# %% [markdown]
# Hacer predicciones en el set de prueba

# %%
#base 
y_true = []
y_pred = []
for x, y in test_ds:
    y_true.extend(list(y.numpy()))
    y_pred.extend(list(model.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin = [1 if pred >= 0.5 else 0 for pred in y_pred]

# varicacion 1
y_pred_var1 = []
for x, y in test_ds:
    y_pred_var1.extend(list(model_var1.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var1 = [1 if pred >= 0.5 else 0 for pred in y_pred_var1]


# varicacion 2
y_pred_var2 = []
for x, y in test_ds:
    y_pred_var2.extend(list(model_var2.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var2 = [1 if pred >= 0.5 else 0 for pred in y_pred_var2]


# varicacion 3
y_pred_var3 = []
for x, y in test_ds:
    y_pred_var3.extend(list(model_var3.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var3 = [1 if pred >= 0.5 else 0 for pred in y_pred_var3]
# Out:
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 89ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002A33C3DA700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 86ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002A33C3DA700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step

# %% [markdown]
# Calcular las métricas

# %%
#base

from sklearn.metrics import classification_report, confusion_matrix

#base
# Calcular métricas
print("Base")
print(classification_report(y_true, y_pred_bin, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin))
# Out:
# Base
#                precision    recall  f1-score   support
#
# No enfermedad       0.67      1.00      0.80        40
#    Enfermedad       1.00      0.05      0.09        21
#
#      accuracy                           0.67        61
#     macro avg       0.83      0.52      0.45        61
#  weighted avg       0.78      0.67      0.56        61
#
# Matriz de confusión:
#  [[40  0]
#  [20  1]]

# %%
#variacion 1
print("Variacion 1")
print(classification_report(y_true, y_pred_bin_var1, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var1))
# Out:
# Variacion 1
#                precision    recall  f1-score   support
#
# No enfermedad       0.67      1.00      0.80        40
#    Enfermedad       1.00      0.05      0.09        21
#
#      accuracy                           0.67        61
#     macro avg       0.83      0.52      0.45        61
#  weighted avg       0.78      0.67      0.56        61
#
# Matriz de confusión:
#  [[40  0]
#  [20  1]]

# %%
#variacion 2
print("Variacion 2")
print(classification_report(y_true, y_pred_bin_var2, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var2))
# Out:
# Variacion 2
#                precision    recall  f1-score   support
#
# No enfermedad       0.65      0.97      0.78        40
#    Enfermedad       0.00      0.00      0.00        21
#
#      accuracy                           0.64        61
#     macro avg       0.33      0.49      0.39        61
#  weighted avg       0.43      0.64      0.51        61
#
# Matriz de confusión:
#  [[39  1]
#  [21  0]]

# %%
#variacion 3
print("Variacion 3")
print(classification_report(y_true, y_pred_bin_var3, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var3))
# Out:
# Variacion 3
#                precision    recall  f1-score   support
#
# No enfermedad       0.65      0.97      0.78        40
#    Enfermedad       0.00      0.00      0.00        21
#
#      accuracy                           0.64        61
#     macro avg       0.33      0.49      0.39        61
#  weighted avg       0.43      0.64      0.51        61
#
# Matriz de confusión:
#  [[39  1]
#  [21  0]]
