# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 13-14: redes neuronales para clasificación
#
# - Redes densas
# - Redes para clasificación
# - Procesamiento de datos continuos y categóricos
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy, pandas, keras, tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# Descripción de las variables:
#
# https://archive.ics.uci.edu/dataset/45/heart+disease

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Definimos listas para las variables categóricas enteras, categóricas string y numéricas.

# %%
subset_feats = ['age', 'trestbps', 'chol', 'sex', 'cp']
df = df[subset_feats+['target']]

# %%
df.head()
# Out:
#    age  trestbps  chol  sex  cp  target
# 0   63       145   233    1   1       0
# 1   67       160   286    1   4       1
# 2   67       120   229    1   4       0
# 3   37       130   250    1   3       0
# 4   41       130   204    0   2       0

# %% [markdown]
# Separamos los datos en entrenamiento, validación y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#      age  trestbps  chol  sex  cp  target
# 69    35       138   183    0   4       0
# 300   65       135   254    1   4       1
# 220   59       134   204    1   1       0
# 134   42       120   240    1   3       0
# 7     57       120   354    0   4       0

# %%
train.shape
# Out:
# (242, 6)

# %%
test = df.drop(train.index)
test.head()
# Out:
#     age  trestbps  chol  sex  cp  target
# 0    63       145   233    1   1       0
# 2    67       120   229    1   4       0
# 4    41       130   204    0   2       0
# 8    63       130   254    1   4       1
# 13   44       120   263    1   2       0

# %%
val = train.sample(frac=0.2, random_state=100)

# %%
val.shape
# Out:
# (48, 6)

# %%
train = train.drop(val.index)

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (194, 6)
# (48, 6)
# (61, 6)

# %% [markdown]
# Calculamos estadísticas de cada variable numérica

# %%
train.describe()
# Out:
#               age    trestbps        chol         sex          cp      target
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    54.953608  132.876289  249.974227    0.664948    3.097938    0.257732
# std      8.754150   17.952879   52.803226    0.473230    1.030969    0.438517
# min     34.000000   94.000000  126.000000    0.000000    0.000000    0.000000
# 25%     49.000000  120.000000  215.750000    0.000000    2.000000    0.000000
# 50%     56.000000  130.000000  243.000000    1.000000    3.000000    0.000000
# 75%     61.000000  143.500000  281.000000    1.000000    4.000000    1.000000
# max     77.000000  192.000000  564.000000    1.000000    4.000000    1.000000

# %% [markdown]
# Función para convertir de dataframe (pandas) a dataset (tensorflow), separando características y etiquetas

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

# %%
train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %% [markdown]
# Ejemplo de cómo queda el tf.dataset

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=54>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=132>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=288>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=2>}
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# Separamos los datos de entrenamiento, validación y prueba en lotes

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Función para codificar variables numéricas (Keras docs)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

# %% [markdown]
# Función para codificar variables categóricas (Keras docs)

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# Creamos una lista de inputs para el modelo, de acuerdo con cada tipo de variable

# %%
inputs = {
    'age': keras.Input(shape=(1,), name='age'),
    'trestbps': keras.Input(shape=(1,), name='trestbps'),
    'chol': keras.Input(shape=(1,), name='chol'),
    'sex': keras.Input(shape=(1,), name='sex', dtype='int64'),
    'cp': keras.Input(shape=(1,), name='cp', dtype='int64')
}

# %%
for i in inputs:
   print(i)
# Out:
# age
# trestbps
# chol
# sex
# cp

# %% [markdown]
# Creamos una lista de variables codificadas/normalizadas de acuerdo con su tipo, empleando las funciones de codificación/normalización

# %%
feats_encoded = [
    encode_numerical_feature(inputs['age'], 'age', train_ds),
    encode_numerical_feature(inputs['trestbps'], 'trestbps', train_ds),
    encode_numerical_feature(inputs['chol'], 'chol', train_ds),
    encode_categorical_feature(inputs['sex'], 'sex', train_ds, False),  # 'sex' es categórica (entero)
    encode_categorical_feature(inputs['cp'], 'cp', train_ds, False)  # 'cp' es categórica (entero)
]

# %%
len_feats = len(feats_encoded)
len_feats
# Out:
# 5

# %%
for i in feats_encoded:
  print(i)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_3/truediv:0', description="created by layer 'normalization_3'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_4/truediv:0', description="created by layer 'normalization_4'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_5/truediv:0', description="created by layer 'normalization_5'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='integer_lookup_2/bincount/DenseBincount:0', description="created by layer 'integer_lookup_2'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 6), dtype=tf.float32, name=None), name='integer_lookup_3/bincount/DenseBincount:0', description="created by layer 'integer_lookup_3'")

# %% [markdown]
# Creamos una capa concatenando todas las variables codificadas

# %%
all_feats = keras.layers.concatenate(feats_encoded)

# %%
type(all_feats)
# Out:
# keras.src.engine.keras_tensor.KerasTensor

# %% [markdown]
# Agregamos una capa densa con 32 neuronas y función de activación relu

# %%
model_layers = keras.layers.Dense(32, activation='relu')(all_feats)

# %% [markdown]
# Agregamos la capa de salida con 1 neurona (probabilidad de sufrir la enfermedad cardiada) y función de activación sigmoide

# %%
model_layers = keras.layers.Dense(1, activation='sigmoid')(model_layers)

# %% [markdown]
# Creamos el modelo con las capas ya creadas y las variables de entrada

# %%
#Base
model = keras.Model(inputs, model_layers)

#variacion 1
model_var1= keras.Model(inputs, model_layers)

#Variacion 2
model_var2= keras.Model(inputs, model_layers)

#Variacion 3
model_var3= keras.Model(inputs, model_layers)

# %% [markdown]
# Compilamos el modelo, definiendo optimizador, función de pérdida y métricas adicionales a capturar

# %%
#Base
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#variacion 1
model_var1.compile(optimizer=keras.optimizers.Adam(learning_rate=0.3), loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 2
model_var2.compile(optimizer=keras.optimizers.Adam(learning_rate=0.003), loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 3
model_var3.compile(optimizer=keras.optimizers.Adam(learning_rate=0.7), loss='binary_crossentropy', metrics=['accuracy'])

# %%
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Aseguramos que Keras use TensorFlow como backend, para asegurar que el modelo pueda usar strings como entradas

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# Entrenamos el modelo con los datos en el formato tf.Dataset

# %%
#Base 
history=model.fit(train_ds, epochs=50, validation_data=val_ds)

#variacion 1
history_var1=model_var1.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 2
history_var2=model_var2.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 3
history_var3=model_var3.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 1s 23ms/step - loss: 0.7939 - accuracy: 0.5000 - val_loss: 0.7622 - val_accuracy: 0.5417
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7519 - accuracy: 0.5619 - val_loss: 0.7289 - val_accuracy: 0.6250
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7184 - accuracy: 0.5722 - val_loss: 0.7002 - val_accuracy: 0.6250
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6907 - accuracy: 0.5876 - val_loss: 0.6753 - val_accuracy: 0.6250
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6632 - accuracy: 0.5825 - val_loss: 0.6530 - val_accuracy: 0.6250
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6398 - accuracy: 0.6289 - val_loss: 0.6337 - val_accuracy: 0.6667
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6201 - accuracy: 0.6649 - val_loss: 0.6179 - val_accuracy: 0.7083
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6028 - accuracy: 0.6649 - val_loss: 0.6035 - val_accuracy: 0.7083
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5880 - accuracy: 0.6546 - val_loss: 0.5907 - val_accuracy: 0.7083
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5741 - accuracy: 0.6701 - val_loss: 0.5794 - val_accuracy: 0.7708
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5629 - accuracy: 0.6804 - val_loss: 0.5696 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5530 - accuracy: 0.6804 - val_loss: 0.5605 - val_accuracy: 0.7292
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5434 - accuracy: 0.7165 - val_loss: 0.5537 - val_accuracy: 0.7292
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5375 - accuracy: 0.7320 - val_loss: 0.5496 - val_accuracy: 0.7292
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5326 - accuracy: 0.7268 - val_loss: 0.5432 - val_accuracy: 0.7083
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5262 - accuracy: 0.7474 - val_loss: 0.5374 - val_accuracy: 0.7083
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5202 - accuracy: 0.7474 - val_loss: 0.5325 - val_accuracy: 0.7083
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5157 - accuracy: 0.7423 - val_loss: 0.5280 - val_accuracy: 0.7292
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5113 - accuracy: 0.7577 - val_loss: 0.5240 - val_accuracy: 0.7292
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5074 - accuracy: 0.7629 - val_loss: 0.5197 - val_accuracy: 0.7292
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5032 - accuracy: 0.7629 - val_loss: 0.5159 - val_accuracy: 0.7292
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4993 - accuracy: 0.7629 - val_loss: 0.5117 - val_accuracy: 0.7292
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4959 - accuracy: 0.7526 - val_loss: 0.5077 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4930 - accuracy: 0.7577 - val_loss: 0.5048 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4905 - accuracy: 0.7577 - val_loss: 0.5024 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4879 - accuracy: 0.7577 - val_loss: 0.5001 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4855 - accuracy: 0.7577 - val_loss: 0.4974 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4835 - accuracy: 0.7577 - val_loss: 0.4933 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4808 - accuracy: 0.7629 - val_loss: 0.4905 - val_accuracy: 0.7500
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4788 - accuracy: 0.7629 - val_loss: 0.4884 - val_accuracy: 0.7500
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4769 - accuracy: 0.7680 - val_loss: 0.4863 - val_accuracy: 0.7500
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4748 - accuracy: 0.7680 - val_loss: 0.4839 - val_accuracy: 0.7500
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4726 - accuracy: 0.7680 - val_loss: 0.4815 - val_accuracy: 0.7500
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4708 - accuracy: 0.7680 - val_loss: 0.4784 - val_accuracy: 0.7292
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4684 - accuracy: 0.7680 - val_loss: 0.4760 - val_accuracy: 0.7292
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4667 - accuracy: 0.7526 - val_loss: 0.4738 - val_accuracy: 0.7708
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4647 - accuracy: 0.7474 - val_loss: 0.4715 - val_accuracy: 0.7708
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4629 - accuracy: 0.7423 - val_loss: 0.4690 - val_accuracy: 0.7708
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4612 - accuracy: 0.7423 - val_loss: 0.4674 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4599 - accuracy: 0.7577 - val_loss: 0.4659 - val_accuracy: 0.7917
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4584 - accuracy: 0.7577 - val_loss: 0.4632 - val_accuracy: 0.7917
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4571 - accuracy: 0.7680 - val_loss: 0.4615 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4560 - accuracy: 0.7732 - val_loss: 0.4595 - val_accuracy: 0.7917
# Epoch 44/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4544 - accuracy: 0.7629 - val_loss: 0.4580 - val_accuracy: 0.7917
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4538 - accuracy: 0.7577 - val_loss: 0.4567 - val_accuracy: 0.7708
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4523 - accuracy: 0.7629 - val_loss: 0.4551 - val_accuracy: 0.7917
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4517 - accuracy: 0.7629 - val_loss: 0.4537 - val_accuracy: 0.7917
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4510 - accuracy: 0.7680 - val_loss: 0.4522 - val_accuracy: 0.7917
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4496 - accuracy: 0.7680 - val_loss: 0.4497 - val_accuracy: 0.7917
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4485 - accuracy: 0.7629 - val_loss: 0.4483 - val_accuracy: 0.7917
# Epoch 1/50
# 7/7 [==============================] - 1s 23ms/step - loss: 0.9059 - accuracy: 0.6443 - val_loss: 0.4953 - val_accuracy: 0.7500
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5808 - accuracy: 0.7423 - val_loss: 0.9108 - val_accuracy: 0.6250
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6044 - accuracy: 0.7680 - val_loss: 0.5545 - val_accuracy: 0.6875
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4719 - accuracy: 0.7423 - val_loss: 0.5594 - val_accuracy: 0.7708
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5309 - accuracy: 0.7320 - val_loss: 0.4856 - val_accuracy: 0.6875
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4302 - accuracy: 0.7629 - val_loss: 0.4501 - val_accuracy: 0.6875
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4163 - accuracy: 0.7887 - val_loss: 0.4952 - val_accuracy: 0.6667
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.7887 - val_loss: 0.4823 - val_accuracy: 0.7292
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3783 - accuracy: 0.7990 - val_loss: 0.5315 - val_accuracy: 0.7083
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3548 - accuracy: 0.8041 - val_loss: 0.5591 - val_accuracy: 0.6458
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3535 - accuracy: 0.8196 - val_loss: 0.5486 - val_accuracy: 0.7083
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4359 - accuracy: 0.8247 - val_loss: 0.5460 - val_accuracy: 0.7083
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3457 - accuracy: 0.8144 - val_loss: 0.5881 - val_accuracy: 0.6875
# Epoch 14/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3238 - accuracy: 0.8247 - val_loss: 0.6571 - val_accuracy: 0.7083
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3342 - accuracy: 0.8247 - val_loss: 0.6943 - val_accuracy: 0.7083
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3233 - accuracy: 0.8299 - val_loss: 0.5008 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3292 - accuracy: 0.8351 - val_loss: 0.4804 - val_accuracy: 0.7708
# Epoch 18/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3088 - accuracy: 0.8247 - val_loss: 0.5018 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2840 - accuracy: 0.8299 - val_loss: 0.5997 - val_accuracy: 0.7292
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2713 - accuracy: 0.8505 - val_loss: 0.6531 - val_accuracy: 0.7083
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2813 - accuracy: 0.8351 - val_loss: 0.8252 - val_accuracy: 0.6875
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3270 - accuracy: 0.8299 - val_loss: 0.8069 - val_accuracy: 0.7292
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8093 - val_loss: 0.5031 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3760 - accuracy: 0.7835 - val_loss: 0.7314 - val_accuracy: 0.7292
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3288 - accuracy: 0.7526 - val_loss: 0.5013 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3239 - accuracy: 0.7835 - val_loss: 0.4869 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3510 - accuracy: 0.7629 - val_loss: 0.4981 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3087 - accuracy: 0.7990 - val_loss: 0.6131 - val_accuracy: 0.6875
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3393 - accuracy: 0.7887 - val_loss: 0.7036 - val_accuracy: 0.6875
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3451 - accuracy: 0.7990 - val_loss: 0.4951 - val_accuracy: 0.6875
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3238 - accuracy: 0.8041 - val_loss: 0.4844 - val_accuracy: 0.7083
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3105 - accuracy: 0.8196 - val_loss: 0.5271 - val_accuracy: 0.7500
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3149 - accuracy: 0.8093 - val_loss: 0.4638 - val_accuracy: 0.7292
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3151 - accuracy: 0.7990 - val_loss: 0.4727 - val_accuracy: 0.6667
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3493 - accuracy: 0.7732 - val_loss: 0.5587 - val_accuracy: 0.6875
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3312 - accuracy: 0.7990 - val_loss: 0.6310 - val_accuracy: 0.7292
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0807 - accuracy: 0.7474 - val_loss: 0.6146 - val_accuracy: 0.6667
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7169 - accuracy: 0.7629 - val_loss: 0.6562 - val_accuracy: 0.6667
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4323 - accuracy: 0.7474 - val_loss: 0.7597 - val_accuracy: 0.7083
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3802 - accuracy: 0.7423 - val_loss: 0.7496 - val_accuracy: 0.7292
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3896 - accuracy: 0.7320 - val_loss: 0.7271 - val_accuracy: 0.7292
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3766 - accuracy: 0.7371 - val_loss: 0.7641 - val_accuracy: 0.7292
# Epoch 43/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4177 - accuracy: 0.7474 - val_loss: 0.9405 - val_accuracy: 0.7292
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4009 - accuracy: 0.7474 - val_loss: 0.4629 - val_accuracy: 0.7292
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5211 - accuracy: 0.7784 - val_loss: 0.4359 - val_accuracy: 0.7083
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4681 - accuracy: 0.7165 - val_loss: 0.4060 - val_accuracy: 0.7292
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4660 - accuracy: 0.7474 - val_loss: 0.4567 - val_accuracy: 0.7292
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4659 - accuracy: 0.7062 - val_loss: 0.4974 - val_accuracy: 0.6875
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4008 - accuracy: 0.7423 - val_loss: 0.5293 - val_accuracy: 0.6667
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3710 - accuracy: 0.7371 - val_loss: 0.5184 - val_accuracy: 0.6667
# Epoch 1/50
# 7/7 [==============================] - 1s 22ms/step - loss: 0.3655 - accuracy: 0.7577 - val_loss: 0.5193 - val_accuracy: 0.6667
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3640 - accuracy: 0.7577 - val_loss: 0.5211 - val_accuracy: 0.6667
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3630 - accuracy: 0.7629 - val_loss: 0.5230 - val_accuracy: 0.6667
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3620 - accuracy: 0.7577 - val_loss: 0.5245 - val_accuracy: 0.6667
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3610 - accuracy: 0.7577 - val_loss: 0.5261 - val_accuracy: 0.6667
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3603 - accuracy: 0.7577 - val_loss: 0.5273 - val_accuracy: 0.6667
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3595 - accuracy: 0.7577 - val_loss: 0.5285 - val_accuracy: 0.6667
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3590 - accuracy: 0.7577 - val_loss: 0.5300 - val_accuracy: 0.6667
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3585 - accuracy: 0.7577 - val_loss: 0.5320 - val_accuracy: 0.6667
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3580 - accuracy: 0.7577 - val_loss: 0.5352 - val_accuracy: 0.6667
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3577 - accuracy: 0.7577 - val_loss: 0.5372 - val_accuracy: 0.6667
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3573 - accuracy: 0.7577 - val_loss: 0.5391 - val_accuracy: 0.6667
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3567 - accuracy: 0.7577 - val_loss: 0.5407 - val_accuracy: 0.6667
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3564 - accuracy: 0.7577 - val_loss: 0.5417 - val_accuracy: 0.6667
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3561 - accuracy: 0.7577 - val_loss: 0.5423 - val_accuracy: 0.6667
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3556 - accuracy: 0.7577 - val_loss: 0.5432 - val_accuracy: 0.6667
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3553 - accuracy: 0.7629 - val_loss: 0.5440 - val_accuracy: 0.6667
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3548 - accuracy: 0.7629 - val_loss: 0.5455 - val_accuracy: 0.6667
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3545 - accuracy: 0.7629 - val_loss: 0.5461 - val_accuracy: 0.6667
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3542 - accuracy: 0.7629 - val_loss: 0.5467 - val_accuracy: 0.6667
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3540 - accuracy: 0.7629 - val_loss: 0.5474 - val_accuracy: 0.6667
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3536 - accuracy: 0.7629 - val_loss: 0.5483 - val_accuracy: 0.6667
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3535 - accuracy: 0.7629 - val_loss: 0.5496 - val_accuracy: 0.6667
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3533 - accuracy: 0.7629 - val_loss: 0.5508 - val_accuracy: 0.6667
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3530 - accuracy: 0.7629 - val_loss: 0.5520 - val_accuracy: 0.6667
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3530 - accuracy: 0.7629 - val_loss: 0.5531 - val_accuracy: 0.6667
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3529 - accuracy: 0.7629 - val_loss: 0.5537 - val_accuracy: 0.6667
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3526 - accuracy: 0.7629 - val_loss: 0.5536 - val_accuracy: 0.6667
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3525 - accuracy: 0.7629 - val_loss: 0.5529 - val_accuracy: 0.6667
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3522 - accuracy: 0.7680 - val_loss: 0.5530 - val_accuracy: 0.6667
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3520 - accuracy: 0.7680 - val_loss: 0.5531 - val_accuracy: 0.6667
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3518 - accuracy: 0.7680 - val_loss: 0.5533 - val_accuracy: 0.6667
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3516 - accuracy: 0.7680 - val_loss: 0.5541 - val_accuracy: 0.6667
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3513 - accuracy: 0.7680 - val_loss: 0.5547 - val_accuracy: 0.6667
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3512 - accuracy: 0.7680 - val_loss: 0.5552 - val_accuracy: 0.6458
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3510 - accuracy: 0.7629 - val_loss: 0.5556 - val_accuracy: 0.6458
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3508 - accuracy: 0.7629 - val_loss: 0.5556 - val_accuracy: 0.6458
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3507 - accuracy: 0.7629 - val_loss: 0.5561 - val_accuracy: 0.6458
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3505 - accuracy: 0.7629 - val_loss: 0.5577 - val_accuracy: 0.6458
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3503 - accuracy: 0.7629 - val_loss: 0.5585 - val_accuracy: 0.6458
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3502 - accuracy: 0.7629 - val_loss: 0.5590 - val_accuracy: 0.6458
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3501 - accuracy: 0.7629 - val_loss: 0.5600 - val_accuracy: 0.6458
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3500 - accuracy: 0.7629 - val_loss: 0.5605 - val_accuracy: 0.6458
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3498 - accuracy: 0.7629 - val_loss: 0.5611 - val_accuracy: 0.6458
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3497 - accuracy: 0.7680 - val_loss: 0.5615 - val_accuracy: 0.6458
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3495 - accuracy: 0.7680 - val_loss: 0.5625 - val_accuracy: 0.6458
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3494 - accuracy: 0.7629 - val_loss: 0.5629 - val_accuracy: 0.6458
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3492 - accuracy: 0.7680 - val_loss: 0.5627 - val_accuracy: 0.6458
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3490 - accuracy: 0.7680 - val_loss: 0.5635 - val_accuracy: 0.6458
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3489 - accuracy: 0.7680 - val_loss: 0.5625 - val_accuracy: 0.6458
# Epoch 1/50
# 7/7 [==============================] - 1s 24ms/step - loss: 0.4892 - accuracy: 0.7165 - val_loss: 0.5431 - val_accuracy: 0.6250
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5979 - accuracy: 0.6495 - val_loss: 0.4958 - val_accuracy: 0.7292
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5189 - accuracy: 0.7423 - val_loss: 0.5990 - val_accuracy: 0.6042
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4676 - accuracy: 0.6340 - val_loss: 0.6490 - val_accuracy: 0.6042
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4307 - accuracy: 0.7216 - val_loss: 0.5141 - val_accuracy: 0.7292
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4277 - accuracy: 0.7423 - val_loss: 0.4608 - val_accuracy: 0.7292
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4439 - accuracy: 0.7423 - val_loss: 0.4490 - val_accuracy: 0.7292
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4318 - accuracy: 0.6804 - val_loss: 0.5117 - val_accuracy: 0.7292
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4278 - accuracy: 0.7371 - val_loss: 0.4257 - val_accuracy: 0.7292
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4299 - accuracy: 0.7423 - val_loss: 0.4109 - val_accuracy: 0.7292
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4164 - accuracy: 0.6959 - val_loss: 0.4210 - val_accuracy: 0.7292
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4425 - accuracy: 0.7423 - val_loss: 0.4040 - val_accuracy: 0.7292
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4354 - accuracy: 0.6649 - val_loss: 0.4151 - val_accuracy: 0.7292
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4314 - accuracy: 0.7423 - val_loss: 0.4292 - val_accuracy: 0.7292
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4425 - accuracy: 0.7423 - val_loss: 0.4122 - val_accuracy: 0.7292
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4182 - accuracy: 0.7113 - val_loss: 0.6824 - val_accuracy: 0.6667
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5038 - accuracy: 0.6753 - val_loss: 0.4270 - val_accuracy: 0.6875
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4380 - accuracy: 0.6392 - val_loss: 0.4157 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4354 - accuracy: 0.7423 - val_loss: 0.4161 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4183 - accuracy: 0.7423 - val_loss: 0.4057 - val_accuracy: 0.7292
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4131 - accuracy: 0.7423 - val_loss: 0.4010 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4461 - accuracy: 0.7423 - val_loss: 0.4967 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4317 - accuracy: 0.7423 - val_loss: 0.4601 - val_accuracy: 0.7292
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4227 - accuracy: 0.7423 - val_loss: 0.4306 - val_accuracy: 0.7292
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4123 - accuracy: 0.7423 - val_loss: 0.4732 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4221 - accuracy: 0.7423 - val_loss: 0.6643 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4980 - accuracy: 0.6907 - val_loss: 0.4956 - val_accuracy: 0.6875
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4831 - accuracy: 0.6546 - val_loss: 0.4083 - val_accuracy: 0.7292
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4406 - accuracy: 0.7423 - val_loss: 0.3993 - val_accuracy: 0.7292
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4305 - accuracy: 0.7423 - val_loss: 0.4101 - val_accuracy: 0.7292
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4355 - accuracy: 0.7423 - val_loss: 0.4223 - val_accuracy: 0.7292
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4376 - accuracy: 0.7423 - val_loss: 0.4145 - val_accuracy: 0.7292
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4295 - accuracy: 0.7423 - val_loss: 0.4494 - val_accuracy: 0.7292
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4382 - accuracy: 0.7423 - val_loss: 0.5323 - val_accuracy: 0.7292
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4348 - accuracy: 0.7423 - val_loss: 0.5494 - val_accuracy: 0.6458
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4877 - accuracy: 0.6546 - val_loss: 0.5551 - val_accuracy: 0.6458
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4399 - accuracy: 0.6701 - val_loss: 0.4915 - val_accuracy: 0.7292
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4262 - accuracy: 0.7423 - val_loss: 0.5777 - val_accuracy: 0.7292
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5487 - accuracy: 0.6701 - val_loss: 0.6167 - val_accuracy: 0.6458
# Epoch 40/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4757 - accuracy: 0.7062 - val_loss: 0.4262 - val_accuracy: 0.7292
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4684 - accuracy: 0.7423 - val_loss: 0.4292 - val_accuracy: 0.7292
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4610 - accuracy: 0.7062 - val_loss: 0.4209 - val_accuracy: 0.6875
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4531 - accuracy: 0.6289 - val_loss: 0.4009 - val_accuracy: 0.7292
# Epoch 44/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4664 - accuracy: 0.7423 - val_loss: 0.4108 - val_accuracy: 0.7292
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4595 - accuracy: 0.7165 - val_loss: 0.4772 - val_accuracy: 0.6667
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4596 - accuracy: 0.6856 - val_loss: 0.4109 - val_accuracy: 0.7292
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4535 - accuracy: 0.7423 - val_loss: 0.4213 - val_accuracy: 0.7292
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4342 - accuracy: 0.7423 - val_loss: 0.4157 - val_accuracy: 0.7292
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4600 - accuracy: 0.6701 - val_loss: 0.4164 - val_accuracy: 0.7292
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4221 - accuracy: 0.7423 - val_loss: 0.4174 - val_accuracy: 0.7292

# %% [markdown]
# Graficar la pérdida de entrenamiento y validación

# %%
#Base
plt.plot(history.history['loss'], label='Perdida')
plt.plot(history.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Base")
plt.show()

#variacion 1
plt.plot(history_var1.history['loss'], label='Perdida')
plt.plot(history_var1.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 1")
plt.show()

#variacion 2
plt.plot(history_var2.history['loss'], label='Perdida')
plt.plot(history_var2.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 2")
plt.show()

#variacion 3
plt.plot(history_var3.history['loss'], label='Perdida')
plt.plot(history_var3.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 3")
plt.show()

# %% [markdown]
# Hacer predicciones en el set de prueba

# %%
#base 
y_true = []
y_pred = []
for x, y in test_ds:
    y_true.extend(list(y.numpy()))
    y_pred.extend(list(model.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin = [1 if pred >= 0.5 else 0 for pred in y_pred]

# varicacion 1
y_pred_var1 = []
for x, y in test_ds:
    y_pred_var1.extend(list(model_var1.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var1 = [1 if pred >= 0.5 else 0 for pred in y_pred_var1]


# varicacion 2
y_pred_var2 = []
for x, y in test_ds:
    y_pred_var2.extend(list(model_var2.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var2 = [1 if pred >= 0.5 else 0 for pred in y_pred_var2]


# varicacion 3
y_pred_var3 = []
for x, y in test_ds:
    y_pred_var3.extend(list(model_var3.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var3 = [1 if pred >= 0.5 else 0 for pred in y_pred_var3]
# Out:
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 88ms/step

# %% [markdown]
# Calcular las métricas

# %%
#base

from sklearn.metrics import classification_report, confusion_matrix

#base
# Calcular métricas
print("Base")
print(classification_report(y_true, y_pred_bin, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin))
# Out:
# Base
#                precision    recall  f1-score   support
#
# No enfermedad       0.66      1.00      0.79        40
#    Enfermedad       0.00      0.00      0.00        21
#
#      accuracy                           0.66        61
#     macro avg       0.33      0.50      0.40        61
#  weighted avg       0.43      0.66      0.52        61
#
# Matriz de confusión:
#  [[40  0]
#  [21  0]]
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#variacion 1
print("Variacion 1")
print(classification_report(y_true, y_pred_bin_var1, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var1))
# Out:
# Variacion 1
#                precision    recall  f1-score   support
#
# No enfermedad       0.66      1.00      0.79        40
#    Enfermedad       0.00      0.00      0.00        21
#
#      accuracy                           0.66        61
#     macro avg       0.33      0.50      0.40        61
#  weighted avg       0.43      0.66      0.52        61
#
# Matriz de confusión:
#  [[40  0]
#  [21  0]]
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#variacion 2
print("Variacion 2")
print(classification_report(y_true, y_pred_bin_var2, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var2))
# Out:
# Variacion 2
#                precision    recall  f1-score   support
#
# No enfermedad       0.66      1.00      0.79        40
#    Enfermedad       0.00      0.00      0.00        21
#
#      accuracy                           0.66        61
#     macro avg       0.33      0.50      0.40        61
#  weighted avg       0.43      0.66      0.52        61
#
# Matriz de confusión:
#  [[40  0]
#  [21  0]]
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#variacion 3
print("Variacion 3")
print(classification_report(y_true, y_pred_bin_var3, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var3))
# Out:
# Variacion 3
#                precision    recall  f1-score   support
#
# No enfermedad       0.66      1.00      0.79        40
#    Enfermedad       0.00      0.00      0.00        21
#
#      accuracy                           0.66        61
#     macro avg       0.33      0.50      0.40        61
#  weighted avg       0.43      0.66      0.52        61
#
# Matriz de confusión:
#  [[40  0]
#  [21  0]]
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
