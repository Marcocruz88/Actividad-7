# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 13-14: redes neuronales para clasificación
#
# - Redes densas
# - Redes para clasificación
# - Procesamiento de datos continuos y categóricos
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy, pandas, keras, tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# Descripción de las variables:
#
# https://archive.ics.uci.edu/dataset/45/heart+disease

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Definimos listas para las variables categóricas enteras, categóricas string y numéricas.

# %%
subset_feats = ['age', 'trestbps', 'chol', 'sex', 'cp']
df = df[subset_feats+['target']]

# %%
df.head()
# Out:
#    age  trestbps  chol  sex  cp  target
# 0   63       145   233    1   1       0
# 1   67       160   286    1   4       1
# 2   67       120   229    1   4       0
# 3   37       130   250    1   3       0
# 4   41       130   204    0   2       0

# %% [markdown]
# Separamos los datos en entrenamiento, validación y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#      age  trestbps  chol  sex  cp  target
# 69    35       138   183    0   4       0
# 300   65       135   254    1   4       1
# 220   59       134   204    1   1       0
# 134   42       120   240    1   3       0
# 7     57       120   354    0   4       0

# %%
train.shape
# Out:
# (242, 6)

# %%
test = df.drop(train.index)
test.head()
# Out:
#     age  trestbps  chol  sex  cp  target
# 0    63       145   233    1   1       0
# 2    67       120   229    1   4       0
# 4    41       130   204    0   2       0
# 8    63       130   254    1   4       1
# 13   44       120   263    1   2       0

# %%
val = train.sample(frac=0.2, random_state=100)

# %%
val.shape
# Out:
# (48, 6)

# %%
train = train.drop(val.index)

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (194, 6)
# (48, 6)
# (61, 6)

# %% [markdown]
# Calculamos estadísticas de cada variable numérica

# %%
train.describe()
# Out:
#               age    trestbps        chol         sex          cp      target
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    54.953608  132.876289  249.974227    0.664948    3.097938    0.257732
# std      8.754150   17.952879   52.803226    0.473230    1.030969    0.438517
# min     34.000000   94.000000  126.000000    0.000000    0.000000    0.000000
# 25%     49.000000  120.000000  215.750000    0.000000    2.000000    0.000000
# 50%     56.000000  130.000000  243.000000    1.000000    3.000000    0.000000
# 75%     61.000000  143.500000  281.000000    1.000000    4.000000    1.000000
# max     77.000000  192.000000  564.000000    1.000000    4.000000    1.000000

# %% [markdown]
# Función para convertir de dataframe (pandas) a dataset (tensorflow), separando características y etiquetas

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

# %%
train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %% [markdown]
# Ejemplo de cómo queda el tf.dataset

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=66>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=146>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=278>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=3>}
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# Separamos los datos de entrenamiento, validación y prueba en lotes

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Función para codificar variables numéricas (Keras docs)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

# %% [markdown]
# Función para codificar variables categóricas (Keras docs)

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# Creamos una lista de inputs para el modelo, de acuerdo con cada tipo de variable

# %%
inputs = {
    'age': keras.Input(shape=(1,), name='age'),
    'trestbps': keras.Input(shape=(1,), name='trestbps'),
    'chol': keras.Input(shape=(1,), name='chol'),
    'sex': keras.Input(shape=(1,), name='sex', dtype='int64'),
    'cp': keras.Input(shape=(1,), name='cp', dtype='int64')
}
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
for i in inputs:
   print(i)
# Out:
# age
# trestbps
# chol
# sex
# cp

# %% [markdown]
# Creamos una lista de variables codificadas/normalizadas de acuerdo con su tipo, empleando las funciones de codificación/normalización

# %%
feats_encoded = [
    encode_numerical_feature(inputs['age'], 'age', train_ds),
    encode_numerical_feature(inputs['trestbps'], 'trestbps', train_ds),
    encode_numerical_feature(inputs['chol'], 'chol', train_ds),
    encode_categorical_feature(inputs['sex'], 'sex', train_ds, False),  # 'sex' es categórica (entero)
    encode_categorical_feature(inputs['cp'], 'cp', train_ds, False)  # 'cp' es categórica (entero)
]
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.

# %%
len_feats = len(feats_encoded)
len_feats
# Out:
# 5

# %%
for i in feats_encoded:
  print(i)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization/truediv:0', description="created by layer 'normalization'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_1/truediv:0', description="created by layer 'normalization_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_2/truediv:0', description="created by layer 'normalization_2'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='integer_lookup/bincount/DenseBincount:0', description="created by layer 'integer_lookup'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 6), dtype=tf.float32, name=None), name='integer_lookup_1/bincount/DenseBincount:0', description="created by layer 'integer_lookup_1'")

# %% [markdown]
# Creamos una capa concatenando todas las variables codificadas

# %%
all_feats = keras.layers.concatenate(feats_encoded)

# %%
type(all_feats)
# Out:
# keras.src.engine.keras_tensor.KerasTensor

# %% [markdown]
# Agregamos una capa densa con 32 neuronas y función de activación relu

# %%
#Base
model_layers = keras.layers.Dense(32, activation='relu')(all_feats)

#variacion 1
model_layers_var1 = keras.layers.Dense(32, activation='relu')(all_feats)
model_layers_var1 = keras.layers.Dense(32, activation='relu')(model_layers_var1)

#variacion 2
model_layers_var2 = keras.layers.Dense(32, activation='relu')(all_feats)
model_layers_var2 = keras.layers.Dense(32, activation='relu')(model_layers_var2)
model_layers_var2 = keras.layers.Dense(32, activation='relu')(model_layers_var2)

#variacion 3
model_layers_var3 = keras.layers.Dense(32, activation='relu')(all_feats)
model_layers_var3 = keras.layers.Dense(32, activation='relu')(model_layers_var3)
model_layers_var3 = keras.layers.Dense(32, activation='relu')(model_layers_var3)
model_layers_var3 = keras.layers.Dense(32, activation='relu')(model_layers_var3)

# %% [markdown]
# Agregamos la capa de salida con 1 neurona (probabilidad de sufrir la enfermedad cardiada) y función de activación sigmoide

# %%
#Base
model_layers = keras.layers.Dense(1, activation='sigmoid')(model_layers)

#variacion 1
model_layers_var1 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var1)

#variacion 2
model_layers_var2 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var2)

#variacion 3
model_layers_var3 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var3)

# %% [markdown]
# Creamos el modelo con las capas ya creadas y las variables de entrada

# %%
#Base
model = keras.Model(inputs, model_layers)

#variacion 1
model_var1= keras.Model(inputs, model_layers_var1)

#Variacion 2
model_var2= keras.Model(inputs, model_layers_var2)

#Variacion 3
model_var3= keras.Model(inputs, model_layers_var3)

# %% [markdown]
# Compilamos el modelo, definiendo optimizador, función de pérdida y métricas adicionales a capturar

# %%
#Base
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#variacion 1
model_var1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 2
model_var2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 3
model_var3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Aseguramos que Keras use TensorFlow como backend, para asegurar que el modelo pueda usar strings como entradas

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# Entrenamos el modelo con los datos en el formato tf.Dataset

# %%
#Base 
history=model.fit(train_ds, epochs=50, validation_data=val_ds)

#variacion 1
history_var1=model_var1.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 2
history_var2=model_var2.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 3
history_var3=model_var3.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 7/7 [==============================] - 1s 30ms/step - loss: 0.6295 - accuracy: 0.7113 - val_loss: 0.6106 - val_accuracy: 0.6875
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6140 - accuracy: 0.7268 - val_loss: 0.5973 - val_accuracy: 0.7083
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6006 - accuracy: 0.7320 - val_loss: 0.5863 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5899 - accuracy: 0.7423 - val_loss: 0.5771 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5805 - accuracy: 0.7423 - val_loss: 0.5686 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5727 - accuracy: 0.7423 - val_loss: 0.5610 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5651 - accuracy: 0.7423 - val_loss: 0.5545 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5577 - accuracy: 0.7423 - val_loss: 0.5493 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5520 - accuracy: 0.7423 - val_loss: 0.5445 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5462 - accuracy: 0.7423 - val_loss: 0.5407 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5410 - accuracy: 0.7423 - val_loss: 0.5377 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5367 - accuracy: 0.7423 - val_loss: 0.5344 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5327 - accuracy: 0.7423 - val_loss: 0.5317 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5285 - accuracy: 0.7423 - val_loss: 0.5284 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5243 - accuracy: 0.7423 - val_loss: 0.5259 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5207 - accuracy: 0.7423 - val_loss: 0.5229 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5170 - accuracy: 0.7423 - val_loss: 0.5196 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5138 - accuracy: 0.7423 - val_loss: 0.5163 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5103 - accuracy: 0.7423 - val_loss: 0.5144 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5068 - accuracy: 0.7423 - val_loss: 0.5114 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5032 - accuracy: 0.7423 - val_loss: 0.5082 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4995 - accuracy: 0.7423 - val_loss: 0.5056 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4961 - accuracy: 0.7423 - val_loss: 0.5031 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4930 - accuracy: 0.7423 - val_loss: 0.5006 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4901 - accuracy: 0.7423 - val_loss: 0.4980 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4868 - accuracy: 0.7423 - val_loss: 0.4945 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4837 - accuracy: 0.7423 - val_loss: 0.4906 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4807 - accuracy: 0.7423 - val_loss: 0.4870 - val_accuracy: 0.7292
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4779 - accuracy: 0.7423 - val_loss: 0.4836 - val_accuracy: 0.7292
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4753 - accuracy: 0.7423 - val_loss: 0.4812 - val_accuracy: 0.7292
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4725 - accuracy: 0.7423 - val_loss: 0.4784 - val_accuracy: 0.7292
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4702 - accuracy: 0.7474 - val_loss: 0.4755 - val_accuracy: 0.7292
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4679 - accuracy: 0.7629 - val_loss: 0.4738 - val_accuracy: 0.7500
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4659 - accuracy: 0.7887 - val_loss: 0.4729 - val_accuracy: 0.7708
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4643 - accuracy: 0.7784 - val_loss: 0.4720 - val_accuracy: 0.7917
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4626 - accuracy: 0.7680 - val_loss: 0.4707 - val_accuracy: 0.7917
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4603 - accuracy: 0.7680 - val_loss: 0.4698 - val_accuracy: 0.7917
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4581 - accuracy: 0.7680 - val_loss: 0.4689 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4563 - accuracy: 0.7629 - val_loss: 0.4701 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4548 - accuracy: 0.7629 - val_loss: 0.4698 - val_accuracy: 0.7917
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4534 - accuracy: 0.7629 - val_loss: 0.4694 - val_accuracy: 0.7708
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4520 - accuracy: 0.7680 - val_loss: 0.4680 - val_accuracy: 0.7708
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4503 - accuracy: 0.7680 - val_loss: 0.4661 - val_accuracy: 0.7708
# Epoch 44/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4492 - accuracy: 0.7680 - val_loss: 0.4639 - val_accuracy: 0.7708
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4470 - accuracy: 0.7732 - val_loss: 0.4622 - val_accuracy: 0.7708
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4456 - accuracy: 0.7732 - val_loss: 0.4610 - val_accuracy: 0.7708
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4449 - accuracy: 0.7680 - val_loss: 0.4600 - val_accuracy: 0.7708
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4435 - accuracy: 0.7680 - val_loss: 0.4587 - val_accuracy: 0.7708
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4423 - accuracy: 0.7629 - val_loss: 0.4570 - val_accuracy: 0.7708
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4412 - accuracy: 0.7629 - val_loss: 0.4558 - val_accuracy: 0.7708
# Epoch 1/50
# 7/7 [==============================] - 1s 27ms/step - loss: 0.7063 - accuracy: 0.5103 - val_loss: 0.6670 - val_accuracy: 0.5417
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6630 - accuracy: 0.6392 - val_loss: 0.6276 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6348 - accuracy: 0.7320 - val_loss: 0.5973 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6127 - accuracy: 0.7423 - val_loss: 0.5806 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5983 - accuracy: 0.7423 - val_loss: 0.5713 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5873 - accuracy: 0.7423 - val_loss: 0.5638 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5776 - accuracy: 0.7423 - val_loss: 0.5553 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5684 - accuracy: 0.7423 - val_loss: 0.5464 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5582 - accuracy: 0.7423 - val_loss: 0.5394 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5494 - accuracy: 0.7423 - val_loss: 0.5325 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5410 - accuracy: 0.7423 - val_loss: 0.5264 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5336 - accuracy: 0.7423 - val_loss: 0.5231 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5272 - accuracy: 0.7423 - val_loss: 0.5181 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5206 - accuracy: 0.7423 - val_loss: 0.5130 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5130 - accuracy: 0.7423 - val_loss: 0.5066 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5069 - accuracy: 0.7423 - val_loss: 0.5011 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5007 - accuracy: 0.7423 - val_loss: 0.4957 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4935 - accuracy: 0.7423 - val_loss: 0.4944 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4885 - accuracy: 0.7474 - val_loss: 0.4911 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4833 - accuracy: 0.7474 - val_loss: 0.4861 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4786 - accuracy: 0.7474 - val_loss: 0.4819 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4760 - accuracy: 0.7474 - val_loss: 0.4777 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4709 - accuracy: 0.7474 - val_loss: 0.4749 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4675 - accuracy: 0.7474 - val_loss: 0.4725 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4630 - accuracy: 0.7474 - val_loss: 0.4712 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4589 - accuracy: 0.7474 - val_loss: 0.4693 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4565 - accuracy: 0.7680 - val_loss: 0.4653 - val_accuracy: 0.7708
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4533 - accuracy: 0.7732 - val_loss: 0.4632 - val_accuracy: 0.7708
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4492 - accuracy: 0.7835 - val_loss: 0.4598 - val_accuracy: 0.7917
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4455 - accuracy: 0.7835 - val_loss: 0.4559 - val_accuracy: 0.7708
# Epoch 31/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4426 - accuracy: 0.7835 - val_loss: 0.4526 - val_accuracy: 0.7500
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4398 - accuracy: 0.7938 - val_loss: 0.4523 - val_accuracy: 0.7500
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4371 - accuracy: 0.7938 - val_loss: 0.4497 - val_accuracy: 0.7500
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4335 - accuracy: 0.7887 - val_loss: 0.4495 - val_accuracy: 0.7500
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4310 - accuracy: 0.7938 - val_loss: 0.4508 - val_accuracy: 0.7500
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4290 - accuracy: 0.7887 - val_loss: 0.4480 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4285 - accuracy: 0.7835 - val_loss: 0.4445 - val_accuracy: 0.7500
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4262 - accuracy: 0.7835 - val_loss: 0.4430 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4238 - accuracy: 0.7835 - val_loss: 0.4417 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4218 - accuracy: 0.7887 - val_loss: 0.4414 - val_accuracy: 0.7917
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4199 - accuracy: 0.7835 - val_loss: 0.4410 - val_accuracy: 0.7917
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4182 - accuracy: 0.7887 - val_loss: 0.4377 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4165 - accuracy: 0.7887 - val_loss: 0.4344 - val_accuracy: 0.7708
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4140 - accuracy: 0.7887 - val_loss: 0.4332 - val_accuracy: 0.7708
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4107 - accuracy: 0.7835 - val_loss: 0.4350 - val_accuracy: 0.7708
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4099 - accuracy: 0.7732 - val_loss: 0.4366 - val_accuracy: 0.8125
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.7784 - val_loss: 0.4366 - val_accuracy: 0.7917
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4084 - accuracy: 0.7784 - val_loss: 0.4398 - val_accuracy: 0.7917
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4055 - accuracy: 0.7784 - val_loss: 0.4400 - val_accuracy: 0.7917
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4046 - accuracy: 0.7784 - val_loss: 0.4416 - val_accuracy: 0.7708
# Epoch 1/50
# 7/7 [==============================] - 1s 28ms/step - loss: 0.7101 - accuracy: 0.3454 - val_loss: 0.6908 - val_accuracy: 0.5417
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6709 - accuracy: 0.6959 - val_loss: 0.6592 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6454 - accuracy: 0.7423 - val_loss: 0.6374 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6253 - accuracy: 0.7423 - val_loss: 0.6124 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6039 - accuracy: 0.7423 - val_loss: 0.5910 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5867 - accuracy: 0.7423 - val_loss: 0.5756 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5713 - accuracy: 0.7423 - val_loss: 0.5582 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5536 - accuracy: 0.7423 - val_loss: 0.5437 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5406 - accuracy: 0.7423 - val_loss: 0.5318 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5283 - accuracy: 0.7423 - val_loss: 0.5219 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5161 - accuracy: 0.7423 - val_loss: 0.5118 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5049 - accuracy: 0.7423 - val_loss: 0.5024 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4939 - accuracy: 0.7423 - val_loss: 0.4925 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4841 - accuracy: 0.7423 - val_loss: 0.4837 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4750 - accuracy: 0.7423 - val_loss: 0.4771 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4671 - accuracy: 0.7423 - val_loss: 0.4725 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4601 - accuracy: 0.7423 - val_loss: 0.4720 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4577 - accuracy: 0.7474 - val_loss: 0.4680 - val_accuracy: 0.7292
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4532 - accuracy: 0.7474 - val_loss: 0.4630 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4486 - accuracy: 0.7577 - val_loss: 0.4555 - val_accuracy: 0.7292
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4435 - accuracy: 0.7577 - val_loss: 0.4493 - val_accuracy: 0.7292
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4378 - accuracy: 0.7577 - val_loss: 0.4442 - val_accuracy: 0.7292
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4333 - accuracy: 0.7629 - val_loss: 0.4389 - val_accuracy: 0.7292
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4319 - accuracy: 0.7629 - val_loss: 0.4372 - val_accuracy: 0.7292
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4289 - accuracy: 0.7680 - val_loss: 0.4321 - val_accuracy: 0.7708
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4242 - accuracy: 0.7784 - val_loss: 0.4260 - val_accuracy: 0.7708
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4200 - accuracy: 0.7732 - val_loss: 0.4226 - val_accuracy: 0.7708
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4143 - accuracy: 0.7887 - val_loss: 0.4220 - val_accuracy: 0.7708
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4109 - accuracy: 0.7990 - val_loss: 0.4229 - val_accuracy: 0.7708
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4067 - accuracy: 0.7990 - val_loss: 0.4202 - val_accuracy: 0.7708
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4030 - accuracy: 0.7784 - val_loss: 0.4228 - val_accuracy: 0.7917
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4055 - accuracy: 0.7732 - val_loss: 0.4252 - val_accuracy: 0.7917
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4045 - accuracy: 0.7732 - val_loss: 0.4226 - val_accuracy: 0.7917
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3984 - accuracy: 0.7887 - val_loss: 0.4173 - val_accuracy: 0.7917
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3953 - accuracy: 0.7887 - val_loss: 0.4174 - val_accuracy: 0.7917
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3923 - accuracy: 0.7990 - val_loss: 0.4190 - val_accuracy: 0.7917
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3892 - accuracy: 0.8093 - val_loss: 0.4153 - val_accuracy: 0.7917
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3865 - accuracy: 0.8093 - val_loss: 0.4162 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3857 - accuracy: 0.8144 - val_loss: 0.4202 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3849 - accuracy: 0.8196 - val_loss: 0.4206 - val_accuracy: 0.7917
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3795 - accuracy: 0.8093 - val_loss: 0.4180 - val_accuracy: 0.7917
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3771 - accuracy: 0.8041 - val_loss: 0.4223 - val_accuracy: 0.7708
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3758 - accuracy: 0.7990 - val_loss: 0.4200 - val_accuracy: 0.7708
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3734 - accuracy: 0.7990 - val_loss: 0.4142 - val_accuracy: 0.7708
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3728 - accuracy: 0.8144 - val_loss: 0.4135 - val_accuracy: 0.7917
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3705 - accuracy: 0.8093 - val_loss: 0.4172 - val_accuracy: 0.7500
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3683 - accuracy: 0.8093 - val_loss: 0.4261 - val_accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3678 - accuracy: 0.8299 - val_loss: 0.4282 - val_accuracy: 0.7500
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3656 - accuracy: 0.8299 - val_loss: 0.4316 - val_accuracy: 0.7708
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3676 - accuracy: 0.8093 - val_loss: 0.4504 - val_accuracy: 0.7708
# Epoch 1/50
# 7/7 [==============================] - 1s 25ms/step - loss: 0.6086 - accuracy: 0.7423 - val_loss: 0.6032 - val_accuracy: 0.7500
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5734 - accuracy: 0.7423 - val_loss: 0.5923 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5478 - accuracy: 0.7423 - val_loss: 0.5869 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5317 - accuracy: 0.7423 - val_loss: 0.5847 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5203 - accuracy: 0.7423 - val_loss: 0.5788 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5065 - accuracy: 0.7423 - val_loss: 0.5699 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4952 - accuracy: 0.7423 - val_loss: 0.5606 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4849 - accuracy: 0.7423 - val_loss: 0.5537 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4792 - accuracy: 0.7423 - val_loss: 0.5499 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4693 - accuracy: 0.7423 - val_loss: 0.5309 - val_accuracy: 0.7292
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4601 - accuracy: 0.7423 - val_loss: 0.5137 - val_accuracy: 0.7292
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4498 - accuracy: 0.7680 - val_loss: 0.5043 - val_accuracy: 0.7708
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4404 - accuracy: 0.7990 - val_loss: 0.4937 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4315 - accuracy: 0.8093 - val_loss: 0.4832 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4207 - accuracy: 0.8196 - val_loss: 0.4765 - val_accuracy: 0.7708
# Epoch 16/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4096 - accuracy: 0.8247 - val_loss: 0.4693 - val_accuracy: 0.7708
# Epoch 17/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4012 - accuracy: 0.8351 - val_loss: 0.4668 - val_accuracy: 0.7917
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3955 - accuracy: 0.8299 - val_loss: 0.4675 - val_accuracy: 0.8125
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3981 - accuracy: 0.8247 - val_loss: 0.4745 - val_accuracy: 0.7917
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3913 - accuracy: 0.8247 - val_loss: 0.4613 - val_accuracy: 0.8125
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3823 - accuracy: 0.8402 - val_loss: 0.4544 - val_accuracy: 0.8125
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3768 - accuracy: 0.8144 - val_loss: 0.4546 - val_accuracy: 0.8125
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3717 - accuracy: 0.8196 - val_loss: 0.4442 - val_accuracy: 0.8125
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3630 - accuracy: 0.8196 - val_loss: 0.4360 - val_accuracy: 0.8333
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3582 - accuracy: 0.8299 - val_loss: 0.4383 - val_accuracy: 0.7917
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3602 - accuracy: 0.8299 - val_loss: 0.4386 - val_accuracy: 0.7708
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3622 - accuracy: 0.8351 - val_loss: 0.4412 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3511 - accuracy: 0.8196 - val_loss: 0.4447 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3428 - accuracy: 0.8299 - val_loss: 0.4473 - val_accuracy: 0.7708
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3390 - accuracy: 0.8351 - val_loss: 0.4499 - val_accuracy: 0.7917
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3330 - accuracy: 0.8299 - val_loss: 0.4532 - val_accuracy: 0.7292
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3368 - accuracy: 0.8041 - val_loss: 0.4581 - val_accuracy: 0.7292
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3310 - accuracy: 0.8196 - val_loss: 0.4412 - val_accuracy: 0.7500
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3256 - accuracy: 0.8351 - val_loss: 0.4430 - val_accuracy: 0.7708
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3207 - accuracy: 0.8454 - val_loss: 0.4434 - val_accuracy: 0.7500
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3138 - accuracy: 0.8608 - val_loss: 0.4479 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3106 - accuracy: 0.8660 - val_loss: 0.4467 - val_accuracy: 0.7708
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3136 - accuracy: 0.8608 - val_loss: 0.4446 - val_accuracy: 0.7292
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3227 - accuracy: 0.8454 - val_loss: 0.4416 - val_accuracy: 0.7500
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3053 - accuracy: 0.8763 - val_loss: 0.4492 - val_accuracy: 0.7083
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3054 - accuracy: 0.8351 - val_loss: 0.4505 - val_accuracy: 0.7500
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2982 - accuracy: 0.8402 - val_loss: 0.4514 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2924 - accuracy: 0.8711 - val_loss: 0.4572 - val_accuracy: 0.7292
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2911 - accuracy: 0.8608 - val_loss: 0.4782 - val_accuracy: 0.7292
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2916 - accuracy: 0.8402 - val_loss: 0.4756 - val_accuracy: 0.7500
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2884 - accuracy: 0.8660 - val_loss: 0.4795 - val_accuracy: 0.7292
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2841 - accuracy: 0.8814 - val_loss: 0.4799 - val_accuracy: 0.7083
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2787 - accuracy: 0.8918 - val_loss: 0.4844 - val_accuracy: 0.7083
# Epoch 49/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2848 - accuracy: 0.8814 - val_loss: 0.4804 - val_accuracy: 0.7083
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2759 - accuracy: 0.8866 - val_loss: 0.4689 - val_accuracy: 0.7500

# %% [markdown]
# Graficar la pérdida de entrenamiento y validación

# %%
#Base
plt.plot(history.history['loss'], label='Perdida')
plt.plot(history.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Base")
plt.show()

#variacion 1
plt.plot(history_var1.history['loss'], label='Perdida')
plt.plot(history_var1.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 1")
plt.show()

#variacion 2
plt.plot(history_var2.history['loss'], label='Perdida')
plt.plot(history_var2.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 2")
plt.show()

#variacion 3
plt.plot(history_var3.history['loss'], label='Perdida')
plt.plot(history_var3.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 3")
plt.show()

# %% [markdown]
# Hacer predicciones en el set de prueba

# %%
#base 
y_true = []
y_pred = []
for x, y in test_ds:
    y_true.extend(list(y.numpy()))
    y_pred.extend(list(model.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin = [1 if pred >= 0.5 else 0 for pred in y_pred]

# varicacion 1
y_pred_var1 = []
for x, y in test_ds:
    y_pred_var1.extend(list(model_var1.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var1 = [1 if pred >= 0.5 else 0 for pred in y_pred_var1]


# varicacion 2
y_pred_var2 = []
for x, y in test_ds:
    y_pred_var2.extend(list(model_var2.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var2 = [1 if pred >= 0.5 else 0 for pred in y_pred_var2]


# varicacion 3
y_pred_var3 = []
for x, y in test_ds:
    y_pred_var3.extend(list(model_var3.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var3 = [1 if pred >= 0.5 else 0 for pred in y_pred_var3]
# Out:
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000207C4E5CA40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 105ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000207C4E5CA40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 118ms/step

# %% [markdown]
# Calcular las métricas

# %%
#base

from sklearn.metrics import classification_report, confusion_matrix

#base
# Calcular métricas
print("Base")
print(classification_report(y_true, y_pred_bin, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin))
# Out:
# Base
#                precision    recall  f1-score   support
#
# No enfermedad       0.70      0.93      0.80        40
#    Enfermedad       0.62      0.24      0.34        21
#
#      accuracy                           0.69        61
#     macro avg       0.66      0.58      0.57        61
#  weighted avg       0.67      0.69      0.64        61
#
# Matriz de confusión:
#  [[37  3]
#  [16  5]]

# %%
#variacion 1
print("Variacion 1")
print(classification_report(y_true, y_pred_bin_var1, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var1))
# Out:
# Variacion 1
#                precision    recall  f1-score   support
#
# No enfermedad       0.68      0.75      0.71        40
#    Enfermedad       0.41      0.33      0.37        21
#
#      accuracy                           0.61        61
#     macro avg       0.55      0.54      0.54        61
#  weighted avg       0.59      0.61      0.60        61
#
# Matriz de confusión:
#  [[30 10]
#  [14  7]]

# %%
#variacion 2
print("Variacion 2")
print(classification_report(y_true, y_pred_bin_var2, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var2))
# Out:
# Variacion 2
#                precision    recall  f1-score   support
#
# No enfermedad       0.71      0.88      0.79        40
#    Enfermedad       0.58      0.33      0.42        21
#
#      accuracy                           0.69        61
#     macro avg       0.65      0.60      0.61        61
#  weighted avg       0.67      0.69      0.66        61
#
# Matriz de confusión:
#  [[35  5]
#  [14  7]]

# %%
#variacion 3
print("Variacion 3")
print(classification_report(y_true, y_pred_bin_var3, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var3))
# Out:
# Variacion 3
#                precision    recall  f1-score   support
#
# No enfermedad       0.66      0.78      0.71        40
#    Enfermedad       0.36      0.24      0.29        21
#
#      accuracy                           0.59        61
#     macro avg       0.51      0.51      0.50        61
#  weighted avg       0.56      0.59      0.57        61
#
# Matriz de confusión:
#  [[31  9]
#  [16  5]]
