# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 13-14: redes neuronales para clasificación
#
# - Redes densas
# - Redes para clasificación
# - Procesamiento de datos continuos y categóricos
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy, pandas, keras, tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# Descripción de las variables:
#
# https://archive.ics.uci.edu/dataset/45/heart+disease

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Definimos listas para las variables categóricas enteras, categóricas string y numéricas.

# %%
subset_feats = ['age', 'trestbps', 'chol', 'sex', 'cp']
df = df[subset_feats+['target']]

# %%
df.head()
# Out:
#    age  trestbps  chol  sex  cp  target
# 0   63       145   233    1   1       0
# 1   67       160   286    1   4       1
# 2   67       120   229    1   4       0
# 3   37       130   250    1   3       0
# 4   41       130   204    0   2       0

# %% [markdown]
# Separamos los datos en entrenamiento, validación y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#      age  trestbps  chol  sex  cp  target
# 69    35       138   183    0   4       0
# 300   65       135   254    1   4       1
# 220   59       134   204    1   1       0
# 134   42       120   240    1   3       0
# 7     57       120   354    0   4       0

# %%
train.shape
# Out:
# (242, 6)

# %%
test = df.drop(train.index)
test.head()
# Out:
#     age  trestbps  chol  sex  cp  target
# 0    63       145   233    1   1       0
# 2    67       120   229    1   4       0
# 4    41       130   204    0   2       0
# 8    63       130   254    1   4       1
# 13   44       120   263    1   2       0

# %%
val = train.sample(frac=0.2, random_state=100)

# %%
val.shape
# Out:
# (48, 6)

# %%
train = train.drop(val.index)

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (194, 6)
# (48, 6)
# (61, 6)

# %% [markdown]
# Calculamos estadísticas de cada variable numérica

# %%
train.describe()
# Out:
#               age    trestbps        chol         sex          cp      target
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    54.953608  132.876289  249.974227    0.664948    3.097938    0.257732
# std      8.754150   17.952879   52.803226    0.473230    1.030969    0.438517
# min     34.000000   94.000000  126.000000    0.000000    0.000000    0.000000
# 25%     49.000000  120.000000  215.750000    0.000000    2.000000    0.000000
# 50%     56.000000  130.000000  243.000000    1.000000    3.000000    0.000000
# 75%     61.000000  143.500000  281.000000    1.000000    4.000000    1.000000
# max     77.000000  192.000000  564.000000    1.000000    4.000000    1.000000

# %% [markdown]
# Función para convertir de dataframe (pandas) a dataset (tensorflow), separando características y etiquetas

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

# %%
train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %% [markdown]
# Ejemplo de cómo queda el tf.dataset

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=64>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=145>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=212>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=4>}
# Target: tf.Tensor(1, shape=(), dtype=int64)

# %% [markdown]
# Separamos los datos de entrenamiento, validación y prueba en lotes

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Función para codificar variables numéricas (Keras docs)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

# %% [markdown]
# Función para codificar variables categóricas (Keras docs)

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# Creamos una lista de inputs para el modelo, de acuerdo con cada tipo de variable

# %%
inputs = {
    'age': keras.Input(shape=(1,), name='age'),
    'trestbps': keras.Input(shape=(1,), name='trestbps'),
    'chol': keras.Input(shape=(1,), name='chol'),
    'sex': keras.Input(shape=(1,), name='sex', dtype='int64'),
    'cp': keras.Input(shape=(1,), name='cp', dtype='int64')
}
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
for i in inputs:
   print(i)
# Out:
# age
# trestbps
# chol
# sex
# cp

# %% [markdown]
# Creamos una lista de variables codificadas/normalizadas de acuerdo con su tipo, empleando las funciones de codificación/normalización

# %%
feats_encoded = [
    encode_numerical_feature(inputs['age'], 'age', train_ds),
    encode_numerical_feature(inputs['trestbps'], 'trestbps', train_ds),
    encode_numerical_feature(inputs['chol'], 'chol', train_ds),
    encode_categorical_feature(inputs['sex'], 'sex', train_ds, False),  # 'sex' es categórica (entero)
    encode_categorical_feature(inputs['cp'], 'cp', train_ds, False)  # 'cp' es categórica (entero)
]
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.

# %%
len_feats = len(feats_encoded)
len_feats
# Out:
# 5

# %%
for i in feats_encoded:
  print(i)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization/truediv:0', description="created by layer 'normalization'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_1/truediv:0', description="created by layer 'normalization_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_2/truediv:0', description="created by layer 'normalization_2'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='integer_lookup/bincount/DenseBincount:0', description="created by layer 'integer_lookup'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 6), dtype=tf.float32, name=None), name='integer_lookup_1/bincount/DenseBincount:0', description="created by layer 'integer_lookup_1'")

# %% [markdown]
# Creamos una capa concatenando todas las variables codificadas

# %%
all_feats = keras.layers.concatenate(feats_encoded)

# %%
type(all_feats)
# Out:
# keras.src.engine.keras_tensor.KerasTensor

# %% [markdown]
# Agregamos una capa densa con 32 neuronas y función de activación relu

# %%
#Base
model_layers = keras.layers.Dense(32, activation='relu')(all_feats)

#variacion 1
model_layers_var1 = keras.layers.Dense(32, activation='relu')(all_feats)
model_layers_var1 = keras.layers.Dense(32, activation='relu')(model_layers_var1)

#variacion 2
model_layers_var2 = keras.layers.Dense(32, activation='relu')(all_feats)
model_layers_var2 = keras.layers.Dense(32, activation='relu')(model_layers_var2)
model_layers_var2 = keras.layers.Dense(32, activation='relu')(model_layers_var2)

#variacion 3
model_layers_var3 = keras.layers.Dense(32, activation='relu')(all_feats)
model_layers_var3 = keras.layers.Dense(32, activation='relu')(model_layers_var3)
model_layers_var3 = keras.layers.Dense(32, activation='relu')(model_layers_var3)
model_layers_var3 = keras.layers.Dense(32, activation='relu')(model_layers_var3)

# %% [markdown]
# Agregamos la capa de salida con 1 neurona (probabilidad de sufrir la enfermedad cardiada) y función de activación sigmoide

# %%
#Base
model_layers = keras.layers.Dense(1, activation='sigmoid')(model_layers)

#variacion 1
model_layers_var1 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var1)

#variacion 2
model_layers_var2 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var2)

#variacion 3
model_layers_var3 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var3)

# %% [markdown]
# Creamos el modelo con las capas ya creadas y las variables de entrada

# %%
#Base
model = keras.Model(inputs, model_layers)

#variacion 1
model_var1= keras.Model(inputs, model_layers_var1)

#Variacion 2
model_var2= keras.Model(inputs, model_layers_var2)

#Variacion 3
model_var3= keras.Model(inputs, model_layers_var3)

# %% [markdown]
# Compilamos el modelo, definiendo optimizador, función de pérdida y métricas adicionales a capturar

# %%
#Base
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#variacion 1
model_var1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 2
model_var2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 3
model_var3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Aseguramos que Keras use TensorFlow como backend, para asegurar que el modelo pueda usar strings como entradas

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# Entrenamos el modelo con los datos en el formato tf.Dataset

# %%
#Base 
history=model.fit(train_ds, epochs=50, validation_data=val_ds)

#variacion 1
history_var1=model_var1.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 2
history_var2=model_var2.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 3
history_var3=model_var3.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 7/7 [==============================] - 1s 24ms/step - loss: 0.6652 - accuracy: 0.6443 - val_loss: 0.6471 - val_accuracy: 0.6875
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6472 - accuracy: 0.6959 - val_loss: 0.6304 - val_accuracy: 0.7292
# Epoch 3/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6306 - accuracy: 0.7320 - val_loss: 0.6164 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6173 - accuracy: 0.7371 - val_loss: 0.6035 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6052 - accuracy: 0.7423 - val_loss: 0.5918 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5948 - accuracy: 0.7423 - val_loss: 0.5812 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5848 - accuracy: 0.7423 - val_loss: 0.5723 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5764 - accuracy: 0.7423 - val_loss: 0.5640 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5678 - accuracy: 0.7423 - val_loss: 0.5560 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5605 - accuracy: 0.7423 - val_loss: 0.5485 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5531 - accuracy: 0.7423 - val_loss: 0.5417 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5463 - accuracy: 0.7423 - val_loss: 0.5358 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5401 - accuracy: 0.7423 - val_loss: 0.5298 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5343 - accuracy: 0.7423 - val_loss: 0.5236 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5284 - accuracy: 0.7423 - val_loss: 0.5176 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5228 - accuracy: 0.7423 - val_loss: 0.5125 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5178 - accuracy: 0.7423 - val_loss: 0.5071 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5127 - accuracy: 0.7423 - val_loss: 0.5027 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5083 - accuracy: 0.7423 - val_loss: 0.4997 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5042 - accuracy: 0.7423 - val_loss: 0.4956 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5000 - accuracy: 0.7474 - val_loss: 0.4913 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4958 - accuracy: 0.7474 - val_loss: 0.4867 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4918 - accuracy: 0.7577 - val_loss: 0.4829 - val_accuracy: 0.7292
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4881 - accuracy: 0.7577 - val_loss: 0.4796 - val_accuracy: 0.7292
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4848 - accuracy: 0.7577 - val_loss: 0.4765 - val_accuracy: 0.7292
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4815 - accuracy: 0.7577 - val_loss: 0.4739 - val_accuracy: 0.7292
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4793 - accuracy: 0.7577 - val_loss: 0.4705 - val_accuracy: 0.7292
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4767 - accuracy: 0.7577 - val_loss: 0.4680 - val_accuracy: 0.7292
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4742 - accuracy: 0.7423 - val_loss: 0.4649 - val_accuracy: 0.7292
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4714 - accuracy: 0.7577 - val_loss: 0.4620 - val_accuracy: 0.7500
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4692 - accuracy: 0.7629 - val_loss: 0.4605 - val_accuracy: 0.7708
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4673 - accuracy: 0.7474 - val_loss: 0.4584 - val_accuracy: 0.7708
# Epoch 33/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4646 - accuracy: 0.7526 - val_loss: 0.4563 - val_accuracy: 0.7500
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4624 - accuracy: 0.7526 - val_loss: 0.4538 - val_accuracy: 0.7500
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4602 - accuracy: 0.7474 - val_loss: 0.4510 - val_accuracy: 0.7292
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4577 - accuracy: 0.7474 - val_loss: 0.4493 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4557 - accuracy: 0.7474 - val_loss: 0.4476 - val_accuracy: 0.7708
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4537 - accuracy: 0.7526 - val_loss: 0.4451 - val_accuracy: 0.7708
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4517 - accuracy: 0.7526 - val_loss: 0.4426 - val_accuracy: 0.7708
# Epoch 40/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4499 - accuracy: 0.7577 - val_loss: 0.4407 - val_accuracy: 0.7708
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4479 - accuracy: 0.7577 - val_loss: 0.4397 - val_accuracy: 0.7708
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4462 - accuracy: 0.7577 - val_loss: 0.4390 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4449 - accuracy: 0.7577 - val_loss: 0.4381 - val_accuracy: 0.7917
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4432 - accuracy: 0.7732 - val_loss: 0.4377 - val_accuracy: 0.7917
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4418 - accuracy: 0.7784 - val_loss: 0.4368 - val_accuracy: 0.7917
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4404 - accuracy: 0.7835 - val_loss: 0.4360 - val_accuracy: 0.7917
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4391 - accuracy: 0.7835 - val_loss: 0.4357 - val_accuracy: 0.7708
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4384 - accuracy: 0.7887 - val_loss: 0.4368 - val_accuracy: 0.7500
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4379 - accuracy: 0.7887 - val_loss: 0.4381 - val_accuracy: 0.7500
# Epoch 50/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4377 - accuracy: 0.7784 - val_loss: 0.4381 - val_accuracy: 0.7500
# Epoch 1/50
# 7/7 [==============================] - 1s 22ms/step - loss: 0.7192 - accuracy: 0.4175 - val_loss: 0.6778 - val_accuracy: 0.6042
# Epoch 2/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6800 - accuracy: 0.5567 - val_loss: 0.6460 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6527 - accuracy: 0.6392 - val_loss: 0.6221 - val_accuracy: 0.7708
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6309 - accuracy: 0.6804 - val_loss: 0.5991 - val_accuracy: 0.7708
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6096 - accuracy: 0.7629 - val_loss: 0.5795 - val_accuracy: 0.7083
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5911 - accuracy: 0.7835 - val_loss: 0.5649 - val_accuracy: 0.7083
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5773 - accuracy: 0.7680 - val_loss: 0.5522 - val_accuracy: 0.7083
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5653 - accuracy: 0.7629 - val_loss: 0.5415 - val_accuracy: 0.7292
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5541 - accuracy: 0.7526 - val_loss: 0.5337 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5453 - accuracy: 0.7423 - val_loss: 0.5251 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5356 - accuracy: 0.7423 - val_loss: 0.5186 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5276 - accuracy: 0.7423 - val_loss: 0.5127 - val_accuracy: 0.7292
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5200 - accuracy: 0.7474 - val_loss: 0.5076 - val_accuracy: 0.7292
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5130 - accuracy: 0.7577 - val_loss: 0.5022 - val_accuracy: 0.7292
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5053 - accuracy: 0.7577 - val_loss: 0.4977 - val_accuracy: 0.7292
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4988 - accuracy: 0.7577 - val_loss: 0.4921 - val_accuracy: 0.7292
# Epoch 17/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4941 - accuracy: 0.7784 - val_loss: 0.4886 - val_accuracy: 0.7292
# Epoch 18/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4896 - accuracy: 0.7835 - val_loss: 0.4849 - val_accuracy: 0.7292
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4850 - accuracy: 0.7887 - val_loss: 0.4808 - val_accuracy: 0.7708
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4794 - accuracy: 0.7784 - val_loss: 0.4759 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4732 - accuracy: 0.7784 - val_loss: 0.4724 - val_accuracy: 0.7708
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4694 - accuracy: 0.7784 - val_loss: 0.4687 - val_accuracy: 0.7708
# Epoch 23/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4665 - accuracy: 0.7680 - val_loss: 0.4651 - val_accuracy: 0.7708
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4636 - accuracy: 0.7680 - val_loss: 0.4612 - val_accuracy: 0.7708
# Epoch 25/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4598 - accuracy: 0.7680 - val_loss: 0.4574 - val_accuracy: 0.7917
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4545 - accuracy: 0.7784 - val_loss: 0.4548 - val_accuracy: 0.7708
# Epoch 27/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4489 - accuracy: 0.7680 - val_loss: 0.4527 - val_accuracy: 0.7708
# Epoch 28/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4451 - accuracy: 0.7526 - val_loss: 0.4542 - val_accuracy: 0.7917
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4439 - accuracy: 0.7680 - val_loss: 0.4541 - val_accuracy: 0.7917
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4415 - accuracy: 0.7629 - val_loss: 0.4520 - val_accuracy: 0.7708
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4385 - accuracy: 0.7680 - val_loss: 0.4503 - val_accuracy: 0.7708
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4360 - accuracy: 0.7629 - val_loss: 0.4479 - val_accuracy: 0.7708
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4354 - accuracy: 0.7577 - val_loss: 0.4455 - val_accuracy: 0.7917
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4306 - accuracy: 0.7680 - val_loss: 0.4440 - val_accuracy: 0.7917
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4277 - accuracy: 0.7680 - val_loss: 0.4421 - val_accuracy: 0.7917
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4250 - accuracy: 0.7680 - val_loss: 0.4406 - val_accuracy: 0.7917
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4237 - accuracy: 0.7732 - val_loss: 0.4380 - val_accuracy: 0.7917
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4205 - accuracy: 0.7732 - val_loss: 0.4358 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4183 - accuracy: 0.7784 - val_loss: 0.4333 - val_accuracy: 0.8125
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4163 - accuracy: 0.7680 - val_loss: 0.4304 - val_accuracy: 0.8125
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4150 - accuracy: 0.7887 - val_loss: 0.4280 - val_accuracy: 0.7917
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4146 - accuracy: 0.7835 - val_loss: 0.4274 - val_accuracy: 0.8125
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4120 - accuracy: 0.7887 - val_loss: 0.4266 - val_accuracy: 0.8125
# Epoch 44/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.7887 - val_loss: 0.4246 - val_accuracy: 0.7917
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4063 - accuracy: 0.7990 - val_loss: 0.4256 - val_accuracy: 0.7917
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4046 - accuracy: 0.8041 - val_loss: 0.4266 - val_accuracy: 0.7917
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4030 - accuracy: 0.8093 - val_loss: 0.4269 - val_accuracy: 0.7917
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4012 - accuracy: 0.8041 - val_loss: 0.4260 - val_accuracy: 0.7708
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4002 - accuracy: 0.7990 - val_loss: 0.4249 - val_accuracy: 0.7917
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3987 - accuracy: 0.8041 - val_loss: 0.4261 - val_accuracy: 0.8125
# Epoch 1/50
# 7/7 [==============================] - 1s 24ms/step - loss: 0.7628 - accuracy: 0.2629 - val_loss: 0.7079 - val_accuracy: 0.3750
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6915 - accuracy: 0.5206 - val_loss: 0.6580 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6473 - accuracy: 0.7062 - val_loss: 0.6235 - val_accuracy: 0.7708
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6156 - accuracy: 0.7423 - val_loss: 0.5952 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5855 - accuracy: 0.7423 - val_loss: 0.5712 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5620 - accuracy: 0.7423 - val_loss: 0.5540 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5433 - accuracy: 0.7423 - val_loss: 0.5411 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5317 - accuracy: 0.7423 - val_loss: 0.5320 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5208 - accuracy: 0.7423 - val_loss: 0.5229 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5115 - accuracy: 0.7423 - val_loss: 0.5158 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5026 - accuracy: 0.7423 - val_loss: 0.5083 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4936 - accuracy: 0.7423 - val_loss: 0.4982 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4835 - accuracy: 0.7474 - val_loss: 0.4905 - val_accuracy: 0.7708
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4768 - accuracy: 0.7371 - val_loss: 0.4850 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4698 - accuracy: 0.7526 - val_loss: 0.4812 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4642 - accuracy: 0.7526 - val_loss: 0.4768 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4612 - accuracy: 0.7526 - val_loss: 0.4741 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4548 - accuracy: 0.7526 - val_loss: 0.4710 - val_accuracy: 0.7292
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4507 - accuracy: 0.7526 - val_loss: 0.4668 - val_accuracy: 0.7083
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4452 - accuracy: 0.7526 - val_loss: 0.4608 - val_accuracy: 0.7083
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4401 - accuracy: 0.7784 - val_loss: 0.4548 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4366 - accuracy: 0.7784 - val_loss: 0.4494 - val_accuracy: 0.7708
# Epoch 23/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4329 - accuracy: 0.7835 - val_loss: 0.4457 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4287 - accuracy: 0.7784 - val_loss: 0.4448 - val_accuracy: 0.7708
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4260 - accuracy: 0.7732 - val_loss: 0.4428 - val_accuracy: 0.7708
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4236 - accuracy: 0.7887 - val_loss: 0.4439 - val_accuracy: 0.7708
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4200 - accuracy: 0.7938 - val_loss: 0.4436 - val_accuracy: 0.7708
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4183 - accuracy: 0.7887 - val_loss: 0.4493 - val_accuracy: 0.7708
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4188 - accuracy: 0.7835 - val_loss: 0.4516 - val_accuracy: 0.7708
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4158 - accuracy: 0.7835 - val_loss: 0.4498 - val_accuracy: 0.7708
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4163 - accuracy: 0.7784 - val_loss: 0.4525 - val_accuracy: 0.7708
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4146 - accuracy: 0.7887 - val_loss: 0.4520 - val_accuracy: 0.7708
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4128 - accuracy: 0.7887 - val_loss: 0.4509 - val_accuracy: 0.7708
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4088 - accuracy: 0.7938 - val_loss: 0.4513 - val_accuracy: 0.7708
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4078 - accuracy: 0.7938 - val_loss: 0.4532 - val_accuracy: 0.7500
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.7887 - val_loss: 0.4519 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4044 - accuracy: 0.7887 - val_loss: 0.4497 - val_accuracy: 0.7500
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4000 - accuracy: 0.7784 - val_loss: 0.4461 - val_accuracy: 0.7708
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3984 - accuracy: 0.7938 - val_loss: 0.4468 - val_accuracy: 0.7708
# Epoch 40/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.7990 - val_loss: 0.4462 - val_accuracy: 0.7708
# Epoch 41/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3910 - accuracy: 0.7887 - val_loss: 0.4462 - val_accuracy: 0.7708
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3884 - accuracy: 0.7938 - val_loss: 0.4450 - val_accuracy: 0.7708
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3859 - accuracy: 0.7938 - val_loss: 0.4477 - val_accuracy: 0.7708
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3847 - accuracy: 0.8041 - val_loss: 0.4475 - val_accuracy: 0.7708
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3833 - accuracy: 0.8144 - val_loss: 0.4433 - val_accuracy: 0.7708
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3797 - accuracy: 0.8041 - val_loss: 0.4421 - val_accuracy: 0.7708
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3772 - accuracy: 0.7887 - val_loss: 0.4425 - val_accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3733 - accuracy: 0.8041 - val_loss: 0.4361 - val_accuracy: 0.7708
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3715 - accuracy: 0.8041 - val_loss: 0.4316 - val_accuracy: 0.7708
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3689 - accuracy: 0.8093 - val_loss: 0.4320 - val_accuracy: 0.7708
# Epoch 1/50
# 7/7 [==============================] - 1s 23ms/step - loss: 0.6933 - accuracy: 0.5515 - val_loss: 0.6663 - val_accuracy: 0.7500
# Epoch 2/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6548 - accuracy: 0.7423 - val_loss: 0.6379 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6311 - accuracy: 0.7423 - val_loss: 0.6167 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6133 - accuracy: 0.7423 - val_loss: 0.5989 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5974 - accuracy: 0.7423 - val_loss: 0.5844 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5791 - accuracy: 0.7423 - val_loss: 0.5652 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5622 - accuracy: 0.7423 - val_loss: 0.5524 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5496 - accuracy: 0.7423 - val_loss: 0.5399 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5393 - accuracy: 0.7423 - val_loss: 0.5276 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5241 - accuracy: 0.7423 - val_loss: 0.5118 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5106 - accuracy: 0.7423 - val_loss: 0.4992 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5017 - accuracy: 0.7423 - val_loss: 0.4881 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4915 - accuracy: 0.7423 - val_loss: 0.4756 - val_accuracy: 0.7708
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4799 - accuracy: 0.7474 - val_loss: 0.4609 - val_accuracy: 0.7917
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4679 - accuracy: 0.7474 - val_loss: 0.4499 - val_accuracy: 0.7708
# Epoch 16/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4610 - accuracy: 0.7474 - val_loss: 0.4408 - val_accuracy: 0.7917
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4525 - accuracy: 0.7423 - val_loss: 0.4365 - val_accuracy: 0.7917
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4425 - accuracy: 0.7732 - val_loss: 0.4311 - val_accuracy: 0.8125
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4330 - accuracy: 0.7887 - val_loss: 0.4259 - val_accuracy: 0.8125
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4267 - accuracy: 0.7732 - val_loss: 0.4192 - val_accuracy: 0.7917
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4189 - accuracy: 0.7680 - val_loss: 0.4145 - val_accuracy: 0.8125
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4147 - accuracy: 0.7732 - val_loss: 0.4062 - val_accuracy: 0.8125
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4091 - accuracy: 0.7887 - val_loss: 0.4012 - val_accuracy: 0.8125
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4034 - accuracy: 0.7990 - val_loss: 0.4002 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4003 - accuracy: 0.8093 - val_loss: 0.4008 - val_accuracy: 0.7708
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3961 - accuracy: 0.8041 - val_loss: 0.4028 - val_accuracy: 0.7917
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3937 - accuracy: 0.8093 - val_loss: 0.4232 - val_accuracy: 0.7917
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3919 - accuracy: 0.8093 - val_loss: 0.4260 - val_accuracy: 0.7708
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3858 - accuracy: 0.7938 - val_loss: 0.4223 - val_accuracy: 0.7292
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3810 - accuracy: 0.8093 - val_loss: 0.4132 - val_accuracy: 0.7708
# Epoch 31/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3865 - accuracy: 0.8093 - val_loss: 0.4011 - val_accuracy: 0.7917
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3753 - accuracy: 0.8247 - val_loss: 0.3907 - val_accuracy: 0.7917
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3702 - accuracy: 0.8093 - val_loss: 0.4009 - val_accuracy: 0.7708
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3682 - accuracy: 0.8093 - val_loss: 0.3906 - val_accuracy: 0.7708
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3596 - accuracy: 0.8351 - val_loss: 0.3867 - val_accuracy: 0.7917
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3589 - accuracy: 0.8402 - val_loss: 0.3861 - val_accuracy: 0.8333
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3553 - accuracy: 0.8247 - val_loss: 0.3909 - val_accuracy: 0.8333
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3515 - accuracy: 0.8351 - val_loss: 0.3925 - val_accuracy: 0.8125
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3481 - accuracy: 0.8351 - val_loss: 0.3937 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3456 - accuracy: 0.8351 - val_loss: 0.4100 - val_accuracy: 0.7500
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3498 - accuracy: 0.8351 - val_loss: 0.3965 - val_accuracy: 0.8125
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3437 - accuracy: 0.8299 - val_loss: 0.3905 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3503 - accuracy: 0.8299 - val_loss: 0.3870 - val_accuracy: 0.7917
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3356 - accuracy: 0.8402 - val_loss: 0.3984 - val_accuracy: 0.7500
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3372 - accuracy: 0.8351 - val_loss: 0.4062 - val_accuracy: 0.7500
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3398 - accuracy: 0.8402 - val_loss: 0.4164 - val_accuracy: 0.7917
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3314 - accuracy: 0.8505 - val_loss: 0.4064 - val_accuracy: 0.7917
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3282 - accuracy: 0.8505 - val_loss: 0.4089 - val_accuracy: 0.7708
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3265 - accuracy: 0.8557 - val_loss: 0.4198 - val_accuracy: 0.8125
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3214 - accuracy: 0.8299 - val_loss: 0.4145 - val_accuracy: 0.7917

# %% [markdown]
# Graficar la pérdida de entrenamiento y validación

# %%
#Base
plt.plot(history.history['loss'], label='Perdida')
plt.plot(history.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Base")
plt.show()

#variacion 1
plt.plot(history_var1.history['loss'], label='Perdida')
plt.plot(history_var1.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 1")
plt.show()

#variacion 2
plt.plot(history_var2.history['loss'], label='Perdida')
plt.plot(history_var2.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 2")
plt.show()

#variacion 3
plt.plot(history_var3.history['loss'], label='Perdida')
plt.plot(history_var3.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 3")
plt.show()

# %% [markdown]
# Hacer predicciones en el set de prueba

# %%
#base 
y_true = []
y_pred = []
for x, y in test_ds:
    y_true.extend(list(y.numpy()))
    y_pred.extend(list(model.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin = [1 if pred >= 0.5 else 0 for pred in y_pred]

# varicacion 1
y_pred_var1 = []
for x, y in test_ds:
    y_pred_var1.extend(list(model_var1.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var1 = [1 if pred >= 0.5 else 0 for pred in y_pred_var1]


# varicacion 2
y_pred_var2 = []
for x, y in test_ds:
    y_pred_var2.extend(list(model_var2.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var2 = [1 if pred >= 0.5 else 0 for pred in y_pred_var2]


# varicacion 3
y_pred_var3 = []
for x, y in test_ds:
    y_pred_var3.extend(list(model_var3.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var3 = [1 if pred >= 0.5 else 0 for pred in y_pred_var3]
# Out:
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 85ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000240C86F8900> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 91ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000240C86F8900> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 97ms/step

# %% [markdown]
# Calcular las métricas

# %%
#base

from sklearn.metrics import classification_report, confusion_matrix

#base
# Calcular métricas
print("Base")
print(classification_report(y_true, y_pred_bin, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin))
# Out:
# Base
#                precision    recall  f1-score   support
#
# No enfermedad       0.71      0.88      0.79        40
#    Enfermedad       0.58      0.33      0.42        21
#
#      accuracy                           0.69        61
#     macro avg       0.65      0.60      0.61        61
#  weighted avg       0.67      0.69      0.66        61
#
# Matriz de confusión:
#  [[35  5]
#  [14  7]]

# %%
#variacion 1
print("Variacion 1")
print(classification_report(y_true, y_pred_bin_var1, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var1))
# Out:
# Variacion 1
#                precision    recall  f1-score   support
#
# No enfermedad       0.62      0.75      0.68        40
#    Enfermedad       0.23      0.14      0.18        21
#
#      accuracy                           0.54        61
#     macro avg       0.43      0.45      0.43        61
#  weighted avg       0.49      0.54      0.51        61
#
# Matriz de confusión:
#  [[30 10]
#  [18  3]]

# %%
#variacion 2
print("Variacion 2")
print(classification_report(y_true, y_pred_bin_var2, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var2))
# Out:
# Variacion 2
#                precision    recall  f1-score   support
#
# No enfermedad       0.71      0.80      0.75        40
#    Enfermedad       0.50      0.38      0.43        21
#
#      accuracy                           0.66        61
#     macro avg       0.61      0.59      0.59        61
#  weighted avg       0.64      0.66      0.64        61
#
# Matriz de confusión:
#  [[32  8]
#  [13  8]]

# %%
#variacion 3
print("Variacion 3")
print(classification_report(y_true, y_pred_bin_var3, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var3))
# Out:
# Variacion 3
#                precision    recall  f1-score   support
#
# No enfermedad       0.67      0.82      0.74        40
#    Enfermedad       0.42      0.24      0.30        21
#
#      accuracy                           0.62        61
#     macro avg       0.55      0.53      0.52        61
#  weighted avg       0.59      0.62      0.59        61
#
# Matriz de confusión:
#  [[33  7]
#  [16  5]]
