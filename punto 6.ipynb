# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 13-14: redes neuronales para clasificación
#
# - Redes densas
# - Redes para clasificación
# - Procesamiento de datos continuos y categóricos
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy, pandas, keras, tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# Descripción de las variables:
#
# https://archive.ics.uci.edu/dataset/45/heart+disease

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Definimos listas para las variables categóricas enteras, categóricas string y numéricas.

# %%
subset_feats = ['age', 'trestbps', 'chol', 'sex', 'cp']
df = df[subset_feats+['target']]

# %%
df.head()
# Out:
#    age  trestbps  chol  sex  cp  target
# 0   63       145   233    1   1       0
# 1   67       160   286    1   4       1
# 2   67       120   229    1   4       0
# 3   37       130   250    1   3       0
# 4   41       130   204    0   2       0

# %% [markdown]
# Separamos los datos en entrenamiento, validación y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#      age  trestbps  chol  sex  cp  target
# 69    35       138   183    0   4       0
# 300   65       135   254    1   4       1
# 220   59       134   204    1   1       0
# 134   42       120   240    1   3       0
# 7     57       120   354    0   4       0

# %%
train.shape
# Out:
# (242, 6)

# %%
test = df.drop(train.index)
test.head()
# Out:
#     age  trestbps  chol  sex  cp  target
# 0    63       145   233    1   1       0
# 2    67       120   229    1   4       0
# 4    41       130   204    0   2       0
# 8    63       130   254    1   4       1
# 13   44       120   263    1   2       0

# %%
val = train.sample(frac=0.2, random_state=100)

# %%
val.shape
# Out:
# (48, 6)

# %%
train = train.drop(val.index)

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (194, 6)
# (48, 6)
# (61, 6)

# %% [markdown]
# Calculamos estadísticas de cada variable numérica

# %%
train.describe()
# Out:
#               age    trestbps        chol         sex          cp      target
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    54.953608  132.876289  249.974227    0.664948    3.097938    0.257732
# std      8.754150   17.952879   52.803226    0.473230    1.030969    0.438517
# min     34.000000   94.000000  126.000000    0.000000    0.000000    0.000000
# 25%     49.000000  120.000000  215.750000    0.000000    2.000000    0.000000
# 50%     56.000000  130.000000  243.000000    1.000000    3.000000    0.000000
# 75%     61.000000  143.500000  281.000000    1.000000    4.000000    1.000000
# max     77.000000  192.000000  564.000000    1.000000    4.000000    1.000000

# %% [markdown]
# Función para convertir de dataframe (pandas) a dataset (tensorflow), separando características y etiquetas

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

# %%
train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %% [markdown]
# Ejemplo de cómo queda el tf.dataset

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=41>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=112>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=250>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=3>}
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# Separamos los datos de entrenamiento, validación y prueba en lotes

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Función para codificar variables numéricas (Keras docs)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

# %% [markdown]
# Función para codificar variables categóricas (Keras docs)

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# Creamos una lista de inputs para el modelo, de acuerdo con cada tipo de variable

# %%
inputs = {
    'age': keras.Input(shape=(1,), name='age'),
    'trestbps': keras.Input(shape=(1,), name='trestbps'),
    'chol': keras.Input(shape=(1,), name='chol'),
    'sex': keras.Input(shape=(1,), name='sex', dtype='int64'),
    'cp': keras.Input(shape=(1,), name='cp', dtype='int64')
}
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
for i in inputs:
   print(i)
# Out:
# age
# trestbps
# chol
# sex
# cp

# %% [markdown]
# Creamos una lista de variables codificadas/normalizadas de acuerdo con su tipo, empleando las funciones de codificación/normalización

# %%
feats_encoded = [
    encode_numerical_feature(inputs['age'], 'age', train_ds),
    encode_numerical_feature(inputs['trestbps'], 'trestbps', train_ds),
    encode_numerical_feature(inputs['chol'], 'chol', train_ds),
    encode_categorical_feature(inputs['sex'], 'sex', train_ds, False),  # 'sex' es categórica (entero)
    encode_categorical_feature(inputs['cp'], 'cp', train_ds, False)  # 'cp' es categórica (entero)
]
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.

# %%
len_feats = len(feats_encoded)
len_feats
# Out:
# 5

# %%
for i in feats_encoded:
  print(i)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization/truediv:0', description="created by layer 'normalization'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_1/truediv:0', description="created by layer 'normalization_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_2/truediv:0', description="created by layer 'normalization_2'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='integer_lookup/bincount/DenseBincount:0', description="created by layer 'integer_lookup'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 6), dtype=tf.float32, name=None), name='integer_lookup_1/bincount/DenseBincount:0', description="created by layer 'integer_lookup_1'")

# %% [markdown]
# Creamos una capa concatenando todas las variables codificadas

# %%
all_feats = keras.layers.concatenate(feats_encoded)

# %%
type(all_feats)
# Out:
# keras.src.engine.keras_tensor.KerasTensor

# %% [markdown]
# Agregamos una capa densa con 32 neuronas y función de activación relu

# %%
#Base
model_layers = keras.layers.Dense(32, activation='relu')(all_feats)

#variacion 1
model_layers_var1 = keras.layers.Dense(32, activation='relu')(all_feats)
model_layers_var1 = keras.layers.Dense(32, activation='relu')(model_layers_var1)

#variacion 2
model_layers_var2 = keras.layers.Dense(32, activation='relu')(all_feats)
model_layers_var2 = keras.layers.Dense(32, activation='relu')(model_layers_var2)
model_layers_var2 = keras.layers.Dense(32, activation='relu')(model_layers_var2)

#variacion 3
model_layers_var3 = keras.layers.Dense(32, activation='relu')(all_feats)
model_layers_var3 = keras.layers.Dense(32, activation='relu')(model_layers_var3)
model_layers_var3 = keras.layers.Dense(32, activation='relu')(model_layers_var3)
model_layers_var3 = keras.layers.Dense(32, activation='relu')(model_layers_var3)

# %% [markdown]
# Agregamos la capa de salida con 1 neurona (probabilidad de sufrir la enfermedad cardiada) y función de activación sigmoide

# %%
#Base
model_layers = keras.layers.Dense(1, activation='sigmoid')(model_layers)

#variacion 1
model_layers_var1 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var1)

#variacion 2
model_layers_var2 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var2)

#variacion 3
model_layers_var3 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var3)

# %% [markdown]
# Creamos el modelo con las capas ya creadas y las variables de entrada

# %%
#Base
model = keras.Model(inputs, model_layers)

#variacion 1
model_var1= keras.Model(inputs, model_layers_var1)

#Variacion 2
model_var2= keras.Model(inputs, model_layers_var2)

#Variacion 3
model_var3= keras.Model(inputs, model_layers_var3)

# %% [markdown]
# Compilamos el modelo, definiendo optimizador, función de pérdida y métricas adicionales a capturar

# %%
#Base
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#variacion 1
model_var1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 2
model_var2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 3
model_var3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Aseguramos que Keras use TensorFlow como backend, para asegurar que el modelo pueda usar strings como entradas

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# Entrenamos el modelo con los datos en el formato tf.Dataset

# %%
#Base 
history=model.fit(train_ds, epochs=50, validation_data=val_ds)

#variacion 1
history_var1=model_var1.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 2
history_var2=model_var2.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 3
history_var3=model_var3.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 7/7 [==============================] - 1s 31ms/step - loss: 0.6587 - accuracy: 0.6289 - val_loss: 0.6391 - val_accuracy: 0.6042
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6345 - accuracy: 0.6856 - val_loss: 0.6152 - val_accuracy: 0.7083
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6150 - accuracy: 0.7526 - val_loss: 0.5947 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5986 - accuracy: 0.7474 - val_loss: 0.5782 - val_accuracy: 0.6875
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5852 - accuracy: 0.7474 - val_loss: 0.5660 - val_accuracy: 0.7292
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5750 - accuracy: 0.7423 - val_loss: 0.5554 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5659 - accuracy: 0.7423 - val_loss: 0.5468 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5572 - accuracy: 0.7423 - val_loss: 0.5382 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5505 - accuracy: 0.7423 - val_loss: 0.5316 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5439 - accuracy: 0.7423 - val_loss: 0.5244 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5378 - accuracy: 0.7423 - val_loss: 0.5170 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5319 - accuracy: 0.7423 - val_loss: 0.5102 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5251 - accuracy: 0.7423 - val_loss: 0.5055 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5202 - accuracy: 0.7423 - val_loss: 0.5006 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5149 - accuracy: 0.7423 - val_loss: 0.4960 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5118 - accuracy: 0.7423 - val_loss: 0.4930 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5083 - accuracy: 0.7423 - val_loss: 0.4903 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5051 - accuracy: 0.7423 - val_loss: 0.4872 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.7474 - val_loss: 0.4840 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4993 - accuracy: 0.7423 - val_loss: 0.4815 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4968 - accuracy: 0.7423 - val_loss: 0.4784 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4941 - accuracy: 0.7423 - val_loss: 0.4752 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4911 - accuracy: 0.7423 - val_loss: 0.4725 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4882 - accuracy: 0.7423 - val_loss: 0.4699 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4853 - accuracy: 0.7423 - val_loss: 0.4675 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4828 - accuracy: 0.7474 - val_loss: 0.4661 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4802 - accuracy: 0.7474 - val_loss: 0.4656 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4775 - accuracy: 0.7526 - val_loss: 0.4656 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4755 - accuracy: 0.7526 - val_loss: 0.4650 - val_accuracy: 0.7292
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4733 - accuracy: 0.7680 - val_loss: 0.4635 - val_accuracy: 0.7292
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4712 - accuracy: 0.7680 - val_loss: 0.4619 - val_accuracy: 0.7083
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4691 - accuracy: 0.7680 - val_loss: 0.4598 - val_accuracy: 0.7292
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4672 - accuracy: 0.7680 - val_loss: 0.4578 - val_accuracy: 0.7292
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4655 - accuracy: 0.7680 - val_loss: 0.4562 - val_accuracy: 0.7292
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4642 - accuracy: 0.7629 - val_loss: 0.4546 - val_accuracy: 0.7292
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4620 - accuracy: 0.7680 - val_loss: 0.4529 - val_accuracy: 0.7292
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4599 - accuracy: 0.7680 - val_loss: 0.4516 - val_accuracy: 0.7500
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4582 - accuracy: 0.7577 - val_loss: 0.4501 - val_accuracy: 0.7292
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4567 - accuracy: 0.7629 - val_loss: 0.4485 - val_accuracy: 0.7500
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4555 - accuracy: 0.7629 - val_loss: 0.4485 - val_accuracy: 0.7500
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4543 - accuracy: 0.7680 - val_loss: 0.4485 - val_accuracy: 0.7500
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4531 - accuracy: 0.7577 - val_loss: 0.4476 - val_accuracy: 0.7500
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4517 - accuracy: 0.7577 - val_loss: 0.4467 - val_accuracy: 0.7500
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4504 - accuracy: 0.7577 - val_loss: 0.4454 - val_accuracy: 0.7500
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4487 - accuracy: 0.7629 - val_loss: 0.4442 - val_accuracy: 0.7500
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4472 - accuracy: 0.7732 - val_loss: 0.4433 - val_accuracy: 0.7500
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4458 - accuracy: 0.7732 - val_loss: 0.4421 - val_accuracy: 0.7708
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4446 - accuracy: 0.7732 - val_loss: 0.4409 - val_accuracy: 0.7708
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4434 - accuracy: 0.7732 - val_loss: 0.4399 - val_accuracy: 0.7708
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4421 - accuracy: 0.7732 - val_loss: 0.4389 - val_accuracy: 0.7708
# Epoch 1/50
# 7/7 [==============================] - 1s 24ms/step - loss: 0.7017 - accuracy: 0.4845 - val_loss: 0.6589 - val_accuracy: 0.6458
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6553 - accuracy: 0.6804 - val_loss: 0.6249 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6215 - accuracy: 0.7474 - val_loss: 0.5980 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5957 - accuracy: 0.7423 - val_loss: 0.5793 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5776 - accuracy: 0.7423 - val_loss: 0.5637 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5632 - accuracy: 0.7423 - val_loss: 0.5522 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5521 - accuracy: 0.7423 - val_loss: 0.5434 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5427 - accuracy: 0.7423 - val_loss: 0.5341 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5325 - accuracy: 0.7423 - val_loss: 0.5246 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5238 - accuracy: 0.7423 - val_loss: 0.5147 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5139 - accuracy: 0.7423 - val_loss: 0.5069 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5085 - accuracy: 0.7423 - val_loss: 0.5010 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5004 - accuracy: 0.7423 - val_loss: 0.4945 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4922 - accuracy: 0.7423 - val_loss: 0.4877 - val_accuracy: 0.7292
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4883 - accuracy: 0.7784 - val_loss: 0.4805 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4839 - accuracy: 0.7784 - val_loss: 0.4738 - val_accuracy: 0.7708
# Epoch 17/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4783 - accuracy: 0.7835 - val_loss: 0.4689 - val_accuracy: 0.7708
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4728 - accuracy: 0.7784 - val_loss: 0.4634 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4678 - accuracy: 0.7732 - val_loss: 0.4573 - val_accuracy: 0.7708
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4624 - accuracy: 0.7680 - val_loss: 0.4518 - val_accuracy: 0.7708
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4569 - accuracy: 0.7732 - val_loss: 0.4476 - val_accuracy: 0.7708
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4529 - accuracy: 0.7680 - val_loss: 0.4427 - val_accuracy: 0.7708
# Epoch 23/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4477 - accuracy: 0.7629 - val_loss: 0.4390 - val_accuracy: 0.7708
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4432 - accuracy: 0.7629 - val_loss: 0.4363 - val_accuracy: 0.8125
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4383 - accuracy: 0.7680 - val_loss: 0.4345 - val_accuracy: 0.8125
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4353 - accuracy: 0.7629 - val_loss: 0.4348 - val_accuracy: 0.8333
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4334 - accuracy: 0.7835 - val_loss: 0.4321 - val_accuracy: 0.8333
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4284 - accuracy: 0.7732 - val_loss: 0.4303 - val_accuracy: 0.7917
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4251 - accuracy: 0.7784 - val_loss: 0.4290 - val_accuracy: 0.7708
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4249 - accuracy: 0.7680 - val_loss: 0.4281 - val_accuracy: 0.7917
# Epoch 31/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4239 - accuracy: 0.7577 - val_loss: 0.4253 - val_accuracy: 0.7917
# Epoch 32/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4180 - accuracy: 0.7732 - val_loss: 0.4171 - val_accuracy: 0.7917
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4162 - accuracy: 0.7732 - val_loss: 0.4140 - val_accuracy: 0.8125
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4154 - accuracy: 0.7784 - val_loss: 0.4141 - val_accuracy: 0.8333
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4127 - accuracy: 0.7835 - val_loss: 0.4125 - val_accuracy: 0.8125
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4104 - accuracy: 0.7887 - val_loss: 0.4087 - val_accuracy: 0.8125
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4088 - accuracy: 0.7835 - val_loss: 0.4059 - val_accuracy: 0.8125
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4063 - accuracy: 0.7784 - val_loss: 0.4040 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4057 - accuracy: 0.7938 - val_loss: 0.4029 - val_accuracy: 0.7708
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4043 - accuracy: 0.7938 - val_loss: 0.4023 - val_accuracy: 0.7708
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4025 - accuracy: 0.7938 - val_loss: 0.3992 - val_accuracy: 0.7708
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4004 - accuracy: 0.7990 - val_loss: 0.4010 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4014 - accuracy: 0.8144 - val_loss: 0.4037 - val_accuracy: 0.7708
# Epoch 44/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3996 - accuracy: 0.8144 - val_loss: 0.3994 - val_accuracy: 0.7917
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3980 - accuracy: 0.8093 - val_loss: 0.3969 - val_accuracy: 0.7917
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3969 - accuracy: 0.8093 - val_loss: 0.3960 - val_accuracy: 0.8125
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3957 - accuracy: 0.8093 - val_loss: 0.3958 - val_accuracy: 0.7917
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3959 - accuracy: 0.8041 - val_loss: 0.3959 - val_accuracy: 0.7917
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3929 - accuracy: 0.8041 - val_loss: 0.3985 - val_accuracy: 0.8125
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3913 - accuracy: 0.7990 - val_loss: 0.4047 - val_accuracy: 0.7500
# Epoch 1/50
# 7/7 [==============================] - 1s 25ms/step - loss: 0.6533 - accuracy: 0.7010 - val_loss: 0.6197 - val_accuracy: 0.7500
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6149 - accuracy: 0.7474 - val_loss: 0.5890 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5883 - accuracy: 0.7423 - val_loss: 0.5667 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5671 - accuracy: 0.7423 - val_loss: 0.5509 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5470 - accuracy: 0.7423 - val_loss: 0.5368 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5327 - accuracy: 0.7423 - val_loss: 0.5240 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5182 - accuracy: 0.7423 - val_loss: 0.5122 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5034 - accuracy: 0.7423 - val_loss: 0.5025 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4937 - accuracy: 0.7423 - val_loss: 0.4971 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4850 - accuracy: 0.7474 - val_loss: 0.4936 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4784 - accuracy: 0.7577 - val_loss: 0.4920 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4680 - accuracy: 0.7835 - val_loss: 0.4880 - val_accuracy: 0.7708
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4580 - accuracy: 0.7680 - val_loss: 0.4842 - val_accuracy: 0.7708
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4514 - accuracy: 0.7577 - val_loss: 0.4812 - val_accuracy: 0.7708
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4441 - accuracy: 0.7784 - val_loss: 0.4781 - val_accuracy: 0.7708
# Epoch 16/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4386 - accuracy: 0.7732 - val_loss: 0.4769 - val_accuracy: 0.7708
# Epoch 17/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4337 - accuracy: 0.7784 - val_loss: 0.4750 - val_accuracy: 0.7708
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4300 - accuracy: 0.7784 - val_loss: 0.4744 - val_accuracy: 0.7708
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4254 - accuracy: 0.7732 - val_loss: 0.4744 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4221 - accuracy: 0.7784 - val_loss: 0.4721 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4187 - accuracy: 0.7835 - val_loss: 0.4678 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4147 - accuracy: 0.7887 - val_loss: 0.4612 - val_accuracy: 0.7917
# Epoch 23/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4166 - accuracy: 0.7835 - val_loss: 0.4594 - val_accuracy: 0.7917
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4114 - accuracy: 0.7938 - val_loss: 0.4528 - val_accuracy: 0.7917
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4085 - accuracy: 0.7732 - val_loss: 0.4505 - val_accuracy: 0.7917
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4082 - accuracy: 0.7732 - val_loss: 0.4525 - val_accuracy: 0.7708
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4044 - accuracy: 0.7784 - val_loss: 0.4500 - val_accuracy: 0.7708
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4014 - accuracy: 0.7835 - val_loss: 0.4512 - val_accuracy: 0.8125
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3973 - accuracy: 0.7938 - val_loss: 0.4549 - val_accuracy: 0.7917
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4012 - accuracy: 0.7784 - val_loss: 0.4608 - val_accuracy: 0.7500
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4010 - accuracy: 0.7938 - val_loss: 0.4576 - val_accuracy: 0.7500
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3964 - accuracy: 0.7887 - val_loss: 0.4537 - val_accuracy: 0.7500
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3907 - accuracy: 0.7990 - val_loss: 0.4482 - val_accuracy: 0.7292
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3890 - accuracy: 0.7938 - val_loss: 0.4506 - val_accuracy: 0.7500
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3844 - accuracy: 0.8041 - val_loss: 0.4497 - val_accuracy: 0.7500
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3793 - accuracy: 0.8093 - val_loss: 0.4544 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3803 - accuracy: 0.7938 - val_loss: 0.4623 - val_accuracy: 0.7500
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3837 - accuracy: 0.7990 - val_loss: 0.4579 - val_accuracy: 0.7500
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3750 - accuracy: 0.7990 - val_loss: 0.4474 - val_accuracy: 0.7500
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3728 - accuracy: 0.8093 - val_loss: 0.4470 - val_accuracy: 0.7917
# Epoch 41/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3678 - accuracy: 0.8041 - val_loss: 0.4476 - val_accuracy: 0.7500
# Epoch 42/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3662 - accuracy: 0.8093 - val_loss: 0.4479 - val_accuracy: 0.7500
# Epoch 43/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3700 - accuracy: 0.8041 - val_loss: 0.4437 - val_accuracy: 0.7500
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3647 - accuracy: 0.8041 - val_loss: 0.4396 - val_accuracy: 0.7708
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3594 - accuracy: 0.8247 - val_loss: 0.4382 - val_accuracy: 0.7708
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3552 - accuracy: 0.8196 - val_loss: 0.4406 - val_accuracy: 0.7708
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3541 - accuracy: 0.8196 - val_loss: 0.4427 - val_accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3523 - accuracy: 0.8196 - val_loss: 0.4424 - val_accuracy: 0.7500
# Epoch 49/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3465 - accuracy: 0.8299 - val_loss: 0.4409 - val_accuracy: 0.7708
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3443 - accuracy: 0.8299 - val_loss: 0.4411 - val_accuracy: 0.7708
# Epoch 1/50
# 7/7 [==============================] - 1s 27ms/step - loss: 0.6747 - accuracy: 0.6856 - val_loss: 0.6566 - val_accuracy: 0.7500
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6424 - accuracy: 0.7423 - val_loss: 0.6291 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6142 - accuracy: 0.7423 - val_loss: 0.6024 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5840 - accuracy: 0.7423 - val_loss: 0.5798 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5609 - accuracy: 0.7423 - val_loss: 0.5638 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5394 - accuracy: 0.7423 - val_loss: 0.5489 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5222 - accuracy: 0.7423 - val_loss: 0.5369 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5094 - accuracy: 0.7423 - val_loss: 0.5273 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4954 - accuracy: 0.7423 - val_loss: 0.5200 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4848 - accuracy: 0.7423 - val_loss: 0.5081 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4747 - accuracy: 0.7423 - val_loss: 0.4968 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4634 - accuracy: 0.7474 - val_loss: 0.4895 - val_accuracy: 0.7292
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4506 - accuracy: 0.7680 - val_loss: 0.4780 - val_accuracy: 0.7292
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4404 - accuracy: 0.7732 - val_loss: 0.4676 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4326 - accuracy: 0.7938 - val_loss: 0.4537 - val_accuracy: 0.7708
# Epoch 16/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4200 - accuracy: 0.7887 - val_loss: 0.4412 - val_accuracy: 0.8125
# Epoch 17/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4171 - accuracy: 0.7990 - val_loss: 0.4360 - val_accuracy: 0.8125
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4143 - accuracy: 0.7938 - val_loss: 0.4372 - val_accuracy: 0.8333
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4070 - accuracy: 0.7990 - val_loss: 0.4307 - val_accuracy: 0.7917
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3982 - accuracy: 0.8041 - val_loss: 0.4247 - val_accuracy: 0.8125
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3929 - accuracy: 0.7990 - val_loss: 0.4184 - val_accuracy: 0.7917
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3906 - accuracy: 0.7990 - val_loss: 0.4117 - val_accuracy: 0.7917
# Epoch 23/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3852 - accuracy: 0.7990 - val_loss: 0.4099 - val_accuracy: 0.8125
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3845 - accuracy: 0.8093 - val_loss: 0.4172 - val_accuracy: 0.8125
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3781 - accuracy: 0.8196 - val_loss: 0.4145 - val_accuracy: 0.8333
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3767 - accuracy: 0.7990 - val_loss: 0.4123 - val_accuracy: 0.8333
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3715 - accuracy: 0.8144 - val_loss: 0.4107 - val_accuracy: 0.8333
# Epoch 28/50
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3664 - accuracy: 0.8351 - val_loss: 0.4193 - val_accuracy: 0.7917
# Epoch 29/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3667 - accuracy: 0.8041 - val_loss: 0.4191 - val_accuracy: 0.7917
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3578 - accuracy: 0.8247 - val_loss: 0.4147 - val_accuracy: 0.7500
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3574 - accuracy: 0.8247 - val_loss: 0.4160 - val_accuracy: 0.7708
# Epoch 32/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3553 - accuracy: 0.8041 - val_loss: 0.4119 - val_accuracy: 0.7708
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3483 - accuracy: 0.8247 - val_loss: 0.4104 - val_accuracy: 0.7708
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3549 - accuracy: 0.8041 - val_loss: 0.4372 - val_accuracy: 0.7708
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3710 - accuracy: 0.7887 - val_loss: 0.4439 - val_accuracy: 0.7708
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3541 - accuracy: 0.7990 - val_loss: 0.4266 - val_accuracy: 0.7917
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3471 - accuracy: 0.8247 - val_loss: 0.4451 - val_accuracy: 0.7708
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3513 - accuracy: 0.8196 - val_loss: 0.4369 - val_accuracy: 0.8125
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3353 - accuracy: 0.8299 - val_loss: 0.4346 - val_accuracy: 0.7500
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3385 - accuracy: 0.8247 - val_loss: 0.4261 - val_accuracy: 0.7708
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3338 - accuracy: 0.8144 - val_loss: 0.4213 - val_accuracy: 0.7708
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3297 - accuracy: 0.8144 - val_loss: 0.4226 - val_accuracy: 0.7708
# Epoch 43/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3240 - accuracy: 0.8247 - val_loss: 0.4172 - val_accuracy: 0.7917
# Epoch 44/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3270 - accuracy: 0.8351 - val_loss: 0.4102 - val_accuracy: 0.7708
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3188 - accuracy: 0.8557 - val_loss: 0.4175 - val_accuracy: 0.7708
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3192 - accuracy: 0.8196 - val_loss: 0.4250 - val_accuracy: 0.7708
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3159 - accuracy: 0.8196 - val_loss: 0.4184 - val_accuracy: 0.7708
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3128 - accuracy: 0.8505 - val_loss: 0.4204 - val_accuracy: 0.7708
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3132 - accuracy: 0.8454 - val_loss: 0.4199 - val_accuracy: 0.7917
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3078 - accuracy: 0.8454 - val_loss: 0.4190 - val_accuracy: 0.7917

# %% [markdown]
# Graficar la pérdida de entrenamiento y validación

# %%
#Base
plt.plot(history.history['loss'], label='Perdida')
plt.plot(history.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Base")
plt.show()

#variacion 1
plt.plot(history_var1.history['loss'], label='Perdida')
plt.plot(history_var1.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 1")
plt.show()

#variacion 2
plt.plot(history_var2.history['loss'], label='Perdida')
plt.plot(history_var2.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 2")
plt.show()

#variacion 3
plt.plot(history_var3.history['loss'], label='Perdida')
plt.plot(history_var3.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 3")
plt.show()

# %% [markdown]
# Hacer predicciones en el set de prueba

# %%
#base 
y_true = []
y_pred = []
for x, y in test_ds:
    y_true.extend(list(y.numpy()))
    y_pred.extend(list(model.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin = [1 if pred >= 0.5 else 0 for pred in y_pred]

# varicacion 1
y_pred_var1 = []
for x, y in test_ds:
    y_pred_var1.extend(list(model_var1.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var1 = [1 if pred >= 0.5 else 0 for pred in y_pred_var1]


# varicacion 2
y_pred_var2 = []
for x, y in test_ds:
    y_pred_var2.extend(list(model_var2.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var2 = [1 if pred >= 0.5 else 0 for pred in y_pred_var2]


# varicacion 3
y_pred_var3 = []
for x, y in test_ds:
    y_pred_var3.extend(list(model_var3.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var3 = [1 if pred >= 0.5 else 0 for pred in y_pred_var3]
# Out:
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 95ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000018E69F6B100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 103ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000018E69F6B100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 125ms/step

# %% [markdown]
# Calcular las métricas

# %%
#base

from sklearn.metrics import classification_report, confusion_matrix

#base
# Calcular métricas
print("Base")
print(classification_report(y_true, y_pred_bin, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin))
# Out:
# Base
#                precision    recall  f1-score   support
#
# No enfermedad       0.72      0.95      0.82        40
#    Enfermedad       0.75      0.29      0.41        21
#
#      accuracy                           0.72        61
#     macro avg       0.73      0.62      0.62        61
#  weighted avg       0.73      0.72      0.68        61
#
# Matriz de confusión:
#  [[38  2]
#  [15  6]]

# %%
#variacion 1
print("Variacion 1")
print(classification_report(y_true, y_pred_bin_var1, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var1))
# Out:
# Variacion 1
#                precision    recall  f1-score   support
#
# No enfermedad       0.60      0.72      0.66        40
#    Enfermedad       0.15      0.10      0.12        21
#
#      accuracy                           0.51        61
#     macro avg       0.38      0.41      0.39        61
#  weighted avg       0.45      0.51      0.47        61
#
# Matriz de confusión:
#  [[29 11]
#  [19  2]]

# %%
#variacion 2
print("Variacion 2")
print(classification_report(y_true, y_pred_bin_var2, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var2))
# Out:
# Variacion 2
#                precision    recall  f1-score   support
#
# No enfermedad       0.70      0.82      0.76        40
#    Enfermedad       0.50      0.33      0.40        21
#
#      accuracy                           0.66        61
#     macro avg       0.60      0.58      0.58        61
#  weighted avg       0.63      0.66      0.64        61
#
# Matriz de confusión:
#  [[33  7]
#  [14  7]]

# %%
#variacion 3
print("Variacion 3")
print(classification_report(y_true, y_pred_bin_var3, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var3))
# Out:
# Variacion 3
#                precision    recall  f1-score   support
#
# No enfermedad       0.66      0.82      0.73        40
#    Enfermedad       0.36      0.19      0.25        21
#
#      accuracy                           0.61        61
#     macro avg       0.51      0.51      0.49        61
#  weighted avg       0.56      0.61      0.57        61
#
# Matriz de confusión:
#  [[33  7]
#  [17  4]]
