# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 13-14: redes neuronales para clasificación
#
# - Redes densas
# - Redes para clasificación
# - Procesamiento de datos continuos y categóricos
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy, pandas, keras, tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# Descripción de las variables:
#
# https://archive.ics.uci.edu/dataset/45/heart+disease

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Definimos listas para las variables categóricas enteras, categóricas string y numéricas.

# %%
subset_feats = ['age', 'trestbps', 'chol', 'sex', 'cp']
df = df[subset_feats+['target']]

# %%
df.head()
# Out:
#    age  trestbps  chol  sex  cp  target
# 0   63       145   233    1   1       0
# 1   67       160   286    1   4       1
# 2   67       120   229    1   4       0
# 3   37       130   250    1   3       0
# 4   41       130   204    0   2       0

# %% [markdown]
# Separamos los datos en entrenamiento, validación y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#      age  trestbps  chol  sex  cp  target
# 69    35       138   183    0   4       0
# 300   65       135   254    1   4       1
# 220   59       134   204    1   1       0
# 134   42       120   240    1   3       0
# 7     57       120   354    0   4       0

# %%
train.shape
# Out:
# (242, 6)

# %%
test = df.drop(train.index)
test.head()
# Out:
#     age  trestbps  chol  sex  cp  target
# 0    63       145   233    1   1       0
# 2    67       120   229    1   4       0
# 4    41       130   204    0   2       0
# 8    63       130   254    1   4       1
# 13   44       120   263    1   2       0

# %%
val = train.sample(frac=0.2, random_state=100)

# %%
val.shape
# Out:
# (48, 6)

# %%
train = train.drop(val.index)

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (194, 6)
# (48, 6)
# (61, 6)

# %% [markdown]
# Calculamos estadísticas de cada variable numérica

# %%
train.describe()
# Out:
#               age    trestbps        chol         sex          cp      target
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    54.953608  132.876289  249.974227    0.664948    3.097938    0.257732
# std      8.754150   17.952879   52.803226    0.473230    1.030969    0.438517
# min     34.000000   94.000000  126.000000    0.000000    0.000000    0.000000
# 25%     49.000000  120.000000  215.750000    0.000000    2.000000    0.000000
# 50%     56.000000  130.000000  243.000000    1.000000    3.000000    0.000000
# 75%     61.000000  143.500000  281.000000    1.000000    4.000000    1.000000
# max     77.000000  192.000000  564.000000    1.000000    4.000000    1.000000

# %% [markdown]
# Función para convertir de dataframe (pandas) a dataset (tensorflow), separando características y etiquetas

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

# %%
train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %% [markdown]
# Ejemplo de cómo queda el tf.dataset

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=45>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=115>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=260>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=4>}
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# Separamos los datos de entrenamiento, validación y prueba en lotes

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Función para codificar variables numéricas (Keras docs)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

# %% [markdown]
# Función para codificar variables categóricas (Keras docs)

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# Creamos una lista de inputs para el modelo, de acuerdo con cada tipo de variable

# %%
inputs = {
    'age': keras.Input(shape=(1,), name='age'),
    'trestbps': keras.Input(shape=(1,), name='trestbps'),
    'chol': keras.Input(shape=(1,), name='chol'),
    'sex': keras.Input(shape=(1,), name='sex', dtype='int64'),
    'cp': keras.Input(shape=(1,), name='cp', dtype='int64')
}
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
for i in inputs:
   print(i)
# Out:
# age
# trestbps
# chol
# sex
# cp

# %% [markdown]
# Creamos una lista de variables codificadas/normalizadas de acuerdo con su tipo, empleando las funciones de codificación/normalización

# %%
feats_encoded = [
    encode_numerical_feature(inputs['age'], 'age', train_ds),
    encode_numerical_feature(inputs['trestbps'], 'trestbps', train_ds),
    encode_numerical_feature(inputs['chol'], 'chol', train_ds),
    encode_categorical_feature(inputs['sex'], 'sex', train_ds, False),  # 'sex' es categórica (entero)
    encode_categorical_feature(inputs['cp'], 'cp', train_ds, False)  # 'cp' es categórica (entero)
]
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.

# %%
len_feats = len(feats_encoded)
len_feats
# Out:
# 5

# %%
for i in feats_encoded:
  print(i)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization/truediv:0', description="created by layer 'normalization'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_1/truediv:0', description="created by layer 'normalization_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_2/truediv:0', description="created by layer 'normalization_2'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='integer_lookup/bincount/DenseBincount:0', description="created by layer 'integer_lookup'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 6), dtype=tf.float32, name=None), name='integer_lookup_1/bincount/DenseBincount:0', description="created by layer 'integer_lookup_1'")

# %% [markdown]
# Creamos una capa concatenando todas las variables codificadas

# %%
all_feats = keras.layers.concatenate(feats_encoded)

# %%
type(all_feats)
# Out:
# keras.src.engine.keras_tensor.KerasTensor

# %% [markdown]
# Agregamos una capa densa con 32 neuronas y función de activación relu

# %%
#Base
model_layers = keras.layers.Dense(32, activation='relu')(all_feats)

#variacion 1
model_layers_var1 = keras.layers.Dense(8, activation='relu')(all_feats)

#variacion 2
model_layers_var2 = keras.layers.Dense(64, activation='relu')(all_feats)

#variacion 3
model_layers_var3 = keras.layers.Dense(128, activation='relu')(all_feats)

# %% [markdown]
# Agregamos la capa de salida con 1 neurona (probabilidad de sufrir la enfermedad cardiada) y función de activación sigmoide

# %%
#Base
model_layers = keras.layers.Dense(1, activation='sigmoid')(model_layers)

#variacion 1
model_layers_var1 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var1)

#variacion 2
model_layers_var2 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var2)

#variacion 3
model_layers_var3 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var3)

# %% [markdown]
# Creamos el modelo con las capas ya creadas y las variables de entrada

# %%
#Base
model = keras.Model(inputs, model_layers)

#variacion 1
model_var1= keras.Model(inputs, model_layers_var1)

#Variacion 2
model_var2= keras.Model(inputs, model_layers_var2)

#Variacion 3
model_var3= keras.Model(inputs, model_layers_var3)

# %% [markdown]
# Compilamos el modelo, definiendo optimizador, función de pérdida y métricas adicionales a capturar

# %%
#Base
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#variacion 1
model_var1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 2
model_var2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 3
model_var3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Aseguramos que Keras use TensorFlow como backend, para asegurar que el modelo pueda usar strings como entradas

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# Entrenamos el modelo con los datos en el formato tf.Dataset

# %%
#Base 
history=model.fit(train_ds, epochs=50, validation_data=val_ds)

#variacion 1
history_var1=model_var1.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 2
history_var2=model_var2.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 3
history_var3=model_var3.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 7/7 [==============================] - 1s 27ms/step - loss: 0.6192 - accuracy: 0.7268 - val_loss: 0.6243 - val_accuracy: 0.7917
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6039 - accuracy: 0.7268 - val_loss: 0.6133 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5933 - accuracy: 0.7423 - val_loss: 0.6040 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5837 - accuracy: 0.7474 - val_loss: 0.5943 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5738 - accuracy: 0.7474 - val_loss: 0.5842 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5641 - accuracy: 0.7474 - val_loss: 0.5752 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5557 - accuracy: 0.7474 - val_loss: 0.5661 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5468 - accuracy: 0.7423 - val_loss: 0.5584 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5396 - accuracy: 0.7423 - val_loss: 0.5511 - val_accuracy: 0.7708
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5330 - accuracy: 0.7423 - val_loss: 0.5456 - val_accuracy: 0.7708
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5277 - accuracy: 0.7474 - val_loss: 0.5400 - val_accuracy: 0.7708
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5231 - accuracy: 0.7526 - val_loss: 0.5356 - val_accuracy: 0.7708
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5198 - accuracy: 0.7526 - val_loss: 0.5315 - val_accuracy: 0.7708
# Epoch 14/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5159 - accuracy: 0.7526 - val_loss: 0.5267 - val_accuracy: 0.7708
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5115 - accuracy: 0.7526 - val_loss: 0.5222 - val_accuracy: 0.7708
# Epoch 16/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5078 - accuracy: 0.7526 - val_loss: 0.5183 - val_accuracy: 0.7708
# Epoch 17/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5039 - accuracy: 0.7474 - val_loss: 0.5145 - val_accuracy: 0.7708
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5005 - accuracy: 0.7474 - val_loss: 0.5113 - val_accuracy: 0.7708
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4984 - accuracy: 0.7526 - val_loss: 0.5100 - val_accuracy: 0.7708
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4958 - accuracy: 0.7526 - val_loss: 0.5072 - val_accuracy: 0.7708
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4926 - accuracy: 0.7474 - val_loss: 0.5034 - val_accuracy: 0.7708
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4897 - accuracy: 0.7474 - val_loss: 0.4999 - val_accuracy: 0.7708
# Epoch 23/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4868 - accuracy: 0.7474 - val_loss: 0.4970 - val_accuracy: 0.7708
# Epoch 24/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4838 - accuracy: 0.7474 - val_loss: 0.4943 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4813 - accuracy: 0.7474 - val_loss: 0.4917 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4787 - accuracy: 0.7474 - val_loss: 0.4896 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4760 - accuracy: 0.7474 - val_loss: 0.4869 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4734 - accuracy: 0.7474 - val_loss: 0.4842 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4707 - accuracy: 0.7474 - val_loss: 0.4821 - val_accuracy: 0.7500
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4685 - accuracy: 0.7577 - val_loss: 0.4797 - val_accuracy: 0.7500
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4664 - accuracy: 0.7577 - val_loss: 0.4777 - val_accuracy: 0.7500
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4645 - accuracy: 0.7577 - val_loss: 0.4758 - val_accuracy: 0.7500
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4631 - accuracy: 0.7577 - val_loss: 0.4742 - val_accuracy: 0.7500
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4611 - accuracy: 0.7577 - val_loss: 0.4725 - val_accuracy: 0.7500
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4601 - accuracy: 0.7577 - val_loss: 0.4700 - val_accuracy: 0.7500
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4580 - accuracy: 0.7577 - val_loss: 0.4680 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4563 - accuracy: 0.7629 - val_loss: 0.4664 - val_accuracy: 0.7500
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4543 - accuracy: 0.7629 - val_loss: 0.4647 - val_accuracy: 0.7500
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4529 - accuracy: 0.7629 - val_loss: 0.4629 - val_accuracy: 0.7500
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4510 - accuracy: 0.7680 - val_loss: 0.4612 - val_accuracy: 0.7500
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4499 - accuracy: 0.7629 - val_loss: 0.4596 - val_accuracy: 0.7500
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4489 - accuracy: 0.7629 - val_loss: 0.4583 - val_accuracy: 0.7500
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4479 - accuracy: 0.7629 - val_loss: 0.4572 - val_accuracy: 0.7500
# Epoch 44/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4468 - accuracy: 0.7680 - val_loss: 0.4565 - val_accuracy: 0.7500
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4458 - accuracy: 0.7680 - val_loss: 0.4555 - val_accuracy: 0.7500
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4446 - accuracy: 0.7732 - val_loss: 0.4540 - val_accuracy: 0.7500
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4431 - accuracy: 0.7784 - val_loss: 0.4516 - val_accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4404 - accuracy: 0.7732 - val_loss: 0.4498 - val_accuracy: 0.7500
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4387 - accuracy: 0.7629 - val_loss: 0.4503 - val_accuracy: 0.7708
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4373 - accuracy: 0.7526 - val_loss: 0.4494 - val_accuracy: 0.7917
# Epoch 1/50
# 7/7 [==============================] - 1s 25ms/step - loss: 0.6631 - accuracy: 0.6134 - val_loss: 0.6438 - val_accuracy: 0.5833
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6561 - accuracy: 0.6186 - val_loss: 0.6395 - val_accuracy: 0.6042
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6504 - accuracy: 0.6392 - val_loss: 0.6358 - val_accuracy: 0.6042
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6451 - accuracy: 0.6495 - val_loss: 0.6326 - val_accuracy: 0.6042
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6410 - accuracy: 0.6598 - val_loss: 0.6294 - val_accuracy: 0.6042
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6368 - accuracy: 0.6701 - val_loss: 0.6265 - val_accuracy: 0.6250
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6327 - accuracy: 0.6907 - val_loss: 0.6238 - val_accuracy: 0.6250
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6286 - accuracy: 0.7010 - val_loss: 0.6215 - val_accuracy: 0.6250
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6248 - accuracy: 0.7165 - val_loss: 0.6192 - val_accuracy: 0.6250
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6209 - accuracy: 0.7165 - val_loss: 0.6171 - val_accuracy: 0.6458
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6178 - accuracy: 0.7165 - val_loss: 0.6152 - val_accuracy: 0.6458
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6144 - accuracy: 0.7320 - val_loss: 0.6131 - val_accuracy: 0.6667
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6113 - accuracy: 0.7268 - val_loss: 0.6112 - val_accuracy: 0.6875
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6084 - accuracy: 0.7268 - val_loss: 0.6094 - val_accuracy: 0.6875
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6055 - accuracy: 0.7062 - val_loss: 0.6077 - val_accuracy: 0.7083
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6027 - accuracy: 0.7113 - val_loss: 0.6059 - val_accuracy: 0.7083
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5999 - accuracy: 0.7216 - val_loss: 0.6043 - val_accuracy: 0.7292
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5973 - accuracy: 0.7371 - val_loss: 0.6028 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5947 - accuracy: 0.7371 - val_loss: 0.6012 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5920 - accuracy: 0.7320 - val_loss: 0.5989 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5893 - accuracy: 0.7320 - val_loss: 0.5970 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5864 - accuracy: 0.7371 - val_loss: 0.5951 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5842 - accuracy: 0.7474 - val_loss: 0.5933 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5819 - accuracy: 0.7680 - val_loss: 0.5912 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5797 - accuracy: 0.7680 - val_loss: 0.5894 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5779 - accuracy: 0.7680 - val_loss: 0.5877 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5760 - accuracy: 0.7835 - val_loss: 0.5858 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5742 - accuracy: 0.7835 - val_loss: 0.5833 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5723 - accuracy: 0.7784 - val_loss: 0.5815 - val_accuracy: 0.7500
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5710 - accuracy: 0.7732 - val_loss: 0.5800 - val_accuracy: 0.7500
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5689 - accuracy: 0.7784 - val_loss: 0.5783 - val_accuracy: 0.7500
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5670 - accuracy: 0.7784 - val_loss: 0.5767 - val_accuracy: 0.7500
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5651 - accuracy: 0.7784 - val_loss: 0.5750 - val_accuracy: 0.7500
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5633 - accuracy: 0.7784 - val_loss: 0.5734 - val_accuracy: 0.7500
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5616 - accuracy: 0.7732 - val_loss: 0.5713 - val_accuracy: 0.7500
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5595 - accuracy: 0.7732 - val_loss: 0.5700 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5578 - accuracy: 0.7732 - val_loss: 0.5687 - val_accuracy: 0.7500
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5561 - accuracy: 0.7732 - val_loss: 0.5671 - val_accuracy: 0.7500
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5542 - accuracy: 0.7680 - val_loss: 0.5650 - val_accuracy: 0.7500
# Epoch 40/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5522 - accuracy: 0.7732 - val_loss: 0.5630 - val_accuracy: 0.7500
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5502 - accuracy: 0.7732 - val_loss: 0.5605 - val_accuracy: 0.7500
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5481 - accuracy: 0.7732 - val_loss: 0.5587 - val_accuracy: 0.7500
# Epoch 43/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5462 - accuracy: 0.7732 - val_loss: 0.5571 - val_accuracy: 0.7500
# Epoch 44/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5445 - accuracy: 0.7732 - val_loss: 0.5557 - val_accuracy: 0.7500
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5427 - accuracy: 0.7732 - val_loss: 0.5543 - val_accuracy: 0.7500
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5410 - accuracy: 0.7732 - val_loss: 0.5524 - val_accuracy: 0.7500
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5393 - accuracy: 0.7732 - val_loss: 0.5507 - val_accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5376 - accuracy: 0.7680 - val_loss: 0.5492 - val_accuracy: 0.7500
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5363 - accuracy: 0.7732 - val_loss: 0.5478 - val_accuracy: 0.7500
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5348 - accuracy: 0.7732 - val_loss: 0.5468 - val_accuracy: 0.7500
# Epoch 1/50
# 7/7 [==============================] - 1s 25ms/step - loss: 0.8040 - accuracy: 0.2835 - val_loss: 0.7780 - val_accuracy: 0.3333
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7533 - accuracy: 0.3505 - val_loss: 0.7351 - val_accuracy: 0.4583
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7157 - accuracy: 0.4433 - val_loss: 0.6989 - val_accuracy: 0.5625
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6801 - accuracy: 0.6031 - val_loss: 0.6673 - val_accuracy: 0.6458
# Epoch 5/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6525 - accuracy: 0.6804 - val_loss: 0.6417 - val_accuracy: 0.6875
# Epoch 6/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6281 - accuracy: 0.7165 - val_loss: 0.6205 - val_accuracy: 0.7292
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6095 - accuracy: 0.7320 - val_loss: 0.6038 - val_accuracy: 0.7292
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5940 - accuracy: 0.7371 - val_loss: 0.5909 - val_accuracy: 0.7292
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5824 - accuracy: 0.7423 - val_loss: 0.5789 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5708 - accuracy: 0.7423 - val_loss: 0.5692 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5605 - accuracy: 0.7423 - val_loss: 0.5608 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5520 - accuracy: 0.7423 - val_loss: 0.5540 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5438 - accuracy: 0.7423 - val_loss: 0.5473 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5364 - accuracy: 0.7423 - val_loss: 0.5419 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5303 - accuracy: 0.7423 - val_loss: 0.5368 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5236 - accuracy: 0.7423 - val_loss: 0.5317 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5183 - accuracy: 0.7423 - val_loss: 0.5276 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5131 - accuracy: 0.7423 - val_loss: 0.5234 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5087 - accuracy: 0.7423 - val_loss: 0.5197 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5045 - accuracy: 0.7423 - val_loss: 0.5161 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4999 - accuracy: 0.7423 - val_loss: 0.5121 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4958 - accuracy: 0.7423 - val_loss: 0.5077 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4918 - accuracy: 0.7423 - val_loss: 0.5033 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4882 - accuracy: 0.7423 - val_loss: 0.5000 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4845 - accuracy: 0.7474 - val_loss: 0.4980 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4814 - accuracy: 0.7474 - val_loss: 0.4958 - val_accuracy: 0.7292
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4795 - accuracy: 0.7526 - val_loss: 0.4932 - val_accuracy: 0.7917
# Epoch 28/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4760 - accuracy: 0.7784 - val_loss: 0.4900 - val_accuracy: 0.7917
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4732 - accuracy: 0.7887 - val_loss: 0.4872 - val_accuracy: 0.7917
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4702 - accuracy: 0.7835 - val_loss: 0.4851 - val_accuracy: 0.7708
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4680 - accuracy: 0.7784 - val_loss: 0.4834 - val_accuracy: 0.7500
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4649 - accuracy: 0.7784 - val_loss: 0.4814 - val_accuracy: 0.7500
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4625 - accuracy: 0.7835 - val_loss: 0.4790 - val_accuracy: 0.7708
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4598 - accuracy: 0.7835 - val_loss: 0.4772 - val_accuracy: 0.7708
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4576 - accuracy: 0.7835 - val_loss: 0.4747 - val_accuracy: 0.7500
# Epoch 36/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4551 - accuracy: 0.7784 - val_loss: 0.4723 - val_accuracy: 0.7917
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4526 - accuracy: 0.7732 - val_loss: 0.4701 - val_accuracy: 0.7917
# Epoch 38/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4506 - accuracy: 0.7784 - val_loss: 0.4683 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4491 - accuracy: 0.7784 - val_loss: 0.4667 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4477 - accuracy: 0.7835 - val_loss: 0.4664 - val_accuracy: 0.7917
# Epoch 41/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4462 - accuracy: 0.7835 - val_loss: 0.4660 - val_accuracy: 0.7917
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4447 - accuracy: 0.7835 - val_loss: 0.4642 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4431 - accuracy: 0.7835 - val_loss: 0.4629 - val_accuracy: 0.7917
# Epoch 44/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4417 - accuracy: 0.7784 - val_loss: 0.4629 - val_accuracy: 0.7917
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4409 - accuracy: 0.7784 - val_loss: 0.4635 - val_accuracy: 0.7917
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4403 - accuracy: 0.7784 - val_loss: 0.4629 - val_accuracy: 0.7917
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4389 - accuracy: 0.7835 - val_loss: 0.4615 - val_accuracy: 0.7708
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4366 - accuracy: 0.7887 - val_loss: 0.4601 - val_accuracy: 0.7708
# Epoch 49/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4352 - accuracy: 0.7938 - val_loss: 0.4592 - val_accuracy: 0.7500
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4336 - accuracy: 0.7887 - val_loss: 0.4580 - val_accuracy: 0.7292
# Epoch 1/50
# 7/7 [==============================] - 1s 23ms/step - loss: 0.6940 - accuracy: 0.4897 - val_loss: 0.6422 - val_accuracy: 0.7083
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6415 - accuracy: 0.7010 - val_loss: 0.5994 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6025 - accuracy: 0.7423 - val_loss: 0.5698 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5768 - accuracy: 0.7423 - val_loss: 0.5473 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5574 - accuracy: 0.7423 - val_loss: 0.5307 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5431 - accuracy: 0.7423 - val_loss: 0.5208 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5304 - accuracy: 0.7423 - val_loss: 0.5119 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5198 - accuracy: 0.7423 - val_loss: 0.5042 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5111 - accuracy: 0.7423 - val_loss: 0.4961 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5025 - accuracy: 0.7423 - val_loss: 0.4896 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4952 - accuracy: 0.7423 - val_loss: 0.4844 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4882 - accuracy: 0.7423 - val_loss: 0.4804 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4818 - accuracy: 0.7423 - val_loss: 0.4755 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4748 - accuracy: 0.7474 - val_loss: 0.4698 - val_accuracy: 0.8125
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4705 - accuracy: 0.7526 - val_loss: 0.4649 - val_accuracy: 0.7917
# Epoch 16/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4654 - accuracy: 0.7680 - val_loss: 0.4599 - val_accuracy: 0.7917
# Epoch 17/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4608 - accuracy: 0.7680 - val_loss: 0.4553 - val_accuracy: 0.7917
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4565 - accuracy: 0.7732 - val_loss: 0.4528 - val_accuracy: 0.7917
# Epoch 19/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4521 - accuracy: 0.7732 - val_loss: 0.4498 - val_accuracy: 0.7917
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4484 - accuracy: 0.7784 - val_loss: 0.4466 - val_accuracy: 0.7917
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4441 - accuracy: 0.7887 - val_loss: 0.4432 - val_accuracy: 0.7917
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4405 - accuracy: 0.7887 - val_loss: 0.4399 - val_accuracy: 0.7917
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4372 - accuracy: 0.7938 - val_loss: 0.4375 - val_accuracy: 0.7917
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4353 - accuracy: 0.7784 - val_loss: 0.4363 - val_accuracy: 0.7708
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4334 - accuracy: 0.7680 - val_loss: 0.4353 - val_accuracy: 0.8125
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4319 - accuracy: 0.7680 - val_loss: 0.4360 - val_accuracy: 0.8125
# Epoch 27/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4290 - accuracy: 0.7784 - val_loss: 0.4357 - val_accuracy: 0.8125
# Epoch 28/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4267 - accuracy: 0.7835 - val_loss: 0.4342 - val_accuracy: 0.8125
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4248 - accuracy: 0.7732 - val_loss: 0.4333 - val_accuracy: 0.7708
# Epoch 30/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4237 - accuracy: 0.7784 - val_loss: 0.4329 - val_accuracy: 0.7708
# Epoch 31/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4222 - accuracy: 0.7784 - val_loss: 0.4327 - val_accuracy: 0.7917
# Epoch 32/50
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4193 - accuracy: 0.7938 - val_loss: 0.4341 - val_accuracy: 0.7708
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4188 - accuracy: 0.7990 - val_loss: 0.4350 - val_accuracy: 0.7917
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4167 - accuracy: 0.8041 - val_loss: 0.4336 - val_accuracy: 0.7917
# Epoch 35/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4153 - accuracy: 0.7990 - val_loss: 0.4292 - val_accuracy: 0.7917
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4133 - accuracy: 0.7990 - val_loss: 0.4262 - val_accuracy: 0.7917
# Epoch 37/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4116 - accuracy: 0.8041 - val_loss: 0.4244 - val_accuracy: 0.7917
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4110 - accuracy: 0.7990 - val_loss: 0.4227 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4097 - accuracy: 0.7990 - val_loss: 0.4220 - val_accuracy: 0.7917
# Epoch 40/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4088 - accuracy: 0.7938 - val_loss: 0.4241 - val_accuracy: 0.7917
# Epoch 41/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4093 - accuracy: 0.7990 - val_loss: 0.4272 - val_accuracy: 0.7917
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4086 - accuracy: 0.7938 - val_loss: 0.4293 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4097 - accuracy: 0.8041 - val_loss: 0.4303 - val_accuracy: 0.8125
# Epoch 44/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4111 - accuracy: 0.8041 - val_loss: 0.4336 - val_accuracy: 0.8125
# Epoch 45/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4095 - accuracy: 0.8041 - val_loss: 0.4334 - val_accuracy: 0.8125
# Epoch 46/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4083 - accuracy: 0.8041 - val_loss: 0.4327 - val_accuracy: 0.7917
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.7990 - val_loss: 0.4321 - val_accuracy: 0.7917
# Epoch 48/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4059 - accuracy: 0.8144 - val_loss: 0.4325 - val_accuracy: 0.7708
# Epoch 49/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4040 - accuracy: 0.7990 - val_loss: 0.4353 - val_accuracy: 0.7917
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4032 - accuracy: 0.8041 - val_loss: 0.4382 - val_accuracy: 0.7917

# %% [markdown]
# Graficar la pérdida de entrenamiento y validación

# %%
#Base
plt.plot(history.history['loss'], label='Perdida')
plt.plot(history.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Base")
plt.show()

#variacion 1
plt.plot(history_var1.history['loss'], label='Perdida')
plt.plot(history_var1.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 1")
plt.show()

#variacion 2
plt.plot(history_var2.history['loss'], label='Perdida')
plt.plot(history_var2.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 2")
plt.show()

#variacion 3
plt.plot(history_var3.history['loss'], label='Perdida')
plt.plot(history_var3.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 3")
plt.show()

# %% [markdown]
# Hacer predicciones en el set de prueba

# %%
#base 
y_true = []
y_pred = []
for x, y in test_ds:
    y_true.extend(list(y.numpy()))
    y_pred.extend(list(model.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin = [1 if pred >= 0.5 else 0 for pred in y_pred]

# varicacion 1
y_pred_var1 = []
for x, y in test_ds:
    y_pred_var1.extend(list(model_var1.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var1 = [1 if pred >= 0.5 else 0 for pred in y_pred_var1]


# varicacion 2
y_pred_var2 = []
for x, y in test_ds:
    y_pred_var2.extend(list(model_var2.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var2 = [1 if pred >= 0.5 else 0 for pred in y_pred_var2]


# varicacion 3
y_pred_var3 = []
for x, y in test_ds:
    y_pred_var3.extend(list(model_var3.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var3 = [1 if pred >= 0.5 else 0 for pred in y_pred_var3]
# Out:
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 310ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001E015372340> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 91ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001E015372340> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 121ms/step

# %% [markdown]
# Calcular las métricas

# %%
#base

from sklearn.metrics import classification_report, confusion_matrix

#base
# Calcular métricas
print("Base")
print(classification_report(y_true, y_pred_bin, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin))
# Out:
# Base
#                precision    recall  f1-score   support
#
# No enfermedad       0.70      0.95      0.81        40
#    Enfermedad       0.71      0.24      0.36        21
#
#      accuracy                           0.70        61
#     macro avg       0.71      0.59      0.58        61
#  weighted avg       0.71      0.70      0.65        61
#
# Matriz de confusión:
#  [[38  2]
#  [16  5]]

# %%
#variacion 1
print("Variacion 1")
print(classification_report(y_true, y_pred_bin_var1, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var1))
# Out:
# Variacion 1
#                precision    recall  f1-score   support
#
# No enfermedad       0.62      0.85      0.72        40
#    Enfermedad       0.00      0.00      0.00        21
#
#      accuracy                           0.56        61
#     macro avg       0.31      0.42      0.36        61
#  weighted avg       0.41      0.56      0.47        61
#
# Matriz de confusión:
#  [[34  6]
#  [21  0]]

# %%
#variacion 2
print("Variacion 2")
print(classification_report(y_true, y_pred_bin_var2, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var2))
# Out:
# Variacion 2
#                precision    recall  f1-score   support
#
# No enfermedad       0.64      0.80      0.71        40
#    Enfermedad       0.27      0.14      0.19        21
#
#      accuracy                           0.57        61
#     macro avg       0.46      0.47      0.45        61
#  weighted avg       0.51      0.57      0.53        61
#
# Matriz de confusión:
#  [[32  8]
#  [18  3]]

# %%
#variacion 3
print("Variacion 3")
print(classification_report(y_true, y_pred_bin_var3, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var3))
# Out:
# Variacion 3
#                precision    recall  f1-score   support
#
# No enfermedad       0.67      0.78      0.72        40
#    Enfermedad       0.40      0.29      0.33        21
#
#      accuracy                           0.61        61
#     macro avg       0.54      0.53      0.53        61
#  weighted avg       0.58      0.61      0.59        61
#
# Matriz de confusión:
#  [[31  9]
#  [15  6]]
