# %% [markdown]
# ## ACTD 2024 - 20

# %% [markdown]
# ### Clases 13-14: redes neuronales para clasificación
#
# - Redes densas
# - Redes para clasificación
# - Procesamiento de datos continuos y categóricos
# - Funciones de activación y pérdida

# %% [markdown]
# Empecemos importando numpy, pandas, keras, tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Carguemos el archivo auto-mpg.data (disponible en Bloque Neón) usando pandas. Note que debemos incluir los nombres de las columnas, además de indicar los caracteres para separación, nas y comentarios.

# %%
df = pd.read_csv('heart.csv')

# %% [markdown]
# Exploremos las primeras filas del dataframe.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %% [markdown]
# Descripción de las variables:
#
# https://archive.ics.uci.edu/dataset/45/heart+disease

# %% [markdown]
# Exploremos el tamaño del df

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# Identificamos NAs en los datos

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Definimos listas para las variables categóricas enteras, categóricas string y numéricas.

# %%
subset_feats = ['age', 'trestbps', 'chol', 'sex', 'cp']
df = df[subset_feats+['target']]

# %%
df.head()
# Out:
#    age  trestbps  chol  sex  cp  target
# 0   63       145   233    1   1       0
# 1   67       160   286    1   4       1
# 2   67       120   229    1   4       0
# 3   37       130   250    1   3       0
# 4   41       130   204    0   2       0

# %% [markdown]
# Separamos los datos en entrenamiento, validación y prueba

# %%
train = df.sample(frac=0.8, random_state=100)
train.head()
# Out:
#      age  trestbps  chol  sex  cp  target
# 69    35       138   183    0   4       0
# 300   65       135   254    1   4       1
# 220   59       134   204    1   1       0
# 134   42       120   240    1   3       0
# 7     57       120   354    0   4       0

# %%
train.shape
# Out:
# (242, 6)

# %%
test = df.drop(train.index)
test.head()
# Out:
#     age  trestbps  chol  sex  cp  target
# 0    63       145   233    1   1       0
# 2    67       120   229    1   4       0
# 4    41       130   204    0   2       0
# 8    63       130   254    1   4       1
# 13   44       120   263    1   2       0

# %%
val = train.sample(frac=0.2, random_state=100)

# %%
val.shape
# Out:
# (48, 6)

# %%
train = train.drop(val.index)

# %%
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# (194, 6)
# (48, 6)
# (61, 6)

# %% [markdown]
# Calculamos estadísticas de cada variable numérica

# %%
train.describe()
# Out:
#               age    trestbps        chol         sex          cp      target
# count  194.000000  194.000000  194.000000  194.000000  194.000000  194.000000
# mean    54.953608  132.876289  249.974227    0.664948    3.097938    0.257732
# std      8.754150   17.952879   52.803226    0.473230    1.030969    0.438517
# min     34.000000   94.000000  126.000000    0.000000    0.000000    0.000000
# 25%     49.000000  120.000000  215.750000    0.000000    2.000000    0.000000
# 50%     56.000000  130.000000  243.000000    1.000000    3.000000    0.000000
# 75%     61.000000  143.500000  281.000000    1.000000    4.000000    1.000000
# max     77.000000  192.000000  564.000000    1.000000    4.000000    1.000000

# %% [markdown]
# Función para convertir de dataframe (pandas) a dataset (tensorflow), separando características y etiquetas

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds

# %%
train_ds = dataframe_to_dataset(train)
val_ds = dataframe_to_dataset(val)
test_ds = dataframe_to_dataset(test)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.shuffle_op._ShuffleDataset

# %% [markdown]
# Ejemplo de cómo queda el tf.dataset

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=34>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=118>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=182>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=1>}
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# Separamos los datos de entrenamiento, validación y prueba en lotes

# %%
batch_size = 32
train_ds = train_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)

# %% [markdown]
# Función para codificar variables numéricas (Keras docs)

# %%
def encode_numerical_feature(feature, name, dataset):
    # Crea capa de normalización para este feature
    normalizer = keras.layers.Normalization()

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende las estadísticas de los datos (media, varianza)
    normalizer.adapt(feature_ds)

    # Aplica la normalización a la variable
    encoded_feature = normalizer(feature)
    return encoded_feature

# %% [markdown]
# Función para codificar variables categóricas (Keras docs)

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = keras.layers.StringLookup if is_string else keras.layers.IntegerLookup
    # Crea una capa Lookup para retornas variables 0/1 (dummies)
    # lookup: busca el valor correspondiente de la variable categórica
    lookup = lookup_class(output_mode="binary")

    # Prepara el dataset para considerar únicamente la feature de interés (name)
    feature_ds = dataset.map(lambda x, y: x[name]) # selecciona variable
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1)) # deja el tensor de una dimensión

    # Aprende el conjunto de posibles valores que toma la variable categórica y asigna enteros
    lookup.adapt(feature_ds)

    # Aplica la conversión de categorías a enteros
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# Creamos una lista de inputs para el modelo, de acuerdo con cada tipo de variable

# %%
inputs = {
    'age': keras.Input(shape=(1,), name='age'),
    'trestbps': keras.Input(shape=(1,), name='trestbps'),
    'chol': keras.Input(shape=(1,), name='chol'),
    'sex': keras.Input(shape=(1,), name='sex', dtype='int64'),
    'cp': keras.Input(shape=(1,), name='cp', dtype='int64')
}
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
for i in inputs:
   print(i)
# Out:
# age
# trestbps
# chol
# sex
# cp

# %% [markdown]
# Creamos una lista de variables codificadas/normalizadas de acuerdo con su tipo, empleando las funciones de codificación/normalización

# %%
feats_encoded = [
    encode_numerical_feature(inputs['age'], 'age', train_ds),
    encode_numerical_feature(inputs['trestbps'], 'trestbps', train_ds),
    encode_numerical_feature(inputs['chol'], 'chol', train_ds),
    encode_categorical_feature(inputs['sex'], 'sex', train_ds, False),  # 'sex' es categórica (entero)
    encode_categorical_feature(inputs['cp'], 'cp', train_ds, False)  # 'cp' es categórica (entero)
]
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.

# %%
len_feats = len(feats_encoded)
len_feats
# Out:
# 5

# %%
for i in feats_encoded:
  print(i)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization/truediv:0', description="created by layer 'normalization'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_1/truediv:0', description="created by layer 'normalization_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='normalization_2/truediv:0', description="created by layer 'normalization_2'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 3), dtype=tf.float32, name=None), name='integer_lookup/bincount/DenseBincount:0', description="created by layer 'integer_lookup'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 6), dtype=tf.float32, name=None), name='integer_lookup_1/bincount/DenseBincount:0', description="created by layer 'integer_lookup_1'")

# %% [markdown]
# Creamos una capa concatenando todas las variables codificadas

# %%
all_feats = keras.layers.concatenate(feats_encoded)

# %%
type(all_feats)
# Out:
# keras.src.engine.keras_tensor.KerasTensor

# %% [markdown]
# Agregamos una capa densa con 32 neuronas y función de activación relu

# %%
#Base
model_layers = keras.layers.Dense(32, activation='relu')(all_feats)

#variacion 1
model_layers_var1 = keras.layers.Dense(8, activation='relu')(all_feats)

#variacion 2
model_layers_var2 = keras.layers.Dense(64, activation='relu')(all_feats)

#variacion 3
model_layers_var3 = keras.layers.Dense(128, activation='relu')(all_feats)

# %% [markdown]
# Agregamos la capa de salida con 1 neurona (probabilidad de sufrir la enfermedad cardiada) y función de activación sigmoide

# %%
#Base
model_layers = keras.layers.Dense(1, activation='sigmoid')(model_layers)

#variacion 1
model_layers_var1 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var1)

#variacion 2
model_layers_var2 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var2)

#variacion 3
model_layers_var3 = keras.layers.Dense(1, activation='sigmoid')(model_layers_var3)

# %% [markdown]
# Creamos el modelo con las capas ya creadas y las variables de entrada

# %%
#Base
model = keras.Model(inputs, model_layers)

#variacion 1
model_var1= keras.Model(inputs, model_layers_var1)

#Variacion 2
model_var2= keras.Model(inputs, model_layers_var2)

#Variacion 3
model_var3= keras.Model(inputs, model_layers_var3)

# %% [markdown]
# Compilamos el modelo, definiendo optimizador, función de pérdida y métricas adicionales a capturar

# %%
#Base
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#variacion 1
model_var1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 2
model_var2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#Variacion 3
model_var3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Aseguramos que Keras use TensorFlow como backend, para asegurar que el modelo pueda usar strings como entradas

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %% [markdown]
# Entrenamos el modelo con los datos en el formato tf.Dataset

# %%
#Base 
history=model.fit(train_ds, epochs=50, validation_data=val_ds)

#variacion 1
history_var1=model_var1.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 2
history_var2=model_var2.fit(train_ds, epochs=50, validation_data=val_ds)

#Variacion 3
history_var3=model_var3.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 7/7 [==============================] - 1s 27ms/step - loss: 0.6849 - accuracy: 0.5103 - val_loss: 0.6625 - val_accuracy: 0.5833
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6619 - accuracy: 0.5825 - val_loss: 0.6421 - val_accuracy: 0.6250
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6428 - accuracy: 0.6443 - val_loss: 0.6236 - val_accuracy: 0.6458
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6262 - accuracy: 0.6701 - val_loss: 0.6075 - val_accuracy: 0.6458
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6103 - accuracy: 0.6959 - val_loss: 0.5922 - val_accuracy: 0.6875
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5962 - accuracy: 0.7268 - val_loss: 0.5785 - val_accuracy: 0.7083
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5843 - accuracy: 0.7165 - val_loss: 0.5664 - val_accuracy: 0.7292
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5745 - accuracy: 0.7216 - val_loss: 0.5574 - val_accuracy: 0.7292
# Epoch 9/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5649 - accuracy: 0.7268 - val_loss: 0.5490 - val_accuracy: 0.7292
# Epoch 10/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5569 - accuracy: 0.7320 - val_loss: 0.5407 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5489 - accuracy: 0.7371 - val_loss: 0.5336 - val_accuracy: 0.7292
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5423 - accuracy: 0.7371 - val_loss: 0.5280 - val_accuracy: 0.7292
# Epoch 13/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5363 - accuracy: 0.7474 - val_loss: 0.5246 - val_accuracy: 0.7292
# Epoch 14/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5303 - accuracy: 0.7474 - val_loss: 0.5211 - val_accuracy: 0.7292
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5252 - accuracy: 0.7474 - val_loss: 0.5181 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5207 - accuracy: 0.7423 - val_loss: 0.5141 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5159 - accuracy: 0.7423 - val_loss: 0.5103 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5116 - accuracy: 0.7423 - val_loss: 0.5071 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5074 - accuracy: 0.7423 - val_loss: 0.5041 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5030 - accuracy: 0.7423 - val_loss: 0.5014 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5000 - accuracy: 0.7423 - val_loss: 0.4982 - val_accuracy: 0.7292
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4967 - accuracy: 0.7423 - val_loss: 0.4950 - val_accuracy: 0.7292
# Epoch 23/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4931 - accuracy: 0.7423 - val_loss: 0.4925 - val_accuracy: 0.7292
# Epoch 24/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4902 - accuracy: 0.7423 - val_loss: 0.4907 - val_accuracy: 0.7292
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4870 - accuracy: 0.7423 - val_loss: 0.4896 - val_accuracy: 0.7292
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4831 - accuracy: 0.7474 - val_loss: 0.4871 - val_accuracy: 0.7292
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4804 - accuracy: 0.7474 - val_loss: 0.4846 - val_accuracy: 0.7292
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4777 - accuracy: 0.7474 - val_loss: 0.4821 - val_accuracy: 0.7292
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4756 - accuracy: 0.7577 - val_loss: 0.4796 - val_accuracy: 0.7292
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4730 - accuracy: 0.7577 - val_loss: 0.4772 - val_accuracy: 0.7292
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4705 - accuracy: 0.7629 - val_loss: 0.4752 - val_accuracy: 0.7292
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4677 - accuracy: 0.7629 - val_loss: 0.4737 - val_accuracy: 0.7292
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4652 - accuracy: 0.7629 - val_loss: 0.4730 - val_accuracy: 0.7292
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4625 - accuracy: 0.7629 - val_loss: 0.4710 - val_accuracy: 0.7292
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4600 - accuracy: 0.7629 - val_loss: 0.4687 - val_accuracy: 0.7292
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4579 - accuracy: 0.7732 - val_loss: 0.4659 - val_accuracy: 0.7292
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4562 - accuracy: 0.7887 - val_loss: 0.4625 - val_accuracy: 0.7500
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4541 - accuracy: 0.7887 - val_loss: 0.4594 - val_accuracy: 0.7500
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4518 - accuracy: 0.7887 - val_loss: 0.4572 - val_accuracy: 0.7500
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4500 - accuracy: 0.7887 - val_loss: 0.4553 - val_accuracy: 0.7500
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4477 - accuracy: 0.7887 - val_loss: 0.4539 - val_accuracy: 0.7500
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4457 - accuracy: 0.7887 - val_loss: 0.4519 - val_accuracy: 0.7500
# Epoch 43/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4438 - accuracy: 0.7784 - val_loss: 0.4507 - val_accuracy: 0.7500
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4421 - accuracy: 0.7784 - val_loss: 0.4497 - val_accuracy: 0.7500
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4405 - accuracy: 0.7732 - val_loss: 0.4480 - val_accuracy: 0.7500
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4397 - accuracy: 0.7887 - val_loss: 0.4466 - val_accuracy: 0.7500
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4379 - accuracy: 0.7835 - val_loss: 0.4451 - val_accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4365 - accuracy: 0.7784 - val_loss: 0.4433 - val_accuracy: 0.7292
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4348 - accuracy: 0.7784 - val_loss: 0.4420 - val_accuracy: 0.7292
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4340 - accuracy: 0.7784 - val_loss: 0.4412 - val_accuracy: 0.7500
# Epoch 1/50
# 7/7 [==============================] - 1s 24ms/step - loss: 0.6181 - accuracy: 0.7423 - val_loss: 0.6004 - val_accuracy: 0.7500
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6124 - accuracy: 0.7423 - val_loss: 0.5963 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6076 - accuracy: 0.7423 - val_loss: 0.5927 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6032 - accuracy: 0.7423 - val_loss: 0.5885 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5986 - accuracy: 0.7423 - val_loss: 0.5848 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5940 - accuracy: 0.7423 - val_loss: 0.5808 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5892 - accuracy: 0.7423 - val_loss: 0.5767 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5848 - accuracy: 0.7423 - val_loss: 0.5726 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5808 - accuracy: 0.7423 - val_loss: 0.5680 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5761 - accuracy: 0.7423 - val_loss: 0.5641 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5723 - accuracy: 0.7423 - val_loss: 0.5610 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5692 - accuracy: 0.7423 - val_loss: 0.5582 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5654 - accuracy: 0.7423 - val_loss: 0.5555 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5624 - accuracy: 0.7423 - val_loss: 0.5525 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5586 - accuracy: 0.7423 - val_loss: 0.5505 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5560 - accuracy: 0.7423 - val_loss: 0.5483 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5528 - accuracy: 0.7423 - val_loss: 0.5461 - val_accuracy: 0.7500
# Epoch 18/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5503 - accuracy: 0.7423 - val_loss: 0.5437 - val_accuracy: 0.7500
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5475 - accuracy: 0.7423 - val_loss: 0.5411 - val_accuracy: 0.7500
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5441 - accuracy: 0.7423 - val_loss: 0.5385 - val_accuracy: 0.7500
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5406 - accuracy: 0.7423 - val_loss: 0.5362 - val_accuracy: 0.7500
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5378 - accuracy: 0.7423 - val_loss: 0.5337 - val_accuracy: 0.7500
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5348 - accuracy: 0.7423 - val_loss: 0.5310 - val_accuracy: 0.7500
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5318 - accuracy: 0.7423 - val_loss: 0.5283 - val_accuracy: 0.7500
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5288 - accuracy: 0.7423 - val_loss: 0.5260 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5265 - accuracy: 0.7423 - val_loss: 0.5243 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5237 - accuracy: 0.7423 - val_loss: 0.5224 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5212 - accuracy: 0.7423 - val_loss: 0.5202 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5187 - accuracy: 0.7423 - val_loss: 0.5180 - val_accuracy: 0.7500
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5164 - accuracy: 0.7423 - val_loss: 0.5159 - val_accuracy: 0.7500
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5140 - accuracy: 0.7423 - val_loss: 0.5141 - val_accuracy: 0.7500
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5121 - accuracy: 0.7423 - val_loss: 0.5112 - val_accuracy: 0.7500
# Epoch 33/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5095 - accuracy: 0.7423 - val_loss: 0.5090 - val_accuracy: 0.7500
# Epoch 34/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5068 - accuracy: 0.7423 - val_loss: 0.5070 - val_accuracy: 0.7500
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5048 - accuracy: 0.7474 - val_loss: 0.5050 - val_accuracy: 0.7500
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5024 - accuracy: 0.7474 - val_loss: 0.5028 - val_accuracy: 0.7292
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5000 - accuracy: 0.7474 - val_loss: 0.5005 - val_accuracy: 0.7292
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4977 - accuracy: 0.7474 - val_loss: 0.4988 - val_accuracy: 0.7292
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4960 - accuracy: 0.7526 - val_loss: 0.4972 - val_accuracy: 0.7292
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4943 - accuracy: 0.7526 - val_loss: 0.4951 - val_accuracy: 0.7292
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4920 - accuracy: 0.7577 - val_loss: 0.4927 - val_accuracy: 0.7292
# Epoch 42/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4901 - accuracy: 0.7577 - val_loss: 0.4902 - val_accuracy: 0.7292
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4881 - accuracy: 0.7577 - val_loss: 0.4886 - val_accuracy: 0.7292
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4864 - accuracy: 0.7577 - val_loss: 0.4868 - val_accuracy: 0.7292
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4846 - accuracy: 0.7577 - val_loss: 0.4852 - val_accuracy: 0.7292
# Epoch 46/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4826 - accuracy: 0.7526 - val_loss: 0.4835 - val_accuracy: 0.7292
# Epoch 47/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4810 - accuracy: 0.7526 - val_loss: 0.4816 - val_accuracy: 0.7292
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4792 - accuracy: 0.7526 - val_loss: 0.4801 - val_accuracy: 0.7292
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4777 - accuracy: 0.7526 - val_loss: 0.4784 - val_accuracy: 0.7292
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4761 - accuracy: 0.7526 - val_loss: 0.4766 - val_accuracy: 0.7292
# Epoch 1/50
# 7/7 [==============================] - 1s 22ms/step - loss: 0.6737 - accuracy: 0.6340 - val_loss: 0.6540 - val_accuracy: 0.6667
# Epoch 2/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6467 - accuracy: 0.7371 - val_loss: 0.6261 - val_accuracy: 0.7292
# Epoch 3/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6203 - accuracy: 0.7526 - val_loss: 0.6045 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6024 - accuracy: 0.7474 - val_loss: 0.5860 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5865 - accuracy: 0.7474 - val_loss: 0.5715 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5739 - accuracy: 0.7423 - val_loss: 0.5586 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5613 - accuracy: 0.7423 - val_loss: 0.5475 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5514 - accuracy: 0.7423 - val_loss: 0.5377 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5421 - accuracy: 0.7423 - val_loss: 0.5300 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5340 - accuracy: 0.7423 - val_loss: 0.5227 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5270 - accuracy: 0.7423 - val_loss: 0.5174 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5210 - accuracy: 0.7423 - val_loss: 0.5106 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5143 - accuracy: 0.7423 - val_loss: 0.5044 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5082 - accuracy: 0.7423 - val_loss: 0.4992 - val_accuracy: 0.7708
# Epoch 15/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5028 - accuracy: 0.7526 - val_loss: 0.4941 - val_accuracy: 0.7708
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4978 - accuracy: 0.7526 - val_loss: 0.4887 - val_accuracy: 0.7708
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4931 - accuracy: 0.7526 - val_loss: 0.4832 - val_accuracy: 0.7708
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4882 - accuracy: 0.7526 - val_loss: 0.4778 - val_accuracy: 0.7708
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4846 - accuracy: 0.7526 - val_loss: 0.4732 - val_accuracy: 0.7708
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4806 - accuracy: 0.7526 - val_loss: 0.4699 - val_accuracy: 0.7708
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4770 - accuracy: 0.7577 - val_loss: 0.4669 - val_accuracy: 0.7917
# Epoch 22/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4729 - accuracy: 0.7577 - val_loss: 0.4638 - val_accuracy: 0.7917
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4688 - accuracy: 0.7577 - val_loss: 0.4598 - val_accuracy: 0.7708
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4648 - accuracy: 0.7784 - val_loss: 0.4566 - val_accuracy: 0.7708
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4620 - accuracy: 0.7732 - val_loss: 0.4542 - val_accuracy: 0.7917
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4584 - accuracy: 0.7732 - val_loss: 0.4522 - val_accuracy: 0.7917
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4553 - accuracy: 0.7784 - val_loss: 0.4522 - val_accuracy: 0.7917
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4543 - accuracy: 0.7732 - val_loss: 0.4515 - val_accuracy: 0.8125
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4506 - accuracy: 0.7680 - val_loss: 0.4496 - val_accuracy: 0.7917
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4479 - accuracy: 0.7732 - val_loss: 0.4475 - val_accuracy: 0.7917
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4458 - accuracy: 0.7732 - val_loss: 0.4447 - val_accuracy: 0.7917
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4440 - accuracy: 0.7732 - val_loss: 0.4410 - val_accuracy: 0.7708
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4415 - accuracy: 0.7732 - val_loss: 0.4379 - val_accuracy: 0.7708
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4406 - accuracy: 0.7680 - val_loss: 0.4352 - val_accuracy: 0.8125
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4387 - accuracy: 0.7784 - val_loss: 0.4335 - val_accuracy: 0.7917
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4369 - accuracy: 0.7784 - val_loss: 0.4324 - val_accuracy: 0.7917
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4353 - accuracy: 0.7784 - val_loss: 0.4311 - val_accuracy: 0.7917
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4341 - accuracy: 0.7784 - val_loss: 0.4296 - val_accuracy: 0.7917
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4327 - accuracy: 0.7784 - val_loss: 0.4289 - val_accuracy: 0.7708
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4316 - accuracy: 0.7732 - val_loss: 0.4291 - val_accuracy: 0.7708
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4300 - accuracy: 0.7732 - val_loss: 0.4301 - val_accuracy: 0.7917
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4279 - accuracy: 0.7732 - val_loss: 0.4303 - val_accuracy: 0.7917
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4265 - accuracy: 0.7732 - val_loss: 0.4294 - val_accuracy: 0.7917
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4259 - accuracy: 0.7784 - val_loss: 0.4279 - val_accuracy: 0.7917
# Epoch 45/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4251 - accuracy: 0.7784 - val_loss: 0.4271 - val_accuracy: 0.7917
# Epoch 46/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4243 - accuracy: 0.7732 - val_loss: 0.4265 - val_accuracy: 0.7917
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4215 - accuracy: 0.7938 - val_loss: 0.4272 - val_accuracy: 0.7708
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4209 - accuracy: 0.7990 - val_loss: 0.4271 - val_accuracy: 0.7500
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4200 - accuracy: 0.8041 - val_loss: 0.4276 - val_accuracy: 0.7292
# Epoch 50/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4195 - accuracy: 0.8144 - val_loss: 0.4270 - val_accuracy: 0.7500
# Epoch 1/50
# 7/7 [==============================] - 1s 23ms/step - loss: 0.6815 - accuracy: 0.5515 - val_loss: 0.6394 - val_accuracy: 0.7083
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6318 - accuracy: 0.7216 - val_loss: 0.5966 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5968 - accuracy: 0.7423 - val_loss: 0.5681 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5748 - accuracy: 0.7423 - val_loss: 0.5502 - val_accuracy: 0.7500
# Epoch 5/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5572 - accuracy: 0.7423 - val_loss: 0.5363 - val_accuracy: 0.7500
# Epoch 6/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5436 - accuracy: 0.7423 - val_loss: 0.5251 - val_accuracy: 0.7500
# Epoch 7/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5323 - accuracy: 0.7423 - val_loss: 0.5144 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5217 - accuracy: 0.7423 - val_loss: 0.5041 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5130 - accuracy: 0.7423 - val_loss: 0.4948 - val_accuracy: 0.7500
# Epoch 10/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5038 - accuracy: 0.7423 - val_loss: 0.4883 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4962 - accuracy: 0.7423 - val_loss: 0.4804 - val_accuracy: 0.7500
# Epoch 12/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4913 - accuracy: 0.7577 - val_loss: 0.4726 - val_accuracy: 0.7917
# Epoch 13/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4845 - accuracy: 0.7526 - val_loss: 0.4659 - val_accuracy: 0.7500
# Epoch 14/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4782 - accuracy: 0.7526 - val_loss: 0.4618 - val_accuracy: 0.7708
# Epoch 15/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4724 - accuracy: 0.7474 - val_loss: 0.4569 - val_accuracy: 0.7708
# Epoch 16/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4679 - accuracy: 0.7474 - val_loss: 0.4518 - val_accuracy: 0.7917
# Epoch 17/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4627 - accuracy: 0.7423 - val_loss: 0.4479 - val_accuracy: 0.8125
# Epoch 18/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4582 - accuracy: 0.7526 - val_loss: 0.4434 - val_accuracy: 0.8125
# Epoch 19/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4550 - accuracy: 0.7526 - val_loss: 0.4399 - val_accuracy: 0.8125
# Epoch 20/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4518 - accuracy: 0.7526 - val_loss: 0.4365 - val_accuracy: 0.8125
# Epoch 21/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4494 - accuracy: 0.7474 - val_loss: 0.4332 - val_accuracy: 0.8125
# Epoch 22/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4465 - accuracy: 0.7526 - val_loss: 0.4333 - val_accuracy: 0.8125
# Epoch 23/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4446 - accuracy: 0.7680 - val_loss: 0.4324 - val_accuracy: 0.7708
# Epoch 24/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4419 - accuracy: 0.7732 - val_loss: 0.4315 - val_accuracy: 0.7292
# Epoch 25/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4402 - accuracy: 0.7784 - val_loss: 0.4297 - val_accuracy: 0.7292
# Epoch 26/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4383 - accuracy: 0.7732 - val_loss: 0.4313 - val_accuracy: 0.7500
# Epoch 27/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4360 - accuracy: 0.7835 - val_loss: 0.4307 - val_accuracy: 0.7500
# Epoch 28/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4338 - accuracy: 0.7887 - val_loss: 0.4318 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4325 - accuracy: 0.7887 - val_loss: 0.4320 - val_accuracy: 0.7500
# Epoch 30/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4313 - accuracy: 0.7835 - val_loss: 0.4305 - val_accuracy: 0.7500
# Epoch 31/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4294 - accuracy: 0.7835 - val_loss: 0.4288 - val_accuracy: 0.7500
# Epoch 32/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4279 - accuracy: 0.7835 - val_loss: 0.4276 - val_accuracy: 0.7292
# Epoch 33/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4269 - accuracy: 0.7835 - val_loss: 0.4263 - val_accuracy: 0.7292
# Epoch 34/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4262 - accuracy: 0.7887 - val_loss: 0.4259 - val_accuracy: 0.7292
# Epoch 35/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4247 - accuracy: 0.7835 - val_loss: 0.4248 - val_accuracy: 0.7292
# Epoch 36/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4245 - accuracy: 0.7887 - val_loss: 0.4259 - val_accuracy: 0.7500
# Epoch 37/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4232 - accuracy: 0.7835 - val_loss: 0.4252 - val_accuracy: 0.7708
# Epoch 38/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.7835 - val_loss: 0.4258 - val_accuracy: 0.7708
# Epoch 39/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4215 - accuracy: 0.7938 - val_loss: 0.4272 - val_accuracy: 0.7708
# Epoch 40/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4212 - accuracy: 0.7990 - val_loss: 0.4302 - val_accuracy: 0.7708
# Epoch 41/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4200 - accuracy: 0.8041 - val_loss: 0.4302 - val_accuracy: 0.7708
# Epoch 42/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4195 - accuracy: 0.8041 - val_loss: 0.4287 - val_accuracy: 0.7708
# Epoch 43/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4182 - accuracy: 0.8041 - val_loss: 0.4271 - val_accuracy: 0.7708
# Epoch 44/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4163 - accuracy: 0.7990 - val_loss: 0.4263 - val_accuracy: 0.7708
# Epoch 45/50
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4166 - accuracy: 0.7835 - val_loss: 0.4267 - val_accuracy: 0.7917
# Epoch 46/50
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4149 - accuracy: 0.7990 - val_loss: 0.4245 - val_accuracy: 0.8125
# Epoch 47/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4136 - accuracy: 0.7990 - val_loss: 0.4216 - val_accuracy: 0.7917
# Epoch 48/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4120 - accuracy: 0.7990 - val_loss: 0.4156 - val_accuracy: 0.7917
# Epoch 49/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4120 - accuracy: 0.8041 - val_loss: 0.4128 - val_accuracy: 0.7708
# Epoch 50/50
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4114 - accuracy: 0.8093 - val_loss: 0.4119 - val_accuracy: 0.7708

# %% [markdown]
# Graficar la pérdida de entrenamiento y validación

# %%
#Base
plt.plot(history.history['loss'], label='Perdida')
plt.plot(history.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Base")
plt.show()

#variacion 1
plt.plot(history_var1.history['loss'], label='Perdida')
plt.plot(history_var1.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 1")
plt.show()

#variacion 2
plt.plot(history_var2.history['loss'], label='Perdida')
plt.plot(history_var2.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 2")
plt.show()

#variacion 3
plt.plot(history_var3.history['loss'], label='Perdida')
plt.plot(history_var3.history['val_loss'], label='Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("variacion 3")
plt.show()

# %% [markdown]
# Hacer predicciones en el set de prueba

# %%
#base 
y_true = []
y_pred = []
for x, y in test_ds:
    y_true.extend(list(y.numpy()))
    y_pred.extend(list(model.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin = [1 if pred >= 0.5 else 0 for pred in y_pred]

# varicacion 1
y_pred_var1 = []
for x, y in test_ds:
    y_pred_var1.extend(list(model_var1.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var1 = [1 if pred >= 0.5 else 0 for pred in y_pred_var1]


# varicacion 2
y_pred_var2 = []
for x, y in test_ds:
    y_pred_var2.extend(list(model_var2.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var2 = [1 if pred >= 0.5 else 0 for pred in y_pred_var2]


# varicacion 3
y_pred_var3 = []
for x, y in test_ds:
    y_pred_var3.extend(list(model_var3.predict(x).flatten()))

# Convertir las predicciones a binario (0 o 1)
y_pred_bin_var3 = [1 if pred >= 0.5 else 0 for pred in y_pred_var3]
# Out:
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 88ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000018496486840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 84ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000018496486840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 92ms/step

# %% [markdown]
# Calcular las métricas

# %%
#base

from sklearn.metrics import classification_report, confusion_matrix

#base
# Calcular métricas
print("Base")
print(classification_report(y_true, y_pred_bin, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin))
# Out:
# Base
#                precision    recall  f1-score   support
#
# No enfermedad       0.67      1.00      0.80        40
#    Enfermedad       1.00      0.05      0.09        21
#
#      accuracy                           0.67        61
#     macro avg       0.83      0.52      0.45        61
#  weighted avg       0.78      0.67      0.56        61
#
# Matriz de confusión:
#  [[40  0]
#  [20  1]]

# %%
#variacion 1
print("Variacion 1")
print(classification_report(y_true, y_pred_bin_var1, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var1))
# Out:
# Variacion 1
#                precision    recall  f1-score   support
#
# No enfermedad       0.66      0.95      0.78        40
#    Enfermedad       0.33      0.05      0.08        21
#
#      accuracy                           0.64        61
#     macro avg       0.49      0.50      0.43        61
#  weighted avg       0.54      0.64      0.54        61
#
# Matriz de confusión:
#  [[38  2]
#  [20  1]]

# %%
#variacion 2
print("Variacion 2")
print(classification_report(y_true, y_pred_bin_var2, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var2))
# Out:
# Variacion 2
#                precision    recall  f1-score   support
#
# No enfermedad       0.62      0.72      0.67        40
#    Enfermedad       0.21      0.14      0.17        21
#
#      accuracy                           0.52        61
#     macro avg       0.42      0.43      0.42        61
#  weighted avg       0.48      0.52      0.50        61
#
# Matriz de confusión:
#  [[29 11]
#  [18  3]]

# %%
#variacion 3
print("Variacion 3")
print(classification_report(y_true, y_pred_bin_var3, target_names=['No enfermedad', 'Enfermedad']))
print("Matriz de confusión:\n", confusion_matrix(y_true,y_pred_bin_var3))
# Out:
# Variacion 3
#                precision    recall  f1-score   support
#
# No enfermedad       0.63      0.80      0.70        40
#    Enfermedad       0.20      0.10      0.13        21
#
#      accuracy                           0.56        61
#     macro avg       0.41      0.45      0.42        61
#  weighted avg       0.48      0.56      0.51        61
#
# Matriz de confusión:
#  [[32  8]
#  [19  2]]
